# %%
### Download waste data on household waste 
### from regionalstatistik.de and compile into csv with Regions as rows
### and indicators and years as columns.

# %%
#41141-03-01-4
#https://www.regionalstatistik.de/genesis//online?operation=table&code=32121-01-02-4-B&bypass=true&levelindex=0&levelid=1658850132846#abreadcrumb
#include years 2007-2020 and set regions to Landkreise, download as csv

# %%
# import necessary libraries

import pandas as pd
import numpy as np

# %%
#load dataset from local file
source_df = pd.read_csv("data/32121-01-02-4_flat_haushaltsabfaelle.csv",delimiter=";", encoding='latin1', low_memory=False)

# #remove subgroups of waste (everything except for organic waste total) Haus- und Sperrmüll, Getrennt erfasste organische Abfälle, Getrennt erfasste Wertstoffe, Sonstige Abfälle, Biotonne, abbaubare Garten- und Parkabfälle and Insgesamt
# source_df = source_df[(source_df['2_Auspraegung_Code'] != 'ABFALLART100') & (source_df['2_Auspraegung_Code'] != 'ABFALLART300') & (source_df['2_Auspraegung_Code'] != 'ABFALLART400') & (source_df['2_Auspraegung_Code'] != 'ABFALLART201') & (source_df['2_Auspraegung_Code'] != 'ABFALLART202') & (source_df['2_Auspraegung_Label'] != "Insgesamt")]

#remove subgroups of waste Haus- und Sperrmüll, Getrennt erfasste organische Abfälle, Getrennt erfasste Wertstoffe, Sonstige Abfälle and Insgesamt
source_df = source_df[(source_df['2_Auspraegung_Code'] != 'ABFALLART100') & (source_df['2_Auspraegung_Code'] != 'ABFALLART300') & (source_df['2_Auspraegung_Code'] != 'ABFALLART400') & (source_df['2_Auspraegung_Label'] != "Insgesamt") ]

source_df
# Out:
#        Statistik_Code                                    Statistik_Label  \
# 2               32121  Erhebung der öffentlich-rechtlichen Abfallents...
# 3               32121  Erhebung der öffentlich-rechtlichen Abfallents...
# 4               32121  Erhebung der öffentlich-rechtlichen Abfallents...
# 9               32121  Erhebung der öffentlich-rechtlichen Abfallents...
# 10              32121  Erhebung der öffentlich-rechtlichen Abfallents...
# ...               ...                                                ...
# 64011           32121  Erhebung der öffentlich-rechtlichen Abfallents...
# 64012           32121  Erhebung der öffentlich-rechtlichen Abfallents...
# 64017           32121  Erhebung der öffentlich-rechtlichen Abfallents...
# 64018           32121  Erhebung der öffentlich-rechtlichen Abfallents...
# 64019           32121  Erhebung der öffentlich-rechtlichen Abfallents...
#
#       Zeit_Code Zeit_Label  Zeit 1_Merkmal_Code               1_Merkmal_Label  \
# 2          JAHR       Jahr  2020         KREISE  Kreise und kreisfreie Städte
# 3          JAHR       Jahr  2020         KREISE  Kreise und kreisfreie Städte
# 4          JAHR       Jahr  2020         KREISE  Kreise und kreisfreie Städte
# 9          JAHR       Jahr  2020         KREISE  Kreise und kreisfreie Städte
# 10         JAHR       Jahr  2020         KREISE  Kreise und kreisfreie Städte
# ...         ...        ...   ...            ...                           ...
# 64011      JAHR       Jahr  2004         KREISE  Kreise und kreisfreie Städte
# 64012      JAHR       Jahr  2004         KREISE  Kreise und kreisfreie Städte
# 64017      JAHR       Jahr  2004         KREISE  Kreise und kreisfreie Städte
# 64018      JAHR       Jahr  2004         KREISE  Kreise und kreisfreie Städte
# 64019      JAHR       Jahr  2004         KREISE  Kreise und kreisfreie Städte
#
#       1_Auspraegung_Code            1_Auspraegung_Label 2_Merkmal_Code  \
# 2                     DG                    Deutschland         ABFA01
# 3                     DG                    Deutschland         ABFA01
# 4                     DG                    Deutschland         ABFA01
# 9                     01             Schleswig-Holstein         ABFA01
# 10                    01             Schleswig-Holstein         ABFA01
# ...                  ...                            ...            ...
# 64011              16076                   Greiz, Kreis         ABFA01
# 64012              16076                   Greiz, Kreis         ABFA01
# 64017              16077        Altenburger Land, Kreis         ABFA01
# 64018              16077        Altenburger Land, Kreis         ABFA01
# 64019              16077        Altenburger Land, Kreis         ABFA01
#
#                          2_Merkmal_Label 2_Auspraegung_Code  \
# 2      Abfallarten von Haushaltsabfällen       ABFALLART200
# 3      Abfallarten von Haushaltsabfällen       ABFALLART201
# 4      Abfallarten von Haushaltsabfällen       ABFALLART202
# 9      Abfallarten von Haushaltsabfällen       ABFALLART200
# 10     Abfallarten von Haushaltsabfällen       ABFALLART201
# ...                                  ...                ...
# 64011  Abfallarten von Haushaltsabfällen       ABFALLART201
# 64012  Abfallarten von Haushaltsabfällen       ABFALLART202
# 64017  Abfallarten von Haushaltsabfällen       ABFALLART200
# 64018  Abfallarten von Haushaltsabfällen       ABFALLART201
# 64019  Abfallarten von Haushaltsabfällen       ABFALLART202
#
#                              2_Auspraegung_Label  \
# 2           Getrennt erfasste organische Abfälle
# 3                       Abfälle aus der Biotonne
# 4      biolog. abbaubare Garten- und Parkabfälle
# 9           Getrennt erfasste organische Abfälle
# 10                      Abfälle aus der Biotonne
# ...                                          ...
# 64011                   Abfälle aus der Biotonne
# 64012  biolog. abbaubare Garten- und Parkabfälle
# 64017       Getrennt erfasste organische Abfälle
# 64018                   Abfälle aus der Biotonne
# 64019  biolog. abbaubare Garten- und Parkabfälle
#
#       AEW009__Aufkommen_an_Haushaltsabfaellen_(o.E-altgeraete)__t
# 2                                               10634192
# 3                                                5300612
# 4                                                5333580
# 9                                                 357418
# 10                                                289453
# ...                                                  ...
# 64011                                               3845
# 64012                                               2168
# 64017                                              11950
# 64018                                               5435
# 64019                                               6515
#
# [27438 rows x 14 columns]

# %%
waste_df = source_df.copy()

#extract year from date
waste_df['Jahr']=waste_df['Zeit'].astype(str)

#drop unnecessary columns
waste_df.drop(columns=['Zeit','Statistik_Code', 'Statistik_Label', 'Zeit_Code', 'Zeit_Label', 
       '1_Merkmal_Code', '1_Merkmal_Label', 
       '2_Merkmal_Code', '2_Merkmal_Label',
       '2_Auspraegung_Code'],inplace=True)

#rename columns
waste_df.rename(columns={'1_Auspraegung_Code':'AGS','1_Auspraegung_Label':'Name','2_Auspraegung_Label':'Abfall','AEW009__Aufkommen_an_Haushaltsabfaellen_(o.E-altgeraete)__t':'weight'},inplace=True)

#replace '-' with 0 and '.' with 'NaN according to Zeichnerklärung
waste_df['weight'].replace('-','0',inplace=True)
waste_df['weight'] = waste_df['weight'].apply(pd.to_numeric,errors='coerce')

waste_df['AGS']=waste_df['AGS'].replace("DG",0)

waste_df
# Out:
#          AGS                           Name  \
# 2          0                    Deutschland
# 3          0                    Deutschland
# 4          0                    Deutschland
# 9         01             Schleswig-Holstein
# 10        01             Schleswig-Holstein
# ...      ...                            ...
# 64011  16076                   Greiz, Kreis
# 64012  16076                   Greiz, Kreis
# 64017  16077        Altenburger Land, Kreis
# 64018  16077        Altenburger Land, Kreis
# 64019  16077        Altenburger Land, Kreis
#
#                                           Abfall      weight  Jahr
# 2           Getrennt erfasste organische Abfälle  10634192.0  2020
# 3                       Abfälle aus der Biotonne   5300612.0  2020
# 4      biolog. abbaubare Garten- und Parkabfälle   5333580.0  2020
# 9           Getrennt erfasste organische Abfälle    357418.0  2020
# 10                      Abfälle aus der Biotonne    289453.0  2020
# ...                                          ...         ...   ...
# 64011                   Abfälle aus der Biotonne      3845.0  2004
# 64012  biolog. abbaubare Garten- und Parkabfälle      2168.0  2004
# 64017       Getrennt erfasste organische Abfälle     11950.0  2004
# 64018                   Abfälle aus der Biotonne      5435.0  2004
# 64019  biolog. abbaubare Garten- und Parkabfälle      6515.0  2004
#
# [27438 rows x 5 columns]

# %%
#pivot dataframe to show waste and years as columns
pt_df = waste_df.pivot(index=['AGS','Name'],columns=['Abfall','Jahr'],values=['weight'])

#rename columns
pt_df.rename(columns={'Getrennt erfasste organische Abfälle':'sum'},inplace=True)

#rename columns sub groups organic waste
pt_df.rename(columns={'biolog. abbaubare Garten- und Parkabfälle':'gartenPark', 'Abfälle aus der Biotonne':'biotonne'},inplace=True)

pt_df
# Out:
#                                                           weight             \
# Abfall                                                       sum   biotonne
# Jahr                                                        2020       2020
# AGS   Name
# 0     Deutschland                                     10634192.0  5300612.0
# 01      Schleswig-Holstein                              357418.0   289453.0
# 01001       Flensburg, kreisfreie Stadt                   6050.0     4753.0
# 01002       Kiel, Landeshauptstadt, kreisfreie Stadt     16333.0    12825.0
# 01003       Lübeck, Hansestadt, kreisfreie Stadt         22232.0    15850.0
# ...                                                          ...        ...
# 16073       Saalfeld-Rudolstadt, Kreis                   18769.0        0.0
# 16074       Saale-Holzland-Kreis                           681.0        0.0
# 16075       Saale-Orla-Kreis                             14633.0        0.0
# 16076       Greiz, Kreis                                 12452.0     4209.0
# 16077       Altenburger Land, Kreis                      13470.0     5606.0
#
#                                                                              \
# Abfall                                               gartenPark         sum
# Jahr                                                       2020        2019
# AGS   Name
# 0     Deutschland                                     5333580.0  10168446.0
# 01      Schleswig-Holstein                              67965.0    349582.0
# 01001       Flensburg, kreisfreie Stadt                  1297.0      5922.0
# 01002       Kiel, Landeshauptstadt, kreisfreie Stadt     3508.0     16035.0
# 01003       Lübeck, Hansestadt, kreisfreie Stadt         6383.0     20058.0
# ...                                                         ...         ...
# 16073       Saalfeld-Rudolstadt, Kreis                  18769.0     15470.0
# 16074       Saale-Holzland-Kreis                          681.0       337.0
# 16075       Saale-Orla-Kreis                            14633.0     12039.0
# 16076       Greiz, Kreis                                 8244.0     13994.0
# 16077       Altenburger Land, Kreis                      7863.0     14205.0
#
#                                                                             \
# Abfall                                                 biotonne gartenPark
# Jahr                                                       2019       2019
# AGS   Name
# 0     Deutschland                                     4974001.0  5194445.0
# 01      Schleswig-Holstein                             272217.0    77366.0
# 01001       Flensburg, kreisfreie Stadt                  4610.0     1311.0
# 01002       Kiel, Landeshauptstadt, kreisfreie Stadt    12231.0     3804.0
# 01003       Lübeck, Hansestadt, kreisfreie Stadt        15236.0     4823.0
# ...                                                         ...        ...
# 16073       Saalfeld-Rudolstadt, Kreis                      0.0    15470.0
# 16074       Saale-Holzland-Kreis                            0.0      337.0
# 16075       Saale-Orla-Kreis                                0.0    12039.0
# 16076       Greiz, Kreis                                 4122.0     9871.0
# 16077       Altenburger Land, Kreis                      5434.0     8771.0
#
#                                                                             \
# Abfall                                                      sum   biotonne
# Jahr                                                       2018       2018
# AGS   Name
# 0     Deutschland                                     9930936.0  4811882.0
# 01      Schleswig-Holstein                             329004.0   260503.0
# 01001       Flensburg, kreisfreie Stadt                  5764.0     4640.0
# 01002       Kiel, Landeshauptstadt, kreisfreie Stadt    15174.0    11696.0
# 01003       Lübeck, Hansestadt, kreisfreie Stadt        18789.0    14395.0
# ...                                                         ...        ...
# 16073       Saalfeld-Rudolstadt, Kreis                  17860.0        0.0
# 16074       Saale-Holzland-Kreis                          291.0        0.0
# 16075       Saale-Orla-Kreis                            13580.0        0.0
# 16076       Greiz, Kreis                                15448.0     4039.0
# 16077       Altenburger Land, Kreis                     12971.0     5255.0
#
#                                                                              \
# Abfall                                               gartenPark         sum
# Jahr                                                       2018        2017
# AGS   Name
# 0     Deutschland                                     5119053.0  10317997.0
# 01      Schleswig-Holstein                              68502.0    349171.0
# 01001       Flensburg, kreisfreie Stadt                  1124.0      5974.0
# 01002       Kiel, Landeshauptstadt, kreisfreie Stadt     3479.0     16425.0
# 01003       Lübeck, Hansestadt, kreisfreie Stadt         4394.0     19080.0
# ...                                                         ...         ...
# 16073       Saalfeld-Rudolstadt, Kreis                  17860.0     17208.0
# 16074       Saale-Holzland-Kreis                          291.0       268.0
# 16075       Saale-Orla-Kreis                            13580.0     13062.0
# 16076       Greiz, Kreis                                11409.0     16863.0
# 16077       Altenburger Land, Kreis                      7716.0     14383.0
#
#                                                       ...             \
# Abfall                                                ... gartenPark
# Jahr                                                  ...       2007
# AGS   Name                                            ...
# 0     Deutschland                                     ...  4565002.0
# 01      Schleswig-Holstein                            ...    71079.0
# 01001       Flensburg, kreisfreie Stadt               ...      388.0
# 01002       Kiel, Landeshauptstadt, kreisfreie Stadt  ...     2273.0
# 01003       Lübeck, Hansestadt, kreisfreie Stadt      ...     4423.0
# ...                                                   ...        ...
# 16073       Saalfeld-Rudolstadt, Kreis                ...    10394.0
# 16074       Saale-Holzland-Kreis                      ...        0.0
# 16075       Saale-Orla-Kreis                          ...     7774.0
# 16076       Greiz, Kreis                              ...     3050.0
# 16077       Altenburger Land, Kreis                   ...     7843.0
#
#                                                                             \
# Abfall                                                      sum   biotonne
# Jahr                                                       2006       2006
# AGS   Name
# 0     Deutschland                                     8449750.0  4150037.0
# 01      Schleswig-Holstein                             279705.0   199807.0
# 01001       Flensburg, kreisfreie Stadt                  5658.0     4865.0
# 01002       Kiel, Landeshauptstadt, kreisfreie Stadt    11872.0    10605.0
# 01003       Lübeck, Hansestadt, kreisfreie Stadt        20442.0    16406.0
# ...                                                         ...        ...
# 16073       Saalfeld-Rudolstadt, Kreis                   9314.0        0.0
# 16074       Saale-Holzland-Kreis                            0.0        0.0
# 16075       Saale-Orla-Kreis                             6945.0        0.0
# 16076       Greiz, Kreis                                 7711.0     6104.0
# 16077       Altenburger Land, Kreis                     11473.0     5013.0
#
#                                                                             \
# Abfall                                               gartenPark        sum
# Jahr                                                       2006       2005
# AGS   Name
# 0     Deutschland                                     4299713.0  8337073.0
# 01      Schleswig-Holstein                              79898.0   269548.0
# 01001       Flensburg, kreisfreie Stadt                   793.0     5731.0
# 01002       Kiel, Landeshauptstadt, kreisfreie Stadt     1267.0    12229.0
# 01003       Lübeck, Hansestadt, kreisfreie Stadt         4036.0    20012.0
# ...                                                         ...        ...
# 16073       Saalfeld-Rudolstadt, Kreis                   9314.0     8880.0
# 16074       Saale-Holzland-Kreis                            0.0        0.0
# 16075       Saale-Orla-Kreis                             6945.0     6622.0
# 16076       Greiz, Kreis                                 1607.0     6372.0
# 16077       Altenburger Land, Kreis                      6460.0    12038.0
#
#                                                                             \
# Abfall                                                 biotonne gartenPark
# Jahr                                                       2005       2005
# AGS   Name
# 0     Deutschland                                     4082797.0  4254278.0
# 01      Schleswig-Holstein                             199457.0    70091.0
# 01001       Flensburg, kreisfreie Stadt                  5008.0      723.0
# 01002       Kiel, Landeshauptstadt, kreisfreie Stadt    10346.0     1884.0
# 01003       Lübeck, Hansestadt, kreisfreie Stadt        16435.0     3577.0
# ...                                                         ...        ...
# 16073       Saalfeld-Rudolstadt, Kreis                      0.0     8880.0
# 16074       Saale-Holzland-Kreis                            0.0        0.0
# 16075       Saale-Orla-Kreis                                0.0     6622.0
# 16076       Greiz, Kreis                                 3922.0     2450.0
# 16077       Altenburger Land, Kreis                      5219.0     6819.0
#
#                                                                             \
# Abfall                                                      sum   biotonne
# Jahr                                                       2004       2004
# AGS   Name
# 0     Deutschland                                     8411408.0  4121133.0
# 01      Schleswig-Holstein                             280514.0   198751.0
# 01001       Flensburg, kreisfreie Stadt                  5647.0     5138.0
# 01002       Kiel, Landeshauptstadt, kreisfreie Stadt     9793.0     8759.0
# 01003       Lübeck, Hansestadt, kreisfreie Stadt        21755.0    16477.0
# ...                                                         ...        ...
# 16073       Saalfeld-Rudolstadt, Kreis                   9586.0        0.0
# 16074       Saale-Holzland-Kreis                            0.0        0.0
# 16075       Saale-Orla-Kreis                             7151.0        0.0
# 16076       Greiz, Kreis                                 6013.0     3845.0
# 16077       Altenburger Land, Kreis                     11950.0     5435.0
#
#
# Abfall                                               gartenPark
# Jahr                                                       2004
# AGS   Name
# 0     Deutschland                                     4290276.0
# 01      Schleswig-Holstein                              81764.0
# 01001       Flensburg, kreisfreie Stadt                   509.0
# 01002       Kiel, Landeshauptstadt, kreisfreie Stadt     1033.0
# 01003       Lübeck, Hansestadt, kreisfreie Stadt         5279.0
# ...                                                         ...
# 16073       Saalfeld-Rudolstadt, Kreis                   9586.0
# 16074       Saale-Holzland-Kreis                            0.0
# 16075       Saale-Orla-Kreis                             7151.0
# 16076       Greiz, Kreis                                 2168.0
# 16077       Altenburger Land, Kreis                      6515.0
#
# [538 rows x 51 columns]

# %%
#collapse levels of column names and join waste type to year
pt_df.columns = pt_df.columns.map('_'.join)

#sort columns so indicators are together
pt_df.columns=sorted(pt_df.columns)

#prepend all columns with indicator name
pt_df=pt_df.add_prefix('waste_organicwaste_')

#convert AGS to numeric and set as new index
pt_df.reset_index(inplace=True)
pt_df['AGS'] = pd.to_numeric(pt_df['AGS'])
pt_df.set_index('AGS',inplace=True)
pt_df.sort_index(ascending=True,inplace=True)

#strip whitespace from region names
pt_df['Name']=pt_df['Name'].str.strip()

pt_df
# Out:
#                                 Name  waste_organicwaste_weight_biotonne_2004  \
# AGS
# 0                        Deutschland                               10634192.0
# 1                 Schleswig-Holstein                                 357418.0
# 2                            Hamburg                                 102429.0
# 3                      Niedersachsen                                1329956.0
# 4                             Bremen                                  56822.0
# ...                              ...                                      ...
# 11008008             Berlin-Neukölln                                      NaN
# 11009009     Berlin-Treptow-Köpenick                                      NaN
# 11010010  Berlin-Marzahn-Hellersdorf                                      NaN
# 11011011          Berlin-Lichtenberg                                      NaN
# 11012012        Berlin-Reinickendorf                                      NaN
#
#           waste_organicwaste_weight_biotonne_2005  \
# AGS
# 0                                       5300612.0
# 1                                        289453.0
# 2                                         76552.0
# 3                                        572939.0
# 4                                         25144.0
# ...                                           ...
# 11008008                                      NaN
# 11009009                                      NaN
# 11010010                                      NaN
# 11011011                                      NaN
# 11012012                                      NaN
#
#           waste_organicwaste_weight_biotonne_2006  \
# AGS
# 0                                       5333580.0
# 1                                         67965.0
# 2                                         25877.0
# 3                                        757017.0
# 4                                         31678.0
# ...                                           ...
# 11008008                                      NaN
# 11009009                                      NaN
# 11010010                                      NaN
# 11011011                                      NaN
# 11012012                                      NaN
#
#           waste_organicwaste_weight_biotonne_2007  \
# AGS
# 0                                      10168446.0
# 1                                        349582.0
# 2                                         91600.0
# 3                                       1258621.0
# 4                                         56126.0
# ...                                           ...
# 11008008                                      NaN
# 11009009                                      NaN
# 11010010                                      NaN
# 11011011                                      NaN
# 11012012                                      NaN
#
#           waste_organicwaste_weight_biotonne_2008  \
# AGS
# 0                                       4974001.0
# 1                                        272217.0
# 2                                         69470.0
# 3                                        533336.0
# 4                                         23069.0
# ...                                           ...
# 11008008                                      NaN
# 11009009                                      NaN
# 11010010                                      NaN
# 11011011                                      NaN
# 11012012                                      NaN
#
#           waste_organicwaste_weight_biotonne_2009  \
# AGS
# 0                                       5194445.0
# 1                                         77366.0
# 2                                         22130.0
# 3                                        725285.0
# 4                                         33057.0
# ...                                           ...
# 11008008                                      NaN
# 11009009                                      NaN
# 11010010                                      NaN
# 11011011                                      NaN
# 11012012                                      NaN
#
#           waste_organicwaste_weight_biotonne_2010  \
# AGS
# 0                                       9930936.0
# 1                                        329004.0
# 2                                         85630.0
# 3                                       1271927.0
# 4                                         53216.0
# ...                                           ...
# 11008008                                      NaN
# 11009009                                      NaN
# 11010010                                      NaN
# 11011011                                      NaN
# 11012012                                      NaN
#
#           waste_organicwaste_weight_biotonne_2011  \
# AGS
# 0                                       4811882.0
# 1                                        260503.0
# 2                                         63270.0
# 3                                        501369.0
# 4                                         22398.0
# ...                                           ...
# 11008008                                      NaN
# 11009009                                      NaN
# 11010010                                      NaN
# 11011011                                      NaN
# 11012012                                      NaN
#
#           waste_organicwaste_weight_biotonne_2012  ...  \
# AGS                                                ...
# 0                                       5119053.0  ...
# 1                                         68502.0  ...
# 2                                         22360.0  ...
# 3                                        770558.0  ...
# 4                                         30818.0  ...
# ...                                           ...  ...
# 11008008                                      NaN  ...
# 11009009                                      NaN  ...
# 11010010                                      NaN  ...
# 11011011                                      NaN  ...
# 11012012                                      NaN  ...
#
#           waste_organicwaste_weight_sum_2011  \
# AGS
# 0                                  4565002.0
# 1                                    71079.0
# 2                                    11000.0
# 3                                   715170.0
# 4                                    35455.0
# ...                                      ...
# 11008008                                 0.0
# 11009009                                 0.0
# 11010010                                 0.0
# 11011011                                 0.0
# 11012012                                 0.0
#
#           waste_organicwaste_weight_sum_2012  \
# AGS
# 0                                  8449750.0
# 1                                   279705.0
# 2                                    35700.0
# 3                                  1146005.0
# 4                                    56972.0
# ...                                      ...
# 11008008                                 0.0
# 11009009                                 0.0
# 11010010                                 0.0
# 11011011                                 0.0
# 11012012                                 0.0
#
#           waste_organicwaste_weight_sum_2013  \
# AGS
# 0                                  4150037.0
# 1                                   199807.0
# 2                                    25600.0
# 3                                   484514.0
# 4                                    23318.0
# ...                                      ...
# 11008008                                 0.0
# 11009009                                 0.0
# 11010010                                 0.0
# 11011011                                 0.0
# 11012012                                 0.0
#
#           waste_organicwaste_weight_sum_2014  \
# AGS
# 0                                  4299713.0
# 1                                    79898.0
# 2                                    10100.0
# 3                                   661492.0
# 4                                    33654.0
# ...                                      ...
# 11008008                                 0.0
# 11009009                                 0.0
# 11010010                                 0.0
# 11011011                                 0.0
# 11012012                                 0.0
#
#           waste_organicwaste_weight_sum_2015  \
# AGS
# 0                                  8337073.0
# 1                                   269548.0
# 2                                    36200.0
# 3                                  1121577.0
# 4                                    58026.0
# ...                                      ...
# 11008008                                 0.0
# 11009009                                 0.0
# 11010010                                 0.0
# 11011011                                 0.0
# 11012012                                 0.0
#
#           waste_organicwaste_weight_sum_2016  \
# AGS
# 0                                  4082797.0
# 1                                   199457.0
# 2                                    26200.0
# 3                                   484742.0
# 4                                    23721.0
# ...                                      ...
# 11008008                                 0.0
# 11009009                                 0.0
# 11010010                                 0.0
# 11011011                                 0.0
# 11012012                                 0.0
#
#           waste_organicwaste_weight_sum_2017  \
# AGS
# 0                                  4254278.0
# 1                                    70091.0
# 2                                    10000.0
# 3                                   636835.0
# 4                                    34305.0
# ...                                      ...
# 11008008                                 0.0
# 11009009                                 0.0
# 11010010                                 0.0
# 11011011                                 0.0
# 11012012                                 0.0
#
#           waste_organicwaste_weight_sum_2018  \
# AGS
# 0                                  8411408.0
# 1                                   280514.0
# 2                                    37300.0
# 3                                  1105169.0
# 4                                    57008.0
# ...                                      ...
# 11008008                                 0.0
# 11009009                                 0.0
# 11010010                                 0.0
# 11011011                                 0.0
# 11012012                                 0.0
#
#           waste_organicwaste_weight_sum_2019  \
# AGS
# 0                                  4121133.0
# 1                                   198751.0
# 2                                    27200.0
# 3                                   497938.0
# 4                                    24058.0
# ...                                      ...
# 11008008                                 0.0
# 11009009                                 0.0
# 11010010                                 0.0
# 11011011                                 0.0
# 11012012                                 0.0
#
#           waste_organicwaste_weight_sum_2020
# AGS
# 0                                  4290276.0
# 1                                    81764.0
# 2                                    10100.0
# 3                                   607231.0
# 4                                    32950.0
# ...                                      ...
# 11008008                                 0.0
# 11009009                                 0.0
# 11010010                                 0.0
# 11011011                                 0.0
# 11012012                                 0.0
#
# [538 rows x 52 columns]

# %%
#save dataframe to file
pt_df.to_csv("data/final_data_landkreis_waste_organicwaste.csv")

# %%
## DATASNIPPET FOR TESTING

schweinfurt = waste_df[waste_df.AGS == "09678"]
schweinfurt.drop(["Name","AGS"],axis= 1,inplace=True)

schweinfurt.to_csv("data/snippet/organicwaste_schweinfurtLK.csv")

# %%
# convert column "a" of a DataFrame
waste_df["AGS"] = pd.to_numeric(waste_df["AGS"])
bundeslaender = waste_df[(waste_df["AGS"] <= 16) & (waste_df["AGS"] > 0)]
bundeslaender = bundeslaender[bundeslaender["Abfall"] == "Getrennt erfasste organische Abfälle"]
bundeslaender.drop(["AGS"],axis= 1,inplace=True)
bundeslaender = bundeslaender.reset_index(drop=True)
bundeslaender
bundeslaender.to_csv("data/snippet/organicwaste_bundeslaenderOhneDL.csv")

# %%
deutschland = waste_df[waste_df.Name == "Deutschland"]
deutschland.drop(["Name","AGS"],axis= 1,inplace=True)
deutschland
deutschland.to_csv("data/snippet/organicwaste_deutschland.csv")
# Out:
# /var/folders/dy/pr7w31xd5xnf1fpgcxmx8zrh0000gn/T/ipykernel_87196/3566189559.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   deutschland.drop(["Name","AGS"],axis= 1,inplace=True)
