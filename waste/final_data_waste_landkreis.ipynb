# %%
### Download waste data on household waste 
### from regionalstatistik.de and compile into csv with Regions as rows
### and indicators and years as columns.

# %%
#41141-03-01-4
#https://www.regionalstatistik.de/genesis//online?operation=table&code=32121-01-02-4-B&bypass=true&levelindex=0&levelid=1658850132846#abreadcrumb
#include years 2007-2020 and set regions to Landkreise, download as csv

# %%
# import necessary libraries

import pandas as pd
import numpy as np

# %%
#load dataset from local file
source_df = pd.read_csv("data/32121-01-02-4-B_flat_haushaltsabfaelle.csv",delimiter=";", encoding='latin1', low_memory=False)

# #remove subgroups of waste (everything except for organic waste total) Haus- und Sperrmüll, Getrennt erfasste organische Abfälle, Getrennt erfasste Wertstoffe, Sonstige Abfälle, Biotonne, abbaubare Garten- und Parkabfälle and Insgesamt
# source_df = source_df[(source_df['2_Auspraegung_Code'] != 'ABFALLART100') & (source_df['2_Auspraegung_Code'] != 'ABFALLART300') & (source_df['2_Auspraegung_Code'] != 'ABFALLART400') & (source_df['2_Auspraegung_Code'] != 'ABFALLART201') & (source_df['2_Auspraegung_Code'] != 'ABFALLART202') & (source_df['2_Auspraegung_Label'] != "Insgesamt")]

#remove subgroups of waste Haus- und Sperrmüll, Getrennt erfasste organische Abfälle, Getrennt erfasste Wertstoffe, Sonstige Abfälle and Insgesamt
source_df = source_df[(source_df['2_Auspraegung_Code'] != 'ABFALLART100') & (source_df['2_Auspraegung_Code'] != 'ABFALLART300') & (source_df['2_Auspraegung_Code'] != 'ABFALLART400') & (source_df['2_Auspraegung_Label'] != "Insgesamt")]

source_df
# Out:
#        Statistik_Code                                    Statistik_Label  \
# 2               32121  Erhebung der öffentlich-rechtlichen Abfallents...
# 3               32121  Erhebung der öffentlich-rechtlichen Abfallents...
# 4               32121  Erhebung der öffentlich-rechtlichen Abfallents...
# 9               32121  Erhebung der öffentlich-rechtlichen Abfallents...
# 10              32121  Erhebung der öffentlich-rechtlichen Abfallents...
# ...               ...                                                ...
# 47911           32121  Erhebung der öffentlich-rechtlichen Abfallents...
# 47912           32121  Erhebung der öffentlich-rechtlichen Abfallents...
# 47917           32121  Erhebung der öffentlich-rechtlichen Abfallents...
# 47918           32121  Erhebung der öffentlich-rechtlichen Abfallents...
# 47919           32121  Erhebung der öffentlich-rechtlichen Abfallents...
#
#       Zeit_Code Zeit_Label  Zeit 1_Merkmal_Code               1_Merkmal_Label  \
# 2          JAHR       Jahr  2020         KREISE  Kreise und kreisfreie Städte
# 3          JAHR       Jahr  2020         KREISE  Kreise und kreisfreie Städte
# 4          JAHR       Jahr  2020         KREISE  Kreise und kreisfreie Städte
# 9          JAHR       Jahr  2020         KREISE  Kreise und kreisfreie Städte
# 10         JAHR       Jahr  2020         KREISE  Kreise und kreisfreie Städte
# ...         ...        ...   ...            ...                           ...
# 47911      JAHR       Jahr  2007         KREISE  Kreise und kreisfreie Städte
# 47912      JAHR       Jahr  2007         KREISE  Kreise und kreisfreie Städte
# 47917      JAHR       Jahr  2007         KREISE  Kreise und kreisfreie Städte
# 47918      JAHR       Jahr  2007         KREISE  Kreise und kreisfreie Städte
# 47919      JAHR       Jahr  2007         KREISE  Kreise und kreisfreie Städte
#
#        1_Auspraegung_Code                       1_Auspraegung_Label  \
# 2                    1001               Flensburg, kreisfreie Stadt
# 3                    1001               Flensburg, kreisfreie Stadt
# 4                    1001               Flensburg, kreisfreie Stadt
# 9                    1002  Kiel, Landeshauptstadt, kreisfreie Stadt
# 10                   1002  Kiel, Landeshauptstadt, kreisfreie Stadt
# ...                   ...                                       ...
# 47911               16076                              Greiz, Kreis
# 47912               16076                              Greiz, Kreis
# 47917               16077                   Altenburger Land, Kreis
# 47918               16077                   Altenburger Land, Kreis
# 47919               16077                   Altenburger Land, Kreis
#
#       2_Merkmal_Code                    2_Merkmal_Label 2_Auspraegung_Code  \
# 2             ABFA01  Abfallarten von Haushaltsabfällen       ABFALLART200
# 3             ABFA01  Abfallarten von Haushaltsabfällen       ABFALLART201
# 4             ABFA01  Abfallarten von Haushaltsabfällen       ABFALLART202
# 9             ABFA01  Abfallarten von Haushaltsabfällen       ABFALLART200
# 10            ABFA01  Abfallarten von Haushaltsabfällen       ABFALLART201
# ...              ...                                ...                ...
# 47911         ABFA01  Abfallarten von Haushaltsabfällen       ABFALLART201
# 47912         ABFA01  Abfallarten von Haushaltsabfällen       ABFALLART202
# 47917         ABFA01  Abfallarten von Haushaltsabfällen       ABFALLART200
# 47918         ABFA01  Abfallarten von Haushaltsabfällen       ABFALLART201
# 47919         ABFA01  Abfallarten von Haushaltsabfällen       ABFALLART202
#
#                              2_Auspraegung_Label  \
# 2           Getrennt erfasste organische Abfälle
# 3                       Abfälle aus der Biotonne
# 4      biolog. abbaubare Garten- und Parkabfälle
# 9           Getrennt erfasste organische Abfälle
# 10                      Abfälle aus der Biotonne
# ...                                          ...
# 47911                   Abfälle aus der Biotonne
# 47912  biolog. abbaubare Garten- und Parkabfälle
# 47917       Getrennt erfasste organische Abfälle
# 47918                   Abfälle aus der Biotonne
# 47919  biolog. abbaubare Garten- und Parkabfälle
#
#       AEW009__Aufkommen_an_Haushaltsabfaellen_(o.E-altgeraete)__t
# 2                                                   6050
# 3                                                   4753
# 4                                                   1297
# 9                                                  16333
# 10                                                 12825
# ...                                                  ...
# 47911                                               4044
# 47912                                               3050
# 47917                                              12946
# 47918                                               5103
# 47919                                               7843
#
# [20538 rows x 14 columns]

# %%
waste_df = source_df.copy()

#extract year from date
waste_df['Jahr']=waste_df['Zeit'].astype(str)

#drop unnecessary columns
waste_df.drop(columns=['Zeit','Statistik_Code', 'Statistik_Label', 'Zeit_Code', 'Zeit_Label', 
       '1_Merkmal_Code', '1_Merkmal_Label', 
       '2_Merkmal_Code', '2_Merkmal_Label',
       '2_Auspraegung_Code'],inplace=True)

#rename columns
waste_df.rename(columns={'1_Auspraegung_Code':'AGS','1_Auspraegung_Label':'Name','2_Auspraegung_Label':'Abfall','AEW009__Aufkommen_an_Haushaltsabfaellen_(o.E-altgeraete)__t':'weight'},inplace=True)

#replace '-' with 0 and '.' with 'NaN according to Zeichnerklärung
waste_df['weight'].replace('-','0',inplace=True)
waste_df['weight'] = waste_df['weight'].apply(pd.to_numeric,errors='coerce')

waste_df['AGS']=waste_df['AGS'].replace("DG",0)

waste_df
# Out:
#          AGS                                      Name  \
# 2       1001               Flensburg, kreisfreie Stadt
# 3       1001               Flensburg, kreisfreie Stadt
# 4       1001               Flensburg, kreisfreie Stadt
# 9       1002  Kiel, Landeshauptstadt, kreisfreie Stadt
# 10      1002  Kiel, Landeshauptstadt, kreisfreie Stadt
# ...      ...                                       ...
# 47911  16076                              Greiz, Kreis
# 47912  16076                              Greiz, Kreis
# 47917  16077                   Altenburger Land, Kreis
# 47918  16077                   Altenburger Land, Kreis
# 47919  16077                   Altenburger Land, Kreis
#
#                                           Abfall   weight  Jahr
# 2           Getrennt erfasste organische Abfälle   6050.0  2020
# 3                       Abfälle aus der Biotonne   4753.0  2020
# 4      biolog. abbaubare Garten- und Parkabfälle   1297.0  2020
# 9           Getrennt erfasste organische Abfälle  16333.0  2020
# 10                      Abfälle aus der Biotonne  12825.0  2020
# ...                                          ...      ...   ...
# 47911                   Abfälle aus der Biotonne   4044.0  2007
# 47912  biolog. abbaubare Garten- und Parkabfälle   3050.0  2007
# 47917       Getrennt erfasste organische Abfälle  12946.0  2007
# 47918                   Abfälle aus der Biotonne   5103.0  2007
# 47919  biolog. abbaubare Garten- und Parkabfälle   7843.0  2007
#
# [20538 rows x 5 columns]

# %%
#pivot dataframe to show waste and years as columns
pt_df = waste_df.pivot(index=['AGS','Name'],columns=['Abfall','Jahr'],values=['weight'])

#rename columns
pt_df.rename(columns={'Getrennt erfasste organische Abfälle':'sum'},inplace=True)

#rename columns sub groups organic waste
pt_df.rename(columns={'biolog. abbaubare Garten- und Parkabfälle':'gartenPark', 'Abfälle aus der Biotonne':'biotonne'},inplace=True)

pt_df
# Out:
#                                                     weight           \
# Abfall                                                 sum biotonne
# Jahr                                                  2020     2020
# AGS      Name
# 1001     Flensburg, kreisfreie Stadt                6050.0   4753.0
# 1002     Kiel, Landeshauptstadt, kreisfreie Stadt  16333.0  12825.0
# 1003     Lübeck, Hansestadt, kreisfreie Stadt      22232.0  15850.0
# 1004     Neumünster, kreisfreie Stadt              15841.0   6034.0
# 1051     Dithmarschen, Landkreis                   18565.0  17982.0
# ...                                                    ...      ...
# 11008008 Berlin-Neukölln                               NaN      NaN
# 11009009 Berlin-Treptow-Köpenick                       NaN      NaN
# 11010010 Berlin-Marzahn-Hellersdorf                    NaN      NaN
# 11011011 Berlin-Lichtenberg                            NaN      NaN
# 11012012 Berlin-Reinickendorf                          NaN      NaN
#
#                                                                        \
# Abfall                                            gartenPark      sum
# Jahr                                                    2020     2019
# AGS      Name
# 1001     Flensburg, kreisfreie Stadt                  1297.0   5922.0
# 1002     Kiel, Landeshauptstadt, kreisfreie Stadt     3508.0  16035.0
# 1003     Lübeck, Hansestadt, kreisfreie Stadt         6383.0  20058.0
# 1004     Neumünster, kreisfreie Stadt                 9807.0  17900.0
# 1051     Dithmarschen, Landkreis                       583.0  17681.0
# ...                                                      ...      ...
# 11008008 Berlin-Neukölln                                 NaN      NaN
# 11009009 Berlin-Treptow-Köpenick                         NaN      NaN
# 11010010 Berlin-Marzahn-Hellersdorf                      NaN      NaN
# 11011011 Berlin-Lichtenberg                              NaN      NaN
# 11012012 Berlin-Reinickendorf                            NaN      NaN
#
#                                                                        \
# Abfall                                            biotonne gartenPark
# Jahr                                                  2019       2019
# AGS      Name
# 1001     Flensburg, kreisfreie Stadt                4610.0     1311.0
# 1002     Kiel, Landeshauptstadt, kreisfreie Stadt  12231.0     3804.0
# 1003     Lübeck, Hansestadt, kreisfreie Stadt      15236.0     4823.0
# 1004     Neumünster, kreisfreie Stadt               6322.0    11578.0
# 1051     Dithmarschen, Landkreis                   17119.0      562.0
# ...                                                    ...        ...
# 11008008 Berlin-Neukölln                               NaN        NaN
# 11009009 Berlin-Treptow-Köpenick                       NaN        NaN
# 11010010 Berlin-Marzahn-Hellersdorf                    NaN        NaN
# 11011011 Berlin-Lichtenberg                            NaN        NaN
# 11012012 Berlin-Reinickendorf                          NaN        NaN
#
#                                                                      \
# Abfall                                                 sum biotonne
# Jahr                                                  2018     2018
# AGS      Name
# 1001     Flensburg, kreisfreie Stadt                5764.0   4640.0
# 1002     Kiel, Landeshauptstadt, kreisfreie Stadt  15174.0  11696.0
# 1003     Lübeck, Hansestadt, kreisfreie Stadt      18789.0  14395.0
# 1004     Neumünster, kreisfreie Stadt              13074.0   6827.0
# 1051     Dithmarschen, Landkreis                   17026.0  16479.0
# ...                                                    ...      ...
# 11008008 Berlin-Neukölln                               NaN      NaN
# 11009009 Berlin-Treptow-Köpenick                       NaN      NaN
# 11010010 Berlin-Marzahn-Hellersdorf                    NaN      NaN
# 11011011 Berlin-Lichtenberg                            NaN      NaN
# 11012012 Berlin-Reinickendorf                          NaN      NaN
#
#                                                                        ...  \
# Abfall                                            gartenPark      sum  ...
# Jahr                                                    2018     2017  ...
# AGS      Name                                                          ...
# 1001     Flensburg, kreisfreie Stadt                  1124.0   5974.0  ...
# 1002     Kiel, Landeshauptstadt, kreisfreie Stadt     3479.0  16425.0  ...
# 1003     Lübeck, Hansestadt, kreisfreie Stadt         4394.0  19080.0  ...
# 1004     Neumünster, kreisfreie Stadt                 6247.0  17226.0  ...
# 1051     Dithmarschen, Landkreis                       547.0  17736.0  ...
# ...                                                      ...      ...  ...
# 11008008 Berlin-Neukölln                                 NaN      NaN  ...
# 11009009 Berlin-Treptow-Köpenick                         NaN      NaN  ...
# 11010010 Berlin-Marzahn-Hellersdorf                      NaN      NaN  ...
# 11011011 Berlin-Lichtenberg                              NaN      NaN  ...
# 11012012 Berlin-Reinickendorf                            NaN      NaN  ...
#
#                                                                        \
# Abfall                                            gartenPark      sum
# Jahr                                                    2010     2009
# AGS      Name
# 1001     Flensburg, kreisfreie Stadt                   971.0   5963.0
# 1002     Kiel, Landeshauptstadt, kreisfreie Stadt     3496.0  14141.0
# 1003     Lübeck, Hansestadt, kreisfreie Stadt         5123.0  22418.0
# 1004     Neumünster, kreisfreie Stadt                 4534.0  13936.0
# 1051     Dithmarschen, Landkreis                      1859.0  17117.0
# ...                                                      ...      ...
# 11008008 Berlin-Neukölln                                 0.0      0.0
# 11009009 Berlin-Treptow-Köpenick                         0.0      0.0
# 11010010 Berlin-Marzahn-Hellersdorf                      0.0      0.0
# 11011011 Berlin-Lichtenberg                              0.0      0.0
# 11012012 Berlin-Reinickendorf                            0.0      0.0
#
#                                                                        \
# Abfall                                            biotonne gartenPark
# Jahr                                                  2009       2009
# AGS      Name
# 1001     Flensburg, kreisfreie Stadt                4892.0     1070.0
# 1002     Kiel, Landeshauptstadt, kreisfreie Stadt  10718.0     3423.0
# 1003     Lübeck, Hansestadt, kreisfreie Stadt      16217.0     6202.0
# 1004     Neumünster, kreisfreie Stadt               7658.0     6278.0
# 1051     Dithmarschen, Landkreis                   15081.0     2036.0
# ...                                                    ...        ...
# 11008008 Berlin-Neukölln                               0.0        0.0
# 11009009 Berlin-Treptow-Köpenick                       0.0        0.0
# 11010010 Berlin-Marzahn-Hellersdorf                    0.0        0.0
# 11011011 Berlin-Lichtenberg                            0.0        0.0
# 11012012 Berlin-Reinickendorf                          0.0        0.0
#
#                                                                      \
# Abfall                                                 sum biotonne
# Jahr                                                  2008     2008
# AGS      Name
# 1001     Flensburg, kreisfreie Stadt                5396.0   4845.0
# 1002     Kiel, Landeshauptstadt, kreisfreie Stadt  13474.0  10511.0
# 1003     Lübeck, Hansestadt, kreisfreie Stadt      22400.0  16354.0
# 1004     Neumünster, kreisfreie Stadt              13766.0   7490.0
# 1051     Dithmarschen, Landkreis                   16832.0  14976.0
# ...                                                    ...      ...
# 11008008 Berlin-Neukölln                               0.0      0.0
# 11009009 Berlin-Treptow-Köpenick                       0.0      0.0
# 11010010 Berlin-Marzahn-Hellersdorf                    0.0      0.0
# 11011011 Berlin-Lichtenberg                            0.0      0.0
# 11012012 Berlin-Reinickendorf                          0.0      0.0
#
#                                                                        \
# Abfall                                            gartenPark      sum
# Jahr                                                    2008     2007
# AGS      Name
# 1001     Flensburg, kreisfreie Stadt                   551.0   5308.0
# 1002     Kiel, Landeshauptstadt, kreisfreie Stadt     2963.0  12748.0
# 1003     Lübeck, Hansestadt, kreisfreie Stadt         6046.0  21633.0
# 1004     Neumünster, kreisfreie Stadt                 6276.0  12892.0
# 1051     Dithmarschen, Landkreis                      1856.0  16856.0
# ...                                                      ...      ...
# 11008008 Berlin-Neukölln                                 0.0      0.0
# 11009009 Berlin-Treptow-Köpenick                         0.0      0.0
# 11010010 Berlin-Marzahn-Hellersdorf                      0.0      0.0
# 11011011 Berlin-Lichtenberg                              0.0      0.0
# 11012012 Berlin-Reinickendorf                            0.0      0.0
#
#
# Abfall                                            biotonne gartenPark
# Jahr                                                  2007       2007
# AGS      Name
# 1001     Flensburg, kreisfreie Stadt                4920.0      388.0
# 1002     Kiel, Landeshauptstadt, kreisfreie Stadt  10475.0     2273.0
# 1003     Lübeck, Hansestadt, kreisfreie Stadt      17210.0     4423.0
# 1004     Neumünster, kreisfreie Stadt               7754.0     5138.0
# 1051     Dithmarschen, Landkreis                   14997.0     1859.0
# ...                                                    ...        ...
# 11008008 Berlin-Neukölln                               0.0        0.0
# 11009009 Berlin-Treptow-Köpenick                       0.0        0.0
# 11010010 Berlin-Marzahn-Hellersdorf                    0.0        0.0
# 11011011 Berlin-Lichtenberg                            0.0        0.0
# 11012012 Berlin-Reinickendorf                          0.0        0.0
#
# [489 rows x 42 columns]

# %%
#collapse levels of column names and join waste type to year
pt_df.columns = pt_df.columns.map('_'.join)

#sort columns so indicators are together
pt_df.columns=sorted(pt_df.columns)

#prepend all columns with indicator name
pt_df=pt_df.add_prefix('waste_organicwaste_')

#convert AGS to numeric and set as new index
pt_df.reset_index(inplace=True)
pt_df['AGS'] = pd.to_numeric(pt_df['AGS'])
pt_df.set_index('AGS',inplace=True)
pt_df.sort_index(ascending=True,inplace=True)

#strip whitespace from region names
pt_df['Name']=pt_df['Name'].str.strip()

pt_df
# Out:
#                                               Name  \
# AGS
# 1001                   Flensburg, kreisfreie Stadt
# 1002      Kiel, Landeshauptstadt, kreisfreie Stadt
# 1003          Lübeck, Hansestadt, kreisfreie Stadt
# 1004                  Neumünster, kreisfreie Stadt
# 1051                       Dithmarschen, Landkreis
# ...                                            ...
# 11008008                           Berlin-Neukölln
# 11009009                   Berlin-Treptow-Köpenick
# 11010010                Berlin-Marzahn-Hellersdorf
# 11011011                        Berlin-Lichtenberg
# 11012012                      Berlin-Reinickendorf
#
#           waste_organicwaste_weight_biotonne_2007  \
# AGS
# 1001                                       6050.0
# 1002                                      16333.0
# 1003                                      22232.0
# 1004                                      15841.0
# 1051                                      18565.0
# ...                                           ...
# 11008008                                      NaN
# 11009009                                      NaN
# 11010010                                      NaN
# 11011011                                      NaN
# 11012012                                      NaN
#
#           waste_organicwaste_weight_biotonne_2008  \
# AGS
# 1001                                       4753.0
# 1002                                      12825.0
# 1003                                      15850.0
# 1004                                       6034.0
# 1051                                      17982.0
# ...                                           ...
# 11008008                                      NaN
# 11009009                                      NaN
# 11010010                                      NaN
# 11011011                                      NaN
# 11012012                                      NaN
#
#           waste_organicwaste_weight_biotonne_2009  \
# AGS
# 1001                                       1297.0
# 1002                                       3508.0
# 1003                                       6383.0
# 1004                                       9807.0
# 1051                                        583.0
# ...                                           ...
# 11008008                                      NaN
# 11009009                                      NaN
# 11010010                                      NaN
# 11011011                                      NaN
# 11012012                                      NaN
#
#           waste_organicwaste_weight_biotonne_2010  \
# AGS
# 1001                                       5922.0
# 1002                                      16035.0
# 1003                                      20058.0
# 1004                                      17900.0
# 1051                                      17681.0
# ...                                           ...
# 11008008                                      NaN
# 11009009                                      NaN
# 11010010                                      NaN
# 11011011                                      NaN
# 11012012                                      NaN
#
#           waste_organicwaste_weight_biotonne_2011  \
# AGS
# 1001                                       4610.0
# 1002                                      12231.0
# 1003                                      15236.0
# 1004                                       6322.0
# 1051                                      17119.0
# ...                                           ...
# 11008008                                      NaN
# 11009009                                      NaN
# 11010010                                      NaN
# 11011011                                      NaN
# 11012012                                      NaN
#
#           waste_organicwaste_weight_biotonne_2012  \
# AGS
# 1001                                       1311.0
# 1002                                       3804.0
# 1003                                       4823.0
# 1004                                      11578.0
# 1051                                        562.0
# ...                                           ...
# 11008008                                      NaN
# 11009009                                      NaN
# 11010010                                      NaN
# 11011011                                      NaN
# 11012012                                      NaN
#
#           waste_organicwaste_weight_biotonne_2013  \
# AGS
# 1001                                       5764.0
# 1002                                      15174.0
# 1003                                      18789.0
# 1004                                      13074.0
# 1051                                      17026.0
# ...                                           ...
# 11008008                                      NaN
# 11009009                                      NaN
# 11010010                                      NaN
# 11011011                                      NaN
# 11012012                                      NaN
#
#           waste_organicwaste_weight_biotonne_2014  \
# AGS
# 1001                                       4640.0
# 1002                                      11696.0
# 1003                                      14395.0
# 1004                                       6827.0
# 1051                                      16479.0
# ...                                           ...
# 11008008                                      NaN
# 11009009                                      NaN
# 11010010                                      NaN
# 11011011                                      NaN
# 11012012                                      NaN
#
#           waste_organicwaste_weight_biotonne_2015  ...  \
# AGS                                                ...
# 1001                                       1124.0  ...
# 1002                                       3479.0  ...
# 1003                                       4394.0  ...
# 1004                                       6247.0  ...
# 1051                                        547.0  ...
# ...                                           ...  ...
# 11008008                                      NaN  ...
# 11009009                                      NaN  ...
# 11010010                                      NaN  ...
# 11011011                                      NaN  ...
# 11012012                                      NaN  ...
#
#           waste_organicwaste_weight_sum_2011  \
# AGS
# 1001                                   971.0
# 1002                                  3496.0
# 1003                                  5123.0
# 1004                                  4534.0
# 1051                                  1859.0
# ...                                      ...
# 11008008                                 0.0
# 11009009                                 0.0
# 11010010                                 0.0
# 11011011                                 0.0
# 11012012                                 0.0
#
#           waste_organicwaste_weight_sum_2012  \
# AGS
# 1001                                  5963.0
# 1002                                 14141.0
# 1003                                 22418.0
# 1004                                 13936.0
# 1051                                 17117.0
# ...                                      ...
# 11008008                                 0.0
# 11009009                                 0.0
# 11010010                                 0.0
# 11011011                                 0.0
# 11012012                                 0.0
#
#           waste_organicwaste_weight_sum_2013  \
# AGS
# 1001                                  4892.0
# 1002                                 10718.0
# 1003                                 16217.0
# 1004                                  7658.0
# 1051                                 15081.0
# ...                                      ...
# 11008008                                 0.0
# 11009009                                 0.0
# 11010010                                 0.0
# 11011011                                 0.0
# 11012012                                 0.0
#
#           waste_organicwaste_weight_sum_2014  \
# AGS
# 1001                                  1070.0
# 1002                                  3423.0
# 1003                                  6202.0
# 1004                                  6278.0
# 1051                                  2036.0
# ...                                      ...
# 11008008                                 0.0
# 11009009                                 0.0
# 11010010                                 0.0
# 11011011                                 0.0
# 11012012                                 0.0
#
#           waste_organicwaste_weight_sum_2015  \
# AGS
# 1001                                  5396.0
# 1002                                 13474.0
# 1003                                 22400.0
# 1004                                 13766.0
# 1051                                 16832.0
# ...                                      ...
# 11008008                                 0.0
# 11009009                                 0.0
# 11010010                                 0.0
# 11011011                                 0.0
# 11012012                                 0.0
#
#           waste_organicwaste_weight_sum_2016  \
# AGS
# 1001                                  4845.0
# 1002                                 10511.0
# 1003                                 16354.0
# 1004                                  7490.0
# 1051                                 14976.0
# ...                                      ...
# 11008008                                 0.0
# 11009009                                 0.0
# 11010010                                 0.0
# 11011011                                 0.0
# 11012012                                 0.0
#
#           waste_organicwaste_weight_sum_2017  \
# AGS
# 1001                                   551.0
# 1002                                  2963.0
# 1003                                  6046.0
# 1004                                  6276.0
# 1051                                  1856.0
# ...                                      ...
# 11008008                                 0.0
# 11009009                                 0.0
# 11010010                                 0.0
# 11011011                                 0.0
# 11012012                                 0.0
#
#           waste_organicwaste_weight_sum_2018  \
# AGS
# 1001                                  5308.0
# 1002                                 12748.0
# 1003                                 21633.0
# 1004                                 12892.0
# 1051                                 16856.0
# ...                                      ...
# 11008008                                 0.0
# 11009009                                 0.0
# 11010010                                 0.0
# 11011011                                 0.0
# 11012012                                 0.0
#
#           waste_organicwaste_weight_sum_2019  \
# AGS
# 1001                                  4920.0
# 1002                                 10475.0
# 1003                                 17210.0
# 1004                                  7754.0
# 1051                                 14997.0
# ...                                      ...
# 11008008                                 0.0
# 11009009                                 0.0
# 11010010                                 0.0
# 11011011                                 0.0
# 11012012                                 0.0
#
#           waste_organicwaste_weight_sum_2020
# AGS
# 1001                                   388.0
# 1002                                  2273.0
# 1003                                  4423.0
# 1004                                  5138.0
# 1051                                  1859.0
# ...                                      ...
# 11008008                                 0.0
# 11009009                                 0.0
# 11010010                                 0.0
# 11011011                                 0.0
# 11012012                                 0.0
#
# [489 rows x 43 columns]

# %%
#save dataframe to file
pt_df.to_csv("data/final_data_landkreis_waste_organicwaste.csv")
