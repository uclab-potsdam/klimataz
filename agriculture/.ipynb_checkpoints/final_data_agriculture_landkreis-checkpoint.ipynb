# %%
### Download agriculture data on number of animals per farm
### from regionalstatistik.de and compile into csv with Regions as rows
### and indicators and years as columns.

# %%
#41141-03-01-4-B
#https://www.regionalstatistik.de/genesis/online?operation=find&suchanweisung_language=de&query=41141-03-01-4-B#abreadcrumb
#include all three years and set regions to Landkreise, download as csv

# %%
# import necessary libraries

import pandas as pd
import numpy as np

# %%
#load dataset from local file
source_df = pd.read_csv("data/41141-03-01-4-B_flat.csv",delimiter=";", encoding='latin1', low_memory=False)

#remove subgroups of animals, Milchkühe and Zuchtsauen
source_df = source_df[(source_df['2_Auspraegung_Code'] != 'TIER-111') & (source_df['2_Auspraegung_Code'] != 'TIER-22')]

source_df
# Out:
#       Statistik_Code                                 Statistik_Label  \
# 0              41141  Agrarstrukturerhebung / Landwirtschaftszählung
# 2              41141  Agrarstrukturerhebung / Landwirtschaftszählung
# 4              41141  Agrarstrukturerhebung / Landwirtschaftszählung
# 5              41141  Agrarstrukturerhebung / Landwirtschaftszählung
# 7              41141  Agrarstrukturerhebung / Landwirtschaftszählung
# ...              ...                                             ...
# 7327           41141  Agrarstrukturerhebung / Landwirtschaftszählung
# 7329           41141  Agrarstrukturerhebung / Landwirtschaftszählung
# 7330           41141  Agrarstrukturerhebung / Landwirtschaftszählung
# 7332           41141  Agrarstrukturerhebung / Landwirtschaftszählung
# 7334           41141  Agrarstrukturerhebung / Landwirtschaftszählung
#
#      Zeit_Code Zeit_Label        Zeit 1_Merkmal_Code  \
# 0         STAG   Stichtag  01.03.2010         KREISE
# 2         STAG   Stichtag  01.03.2010         KREISE
# 4         STAG   Stichtag  01.03.2010         KREISE
# 5         STAG   Stichtag  01.03.2010         KREISE
# 7         STAG   Stichtag  01.03.2010         KREISE
# ...        ...        ...         ...            ...
# 7327      STAG   Stichtag  01.03.2020         KREISE
# 7329      STAG   Stichtag  01.03.2020         KREISE
# 7330      STAG   Stichtag  01.03.2020         KREISE
# 7332      STAG   Stichtag  01.03.2020         KREISE
# 7334      STAG   Stichtag  01.03.2020         KREISE
#
#                    1_Merkmal_Label  1_Auspraegung_Code  \
# 0     Kreise und kreisfreie Städte                1001
# 2     Kreise und kreisfreie Städte                1001
# 4     Kreise und kreisfreie Städte                1001
# 5     Kreise und kreisfreie Städte                1002
# 7     Kreise und kreisfreie Städte                1002
# ...                            ...                 ...
# 7327  Kreise und kreisfreie Städte               16076
# 7329  Kreise und kreisfreie Städte               16076
# 7330  Kreise und kreisfreie Städte               16077
# 7332  Kreise und kreisfreie Städte               16077
# 7334  Kreise und kreisfreie Städte               16077
#
#                            1_Auspraegung_Label 2_Merkmal_Code  \
# 0                  Flensburg, kreisfreie Stadt         TIER04
# 2                  Flensburg, kreisfreie Stadt         TIER04
# 4                  Flensburg, kreisfreie Stadt         TIER04
# 5     Kiel, Landeshauptstadt, kreisfreie Stadt         TIER04
# 7     Kiel, Landeshauptstadt, kreisfreie Stadt         TIER04
# ...                                        ...            ...
# 7327                              Greiz, Kreis         TIER04
# 7329                              Greiz, Kreis         TIER04
# 7330                   Altenburger Land, Kreis         TIER04
# 7332                   Altenburger Land, Kreis         TIER04
# 7334                   Altenburger Land, Kreis         TIER04
#
#                                    2_Merkmal_Label 2_Auspraegung_Code  \
# 0     Landwirtschaftliche Betriebe mit Viehhaltung             TIER-1
# 2     Landwirtschaftliche Betriebe mit Viehhaltung             TIER-2
# 4     Landwirtschaftliche Betriebe mit Viehhaltung             TIER-3
# 5     Landwirtschaftliche Betriebe mit Viehhaltung             TIER-1
# 7     Landwirtschaftliche Betriebe mit Viehhaltung             TIER-2
# ...                                            ...                ...
# 7327  Landwirtschaftliche Betriebe mit Viehhaltung             TIER-2
# 7329  Landwirtschaftliche Betriebe mit Viehhaltung             TIER-3
# 7330  Landwirtschaftliche Betriebe mit Viehhaltung             TIER-1
# 7332  Landwirtschaftliche Betriebe mit Viehhaltung             TIER-2
# 7334  Landwirtschaftliche Betriebe mit Viehhaltung             TIER-3
#
#      2_Auspraegung_Label  \
# 0                 Rinder
# 2               Schweine
# 4                 Schafe
# 5                 Rinder
# 7               Schweine
# ...                  ...
# 7327            Schweine
# 7329              Schafe
# 7330              Rinder
# 7332            Schweine
# 7334              Schafe
#
#       BTR034__Landwirtschaftliche_Betriebe_mit_Viehhaltung__Anzahl  \
# 0                                                   NaN
# 2                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 7                                                   NaN
# ...                                                 ...
# 7327                                                NaN
# 7329                                                NaN
# 7330                                                NaN
# 7332                                                NaN
# 7334                                                NaN
#
#       BTR038__Landwirtschaftliche_Betriebe_mit_100_u.m._GV__Anzahl  \
# 0                                                   NaN
# 2                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 7                                                   NaN
# ...                                                 ...
# 7327                                                NaN
# 7329                                                NaN
# 7330                                                NaN
# 7332                                                NaN
# 7334                                                NaN
#
#       VIE003__Viehbestand__GV BTR034__Betriebe__Anzahl TIE003__Tiere__Anzahl
# 0                         NaN                        8                   555
# 2                         NaN                        -                     -
# 4                         NaN                        2                     .
# 5                         NaN                       14                  1296
# 7                         NaN                        3                     .
# ...                       ...                      ...                   ...
# 7327                      NaN                       52                 52023
# 7329                      NaN                       69                  3762
# 7330                      NaN                       65                 12050
# 7332                      NaN                       20                 29186
# 7334                      NaN                       31                  1173
#
# [4401 rows x 18 columns]

# %%
tiere_df = source_df.copy()

#extract year from date
tiere_df['Jahr']=tiere_df['Zeit'].str[-4:]

#drop unnecessary columns
tiere_df.drop(columns=['Zeit','Statistik_Code', 'Statistik_Label', 'Zeit_Code', 'Zeit_Label', 
       '1_Merkmal_Code', '1_Merkmal_Label', 
       '2_Merkmal_Code', '2_Merkmal_Label',
       '2_Auspraegung_Code',
       'BTR034__Landwirtschaftliche_Betriebe_mit_Viehhaltung__Anzahl',
       'BTR038__Landwirtschaftliche_Betriebe_mit_100_u.m._GV__Anzahl',
       'VIE003__Viehbestand__GV', 'BTR034__Betriebe__Anzahl'],inplace=True)

#rename columns
tiere_df.rename(columns={'1_Auspraegung_Code':'AGS','1_Auspraegung_Label':'Name','2_Auspraegung_Label':'Tier','TIE003__Tiere__Anzahl':'Anzahl'},inplace=True)

#replace '-' with 0 and '.' with 'NaN according to Zeichnerklärung
tiere_df['Anzahl'].replace('-','0',inplace=True)
tiere_df['Anzahl'] = tiere_df['Anzahl'].apply(pd.to_numeric,errors='coerce')

tiere_df
# Out:
#         AGS                                      Name      Tier   Anzahl  Jahr
# 0      1001               Flensburg, kreisfreie Stadt    Rinder    555.0  2010
# 2      1001               Flensburg, kreisfreie Stadt  Schweine      0.0  2010
# 4      1001               Flensburg, kreisfreie Stadt    Schafe      NaN  2010
# 5      1002  Kiel, Landeshauptstadt, kreisfreie Stadt    Rinder   1296.0  2010
# 7      1002  Kiel, Landeshauptstadt, kreisfreie Stadt  Schweine      NaN  2010
# ...     ...                                       ...       ...      ...   ...
# 7327  16076                              Greiz, Kreis  Schweine  52023.0  2020
# 7329  16076                              Greiz, Kreis    Schafe   3762.0  2020
# 7330  16077                   Altenburger Land, Kreis    Rinder  12050.0  2020
# 7332  16077                   Altenburger Land, Kreis  Schweine  29186.0  2020
# 7334  16077                   Altenburger Land, Kreis    Schafe   1173.0  2020
#
# [4401 rows x 5 columns]

# %%
#pivot dataframe to show animals and ears as columns
pt_df = tiere_df.pivot(index=['AGS','Name'],columns=['Tier','Jahr'],values=['Anzahl'])
pt_df
# Out:
#                                                      Anzahl                    \
# Tier                                                 Rinder Schweine   Schafe
# Jahr                                                   2010     2010     2010
# AGS      Name
# 1001     Flensburg, kreisfreie Stadt                  555.0      0.0      NaN
# 1002     Kiel, Landeshauptstadt, kreisfreie Stadt    1296.0      NaN      NaN
# 1003     Lübeck, Hansestadt, kreisfreie Stadt        2411.0   8207.0    945.0
# 1004     Neumünster, kreisfreie Stadt                2290.0      NaN     46.0
# 1051     Dithmarschen, Landkreis                   134574.0  69089.0  89451.0
# ...                                                     ...      ...      ...
# 11008008 Berlin-Neukölln                                0.0      0.0      0.0
# 11009009 Berlin-Treptow-Köpenick                        0.0      0.0      0.0
# 11010010 Berlin-Marzahn-Hellersdorf                     0.0      0.0      0.0
# 11011011 Berlin-Lichtenberg                             0.0      0.0      0.0
# 11012012 Berlin-Reinickendorf                           0.0      0.0      0.0
#
#                                                                                \
# Tier                                                 Rinder Schweine   Schafe
# Jahr                                                   2016     2016     2016
# AGS      Name
# 1001     Flensburg, kreisfreie Stadt                  222.0      0.0      NaN
# 1002     Kiel, Landeshauptstadt, kreisfreie Stadt    1723.0      NaN      NaN
# 1003     Lübeck, Hansestadt, kreisfreie Stadt        2354.0   7586.0   1050.0
# 1004     Neumünster, kreisfreie Stadt                2243.0      NaN      NaN
# 1051     Dithmarschen, Landkreis                   132381.0  71491.0  62366.0
# ...                                                     ...      ...      ...
# 11008008 Berlin-Neukölln                                0.0      0.0      0.0
# 11009009 Berlin-Treptow-Köpenick                        0.0      0.0      0.0
# 11010010 Berlin-Marzahn-Hellersdorf                     0.0      0.0      0.0
# 11011011 Berlin-Lichtenberg                             0.0      0.0      0.0
# 11012012 Berlin-Reinickendorf                           0.0      0.0      0.0
#
#
# Tier                                                 Rinder Schweine   Schafe
# Jahr                                                   2020     2020     2020
# AGS      Name
# 1001     Flensburg, kreisfreie Stadt                  198.0      0.0      NaN
# 1002     Kiel, Landeshauptstadt, kreisfreie Stadt    1634.0     15.0      NaN
# 1003     Lübeck, Hansestadt, kreisfreie Stadt        2277.0      NaN    397.0
# 1004     Neumünster, kreisfreie Stadt                1912.0      NaN      NaN
# 1051     Dithmarschen, Landkreis                   119640.0  75966.0  62202.0
# ...                                                     ...      ...      ...
# 11008008 Berlin-Neukölln                                NaN      NaN      NaN
# 11009009 Berlin-Treptow-Köpenick                        NaN      NaN      NaN
# 11010010 Berlin-Marzahn-Hellersdorf                     NaN      NaN      NaN
# 11011011 Berlin-Lichtenberg                             NaN      NaN      NaN
# 11012012 Berlin-Reinickendorf                           NaN      NaN      NaN
#
# [489 rows x 9 columns]

# %%
#collapse levels of column names and join energy type to year
pt_df.columns = pt_df.columns.map('_'.join)

#sort columns so indicators are together
pt_df.columns=sorted(pt_df.columns)

#prepend all columns with indicator name
pt_df=pt_df.add_prefix('animalcount_')

pt_df
# Out:
#                                                    animalcount_Anzahl_Rinder_2010  \
# AGS      Name
# 1001     Flensburg, kreisfreie Stadt                                        555.0
# 1002     Kiel, Landeshauptstadt, kreisfreie Stadt                          1296.0
# 1003     Lübeck, Hansestadt, kreisfreie Stadt                              2411.0
# 1004     Neumünster, kreisfreie Stadt                                      2290.0
# 1051     Dithmarschen, Landkreis                                         134574.0
# ...                                                                           ...
# 11008008 Berlin-Neukölln                                                      0.0
# 11009009 Berlin-Treptow-Köpenick                                              0.0
# 11010010 Berlin-Marzahn-Hellersdorf                                           0.0
# 11011011 Berlin-Lichtenberg                                                   0.0
# 11012012 Berlin-Reinickendorf                                                 0.0
#
#                                                    animalcount_Anzahl_Rinder_2016  \
# AGS      Name
# 1001     Flensburg, kreisfreie Stadt                                          0.0
# 1002     Kiel, Landeshauptstadt, kreisfreie Stadt                             NaN
# 1003     Lübeck, Hansestadt, kreisfreie Stadt                              8207.0
# 1004     Neumünster, kreisfreie Stadt                                         NaN
# 1051     Dithmarschen, Landkreis                                          69089.0
# ...                                                                           ...
# 11008008 Berlin-Neukölln                                                      0.0
# 11009009 Berlin-Treptow-Köpenick                                              0.0
# 11010010 Berlin-Marzahn-Hellersdorf                                           0.0
# 11011011 Berlin-Lichtenberg                                                   0.0
# 11012012 Berlin-Reinickendorf                                                 0.0
#
#                                                    animalcount_Anzahl_Rinder_2020  \
# AGS      Name
# 1001     Flensburg, kreisfreie Stadt                                          NaN
# 1002     Kiel, Landeshauptstadt, kreisfreie Stadt                             NaN
# 1003     Lübeck, Hansestadt, kreisfreie Stadt                               945.0
# 1004     Neumünster, kreisfreie Stadt                                        46.0
# 1051     Dithmarschen, Landkreis                                          89451.0
# ...                                                                           ...
# 11008008 Berlin-Neukölln                                                      0.0
# 11009009 Berlin-Treptow-Köpenick                                              0.0
# 11010010 Berlin-Marzahn-Hellersdorf                                           0.0
# 11011011 Berlin-Lichtenberg                                                   0.0
# 11012012 Berlin-Reinickendorf                                                 0.0
#
#                                                    animalcount_Anzahl_Schafe_2010  \
# AGS      Name
# 1001     Flensburg, kreisfreie Stadt                                        222.0
# 1002     Kiel, Landeshauptstadt, kreisfreie Stadt                          1723.0
# 1003     Lübeck, Hansestadt, kreisfreie Stadt                              2354.0
# 1004     Neumünster, kreisfreie Stadt                                      2243.0
# 1051     Dithmarschen, Landkreis                                         132381.0
# ...                                                                           ...
# 11008008 Berlin-Neukölln                                                      0.0
# 11009009 Berlin-Treptow-Köpenick                                              0.0
# 11010010 Berlin-Marzahn-Hellersdorf                                           0.0
# 11011011 Berlin-Lichtenberg                                                   0.0
# 11012012 Berlin-Reinickendorf                                                 0.0
#
#                                                    animalcount_Anzahl_Schafe_2016  \
# AGS      Name
# 1001     Flensburg, kreisfreie Stadt                                          0.0
# 1002     Kiel, Landeshauptstadt, kreisfreie Stadt                             NaN
# 1003     Lübeck, Hansestadt, kreisfreie Stadt                              7586.0
# 1004     Neumünster, kreisfreie Stadt                                         NaN
# 1051     Dithmarschen, Landkreis                                          71491.0
# ...                                                                           ...
# 11008008 Berlin-Neukölln                                                      0.0
# 11009009 Berlin-Treptow-Köpenick                                              0.0
# 11010010 Berlin-Marzahn-Hellersdorf                                           0.0
# 11011011 Berlin-Lichtenberg                                                   0.0
# 11012012 Berlin-Reinickendorf                                                 0.0
#
#                                                    animalcount_Anzahl_Schafe_2020  \
# AGS      Name
# 1001     Flensburg, kreisfreie Stadt                                          NaN
# 1002     Kiel, Landeshauptstadt, kreisfreie Stadt                             NaN
# 1003     Lübeck, Hansestadt, kreisfreie Stadt                              1050.0
# 1004     Neumünster, kreisfreie Stadt                                         NaN
# 1051     Dithmarschen, Landkreis                                          62366.0
# ...                                                                           ...
# 11008008 Berlin-Neukölln                                                      0.0
# 11009009 Berlin-Treptow-Köpenick                                              0.0
# 11010010 Berlin-Marzahn-Hellersdorf                                           0.0
# 11011011 Berlin-Lichtenberg                                                   0.0
# 11012012 Berlin-Reinickendorf                                                 0.0
#
#                                                    animalcount_Anzahl_Schweine_2010  \
# AGS      Name
# 1001     Flensburg, kreisfreie Stadt                                          198.0
# 1002     Kiel, Landeshauptstadt, kreisfreie Stadt                            1634.0
# 1003     Lübeck, Hansestadt, kreisfreie Stadt                                2277.0
# 1004     Neumünster, kreisfreie Stadt                                        1912.0
# 1051     Dithmarschen, Landkreis                                           119640.0
# ...                                                                             ...
# 11008008 Berlin-Neukölln                                                        NaN
# 11009009 Berlin-Treptow-Köpenick                                                NaN
# 11010010 Berlin-Marzahn-Hellersdorf                                             NaN
# 11011011 Berlin-Lichtenberg                                                     NaN
# 11012012 Berlin-Reinickendorf                                                   NaN
#
#                                                    animalcount_Anzahl_Schweine_2016  \
# AGS      Name
# 1001     Flensburg, kreisfreie Stadt                                            0.0
# 1002     Kiel, Landeshauptstadt, kreisfreie Stadt                              15.0
# 1003     Lübeck, Hansestadt, kreisfreie Stadt                                   NaN
# 1004     Neumünster, kreisfreie Stadt                                           NaN
# 1051     Dithmarschen, Landkreis                                            75966.0
# ...                                                                             ...
# 11008008 Berlin-Neukölln                                                        NaN
# 11009009 Berlin-Treptow-Köpenick                                                NaN
# 11010010 Berlin-Marzahn-Hellersdorf                                             NaN
# 11011011 Berlin-Lichtenberg                                                     NaN
# 11012012 Berlin-Reinickendorf                                                   NaN
#
#                                                    animalcount_Anzahl_Schweine_2020
# AGS      Name
# 1001     Flensburg, kreisfreie Stadt                                            NaN
# 1002     Kiel, Landeshauptstadt, kreisfreie Stadt                               NaN
# 1003     Lübeck, Hansestadt, kreisfreie Stadt                                 397.0
# 1004     Neumünster, kreisfreie Stadt                                           NaN
# 1051     Dithmarschen, Landkreis                                            62202.0
# ...                                                                             ...
# 11008008 Berlin-Neukölln                                                        NaN
# 11009009 Berlin-Treptow-Köpenick                                                NaN
# 11010010 Berlin-Marzahn-Hellersdorf                                             NaN
# 11011011 Berlin-Lichtenberg                                                     NaN
# 11012012 Berlin-Reinickendorf                                                   NaN
#
# [489 rows x 9 columns]

# %%
#save dataframe to file
pt_df.to_csv("data/final_data_landkreis_agriculture_animalcount.csv")
