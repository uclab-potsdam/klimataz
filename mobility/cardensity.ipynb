# %%
import pandas as pd
import numpy as np


def mergeWithPopulation(df):
    df['Zeit'] =  pd.to_datetime(df['Zeit'])
    df['Jahr'] = df['Zeit'].dt.year
    df["AGS"].replace({"DG":0},inplace=True)
    df["AGS"] = pd.to_numeric(df["AGS"])

    population = pd.read_csv("../general_data/population.csv")
    population["AGS"].replace({"DG":0},inplace=True)
    population["AGS"] = pd.to_numeric(population["AGS"])

    #add population numbers
    df = pd.merge(df,population[['AGS','Jahr','BEVSTD__Bevoelkerungsstand__Anzahl']],on=['AGS','Jahr'], how='left')
    return df

def calcCarDensity(df,carcolumn,resultcolumn = "PkW_pro_Tausend_Personen"):

    #make numeric
    df[carcolumn].replace({"-":np.NaN,".":np.NaN},inplace=True)
    df[carcolumn] = pd.to_numeric(df[carcolumn])

    #name of population stays the same, because merged with same dataset
    df["BEVSTD__Bevoelkerungsstand__Anzahl"].replace({"-":np.NaN,".":np.NaN},inplace=True)
    df["BEVSTD__Bevoelkerungsstand__Anzahl"] = pd.to_numeric(df["BEVSTD__Bevoelkerungsstand__Anzahl"])
    df["Bevoelkerung_in_Tausend"] = df["BEVSTD__Bevoelkerungsstand__Anzahl"] / 1000

    #divide cars by population
    df[resultcolumn] = df[carcolumn] / df["Bevoelkerung_in_Tausend"]

    return df

def createWideFormat(df,column, values):
    #pivot table to wide format data
    orte = df["AGS"].unique()

    pivot_total = pd.DataFrame()

    for ort in orte:
            snippet = df[df["AGS"] == ort]

            temp = pd.pivot_table(snippet, index='Jahr',columns=column, values=values)
            temp = temp.reset_index(level=0)

            temp["ort_ags"] = ort
            temp["ort_name"]= str(snippet["1_Auspraegung_Label"].iloc[0])

            pivot_total = pd.concat([pivot_total, temp])
            
    return pivot_total

# %%
#car density with fueltype
#source: Regionalstatistik

df = pd.read_csv("data/car_fueltype.csv",delimiter=";",encoding="latin1")

#prepare AGS and year for merging with population
df.rename({"1_Auspraegung_Code":"AGS","2_Auspraegung_Label":"fueltype"},axis=1,inplace=True)

#drop plugin hybrid (because already included in hybrid)
df = df[df.fueltype != "  darunter Plug-In-Hybrid"]

#merge with population numbers
df = mergeWithPopulation(df)

#calc cars per person
df = calcCarDensity(df,"PKWBES__Personenkraftwagen_nach_Kraftstoffarten__Anzahl")

###IMPORTANT
#for 2021 there is not population data yet on landkreis level, so I will just use the data from 2020

#only 2020 data
df_2020 = df[df["Jahr"] == 2020]
#df_2020.to_csv("data/car_density.csv")

#pivot table to wide format data
orte = df["AGS"].unique()

pivot_total = createWideFormat(df,"fueltype","PkW_pro_Tausend_Personen")

#calc total car numbers
pivot_total["Gesamt"] = pivot_total.iloc[:, -8:-2].sum(axis=1)

pivot_total.to_csv("data/car_density_wideformat.csv")
pivot_total
# Out:
# fueltype  Jahr      Benzin      Diesel   Elektro  Gas (einschl. bivalent)  \
# 0         2020  378.385765  181.725409  1.642919                 5.455713
# 0         2020  368.892859  199.421823  1.692618                 4.415511
# 0         2020  301.810216  182.867436  1.601174                 3.146752
# 0         2020  296.551920  143.843699  1.427407                 3.057571
# 0         2020  312.000222  139.965531  1.436209                 3.914828
# ..         ...         ...         ...       ...                      ...
# 0         2020  406.250306  175.300326  0.567854                 3.886860
# 0         2020  403.786708  181.631569  0.712423                 4.902434
# 0         2020  421.652100  203.988346  0.602773                 4.319871
# 0         2020  426.045848  187.611205  0.486200                 4.499938
# 0         2020  429.172891  144.200733  0.633800                 4.481869
#
# fueltype    Hybrid  sonstige Kraftstoffarten  ort_ags  \
# 0         7.715204                  0.123204        0
# 0         6.144544                  0.106154        1
# 0         7.138568                  0.166789     1001
# 0         6.719356                  0.072992     1002
# 0         5.225948                  0.074127     1003
# ..             ...                       ...      ...
# 0         5.257541                  0.166440    16073
# 0         7.100077                  0.217349    16074
# 0         3.541290                  0.226040    16075
# 0         5.430960                  0.186204    16076
# 0         3.644348                  0.203721    16077
#
# fueltype                                        ort_name      Gesamt
# 0                                            Deutschland  575.048213
# 0                                     Schleswig-Holstein  580.673509
# 0                            Flensburg, kreisfreie Stadt  496.730936
# 0               Kiel, Landeshauptstadt, kreisfreie Stadt  451.672945
# 0                   Lübeck, Hansestadt, kreisfreie Stadt  462.616866
# ..                                                   ...         ...
# 0                             Saalfeld-Rudolstadt, Kreis  591.429327
# 0                                   Saale-Holzland-Kreis  598.350560
# 0                                       Saale-Orla-Kreis  634.330420
# 0                                           Greiz, Kreis  624.260355
# 0                                Altenburger Land, Kreis  582.337362
#
# [448 rows x 10 columns]

# %%
#car density total
#source: Regionalstatistik

df2 = pd.read_csv("data/car_total.csv",delimiter=";",encoding="latin1")

#prepare AGS and year for merging with population
df2.rename({"1_Auspraegung_Code":"AGS","2_Auspraegung_Label":"cartype"},axis=1,inplace=True)

df2 = mergeWithPopulation(df2)
df2 = calcCarDensity(df2,"VER012__Kraftfahrzeugbestand__Anzahl","Fahrzeug_pro_Tausend_Personen")

pivot2 = createWideFormat(df2,"cartype","Fahrzeug_pro_Tausend_Personen")
pivot2.to_csv("data/car_density_total_wideformat.csv")
pivot2

melt = pd.melt(pivot2,id_vars=["ort_name","Jahr"],value_vars=['Insgesamt','Krafträder','Lkw','Pkw','Zugmaschinen'])
#melt['Jahr'] = melt["Jahr"].str.replace("year_", '')

#melt.to_csv("data/car_density_total_longformat.csv")
#melt
pivot2
# Out:
# /var/folders/6w/mz49x3ds0b18vg8p9jx7wg0r0000gn/T/ipykernel_17598/2925681770.py:4: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv("data/car_total.csv",delimiter=";",encoding="latin1")
# cartype  Jahr   Insgesamt  Krafträder        Lkw         Pkw  Zugmaschinen  \
# 0        1996  581.119334   28.096479  27.451124  493.822392     23.188756
# 1        1997  590.903287   30.883341  27.990158  500.201414     23.158941
# 2        1998  597.791697   33.633149  28.579320  503.758919     23.154378
# 3        1999  605.661153   36.599596  29.390334  507.728501     23.187177
# 4        2000  616.663672   38.640406  30.283029  515.724425     23.234448
# ..        ...         ...         ...        ...         ...           ...
# 20       2016  670.778434   45.542371  46.655823  556.791512     16.516205
# 21       2017  683.022614   47.093216  48.659680  565.151682     16.756757
# 22       2018  689.651346   48.691715  50.223041  567.600257     17.632437
# 23       2019  699.327688   50.339512  50.876467  574.206034     18.334769
# 24       2020  712.187061   52.616687  52.786455  581.952556     19.138485
#
# cartype  ort_ags                       ort_name
# 0              0                    Deutschland
# 1              0                    Deutschland
# 2              0                    Deutschland
# 3              0                    Deutschland
# 4              0                    Deutschland
# ..           ...                            ...
# 20         16077        Altenburger Land, Kreis
# 21         16077        Altenburger Land, Kreis
# 22         16077        Altenburger Land, Kreis
# 23         16077        Altenburger Land, Kreis
# 24         16077        Altenburger Land, Kreis
#
# [11801 rows x 8 columns]

# %%
melt
# Out:
#                             ort_name  Jahr       cartype       value
# 0                        Deutschland  1996     Insgesamt  581.119334
# 1                        Deutschland  1997     Insgesamt  590.903287
# 2                        Deutschland  1998     Insgesamt  597.791697
# 3                        Deutschland  1999     Insgesamt  605.661153
# 4                        Deutschland  2000     Insgesamt  616.663672
# ...                              ...   ...           ...         ...
# 59000        Altenburger Land, Kreis  2016  Zugmaschinen   16.516205
# 59001        Altenburger Land, Kreis  2017  Zugmaschinen   16.756757
# 59002        Altenburger Land, Kreis  2018  Zugmaschinen   17.632437
# 59003        Altenburger Land, Kreis  2019  Zugmaschinen   18.334769
# 59004        Altenburger Land, Kreis  2020  Zugmaschinen   19.138485
#
# [59005 rows x 4 columns]

# %%
from dtaidistance import dtw


def get_most_different_cities:

    pkw = pivot2.copy()
    pkw = pkw[['Jahr','Pkw','ort_ags','ort_name']]

    deutschland = pkw[pkw["ort_ags"] == 0].Pkw

    orte = pkw.ort_ags.unique()

    distances = []

    for ags in orte:
        ort = pkw[pkw["ort_ags"] == ags].Pkw
        distance = dtw.distance(deutschland, ort)

        distances.append([distance,ags,pkw[pkw["ort_ags"] == ags].ort_name.iloc[0]])


    return sorted(distances, key=lambda x: x[0], reverse=True)

##this is not really helpful, because it kind of only reflects if a time series is in general a lot higher / lower 
# than the German average. I will now try to look at the gradient / derivative of the data

# %%
#comment this line out if you want to look at the total development
#deutschland = pkw[pkw["ort_ags"] == 0 && pkw["Jahr"] > 2009].Pkw

def get_most_different_cities_by_slope(use_recent_years = False):

    pkw = pivot2.copy()
    pkw = pkw[['Jahr','Pkw','ort_ags','ort_name']]

    
    if(use_recent_years):
         deutschland = pkw[(pkw["ort_ags"] == 0) & (pkw["Jahr"] > 2009)].Pkw
    else: 
        deutschland = pkw[pkw["ort_ags"] == 0].Pkw
    

    deutschland_slope = pd.Series(np.gradient(deutschland), name='slope')
    deutschland_slope

    orte = pkw.ort_ags.unique()

    distances_slope = []

    for ags in orte:
        if(use_recent_years):
            ort = pkw[(pkw["ort_ags"] == ags) & (pkw["Jahr"] > 2009)].Pkw
        else: 
            ort = pkw[pkw["ort_ags"] == ags].Pkw

        #skip places we only have old data of
        if ((use_recent_years and ort.size == (2021-2010)) or not use_recent_years):
            ort_slope = pd.Series(np.gradient(ort), name='slope')
            distance = dtw.distance(deutschland_slope, ort_slope)

            distances_slope.append([distance,ags,pkw[pkw["ort_ags"] == ags].ort_name.iloc[0]])

    return sorted(distances_slope, key=lambda x: x[0], reverse=True)

def get_total_difference():
    orte = pkw.ort_ags.unique()

    differences = []

    for ags in orte:
        ort_1996 = pkw[(pkw["ort_ags"] == ags) & (pkw["Jahr"] == 1996)].Pkw
        ort_2020 = pkw[(pkw["ort_ags"] == ags) & (pkw["Jahr"] == 2020)].Pkw

        if(ort_1996.size > 0 and ort_2020.size > 0):
            diff = ort_2020.iloc[0] - ort_1996.iloc[0]
            differences.append([diff,ags,pkw[pkw["ort_ags"] == ags].ort_name.iloc[0]])

    return sorted(differences, key=lambda x: x[0], reverse=True)

# %%
get_total_difference()
# Out:
# [[558.0338251662442, 3103, '      Wolfsburg, kreisfreie Stadt'],
#  [210.19831210253028, 6436, '      Main-Taunus-Kreis'],
#  [182.24070297878154, 9161, '      Ingolstadt'],
#  [176.52058462600735, 9279, '      Dingolfing-Landau, Landkreis'],
#  [172.1216726995172, 5966, '      Olpe, Kreis'],
#  [171.35337326415674, 10046, '      St. Wendel, Landkreis'],
#  [169.51757913442293, 9374, '      Neustadt a.d.Waldnaab, Landkreis'],
#  [168.05852654376025, 9371, '      Amberg-Sulzbach, Landkreis'],
#  [167.1781077850087, 9674, '      Haßberge, Landkreis'],
#  [164.10597989055475, 10044, '      Saarlouis, Landkreis'],
#  [162.77055445690985, 9372, '      Cham, Landkreis'],
#  [162.76933708699607, 9673, '      Rhön-Grabfeld, Landkreis'],
#  [162.0508623322155, 9377, '      Tirschenreuth, Landkreis'],
#  [158.46232434120952, 7340, '      Südwestpfalz, Landkreis'],
#  [158.35041674507374, 9473, '      Coburg, Landkreis'],
#  [154.00427401816103, 9272, '      Freyung-Grafenau, Landkreis'],
#  [153.9241181000831, 9571, '      Ansbach, Landkreis'],
#  [153.25559140491146, 9678, '      Schweinfurt, Landkreis'],
#  [152.7576069716033, 9278, '      Straubing-Bogen, Landkreis'],
#  [151.26079466658257, 9677, '      Main-Spessart, Landkreis'],
#  [150.8464222096161, 9471, '      Bamberg, Landkreis'],
#  [150.777379618101, 8125, '      Heilbronn, Landkreis'],
#  [149.4991366009233, 8126, '      Hohenlohekreis, Landkreis'],
#  [148.44843275069434, 9476, '      Kronach, Landkreis'],
#  [148.43609490361376, 9276, '      Regen, Landkreis'],
#  [145.65104452120727, 9672, '      Bad Kissingen, Landkreis'],
#  [145.55440307218862, 9779, '      Donau-Ries, Landkreis'],
#  [145.53451867382893, 16065, '      Kyffhäuserkreis'],
#  [145.19724292801686, 5762, '      Höxter, Kreis'],
#  [145.0168031197337, 7233, '      Vulkaneifel, Landkreis'],
#  [144.94585229572004, 9373, '      Neumarkt i.d.OPf., Landkreis'],
#  [144.61380730266717, 9176, '      Eichstätt, Landkreis'],
#  [144.15429380153205, 9478, '      Lichtenfels, Landkreis'],
#  [143.73750086128655, 9773, '      Dillingen a.d.Donau, Landkreis'],
#  [143.71323030566833, 5958, '      Hochsauerlandkreis'],
#  [142.8964036454115, 9675, '      Kitzingen, Landkreis'],
#  [141.34241998506297, 6535, '      Vogelsbergkreis'],
#  [141.2882564101808, 5366, '      Euskirchen, Kreis'],
#  [141.13264043323238, 8128, '      Main-Tauber-Kreis, Landkreis'],
#  [140.96019029385843, 10045, '      Saarpfalz-Kreis'],
#  [140.59404807006769, 12062, '      Elbe-Elster, Landkreis'],
#  [140.25944599178547, 9778, '      Unterallgäu, Landkreis'],
#  [139.81886743563382, 7140, '      Rhein-Hunsrück-Kreis'],
#  [139.8080018180617, 8235, '      Calw, Landkreis'],
#  [139.64573539765826, 16061, '      Eichsfeld, Kreis'],
#  [139.26033315383847, 5558, '      Coesfeld, Kreis'],
#  [138.54428472638108, 8237, '      Freudenstadt, Landkreis'],
#  [138.492495332222, 7337, '      Südliche Weinstraße, Landkreis'],
#  [138.47599166696978, 7336, '      Kusel, Landkreis'],
#  [138.41198194404694, 9185, '      Neuburg-Schrobenhausen, Landkreis'],
#  [138.22777340720836, 8325, '      Rottweil, Landkreis'],
#  [137.42023323349156, 9474, '      Forchheim, Landkreis'],
#  [136.41110395018984, 9774, '      Günzburg, Landkreis'],
#  [136.37848990500686, 8136, '      Ostalbkreis, Landkreis'],
#  [135.81770835231794, 9472, '      Bayreuth, Landkreis'],
#  [135.7778971763529, 3455, '      Friesland, Landkreis'],
#  [135.43672552287876, 8225, '      Neckar-Odenwald-Kreis, Landkreis'],
#  [134.52632470692942, 12071, '      Spree-Neiße, Landkreis'],
#  [134.25337373540106, 6635, '      Waldeck-Frankenberg, Landkreis'],
#  [133.98506935682735, 9376, '      Schwandorf, Landkreis'],
#  [133.57764143370957, 12066, '      Oberspreewald-Lausitz, Landkreis'],
#  [133.3803230736305, 16068, '      Sömmerda, Kreis'],
#  [133.3727629362848, 5370, '      Heinsberg, Kreis'],
#  [132.75114213324548,
#   9575,
#   '      Neustadt a.d.Aisch-Bad Windsheim, Landkreis'],
#  [132.6520404249526, 93, '    Oberpfalz, Regierungsbezirk'],
#  [132.59838254622912, 7132, '      Altenkirchen (Westerwald), Landkreis'],
#  [132.52882643029363, 3155, '      Northeim, Landkreis'],
#  [132.45024588255058, 9671, '      Aschaffenburg, Landkreis'],
#  [132.15498319129227, 15081, '      Altmarkkreis Salzwedel'],
#  [131.87579290332815, 9676, '      Miltenberg, Landkreis'],
#  [131.81494163973082, 9275, '      Passau, Landkreis'],
#  [131.7595549648321, 9271, '      Deggendorf, Landkreis'],
#  [131.64493387717692, 16076, '      Greiz, Kreis'],
#  [131.29129260483035, 9181, '      Landsberg am Lech, Landkreis'],
#  [131.17636693375607, 5374, '      Oberbergischer Kreis'],
#  [130.92455887198003, 9479, '      Wunsiedel i.Fichtelgebirge, Landkreis'],
#  [130.61194201487774, 9477, '      Kulmbach, Landkreis'],
#  [130.23798728176433, 5978, '      Unna, Kreis'],
#  [130.07574930860721, 9679, '      Würzburg, Landkreis'],
#  [129.75372669070407, 8437, '      Sigmaringen, Landkreis'],
#  [129.70693924211014, 7135, '      Cochem-Zell, Landkreis'],
#  [129.58015835324647, 9475, '      Hof, Landkreis'],
#  [129.40214321520432, 8127, '      Schwäbisch Hall, Landkreis'],
#  [129.15058457019938, 3357, '      Rotenburg (Wümme), Landkreis'],
#  [128.982199796882, 5974, '      Soest, Kreis'],
#  [128.9783745692149, 5154, '      Kleve, Kreis'],
#  [128.96703100079895, 5554, '      Borken, Kreis'],
#  [128.93321687702178, 10042, '      Merzig-Wadern, Landkreis'],
#  [128.65238089375453, 16069, '      Hildburghausen, Kreis'],
#  [128.22582397373696, 7235, '      Trier-Saarburg, Landkreis'],
#  [128.1289315360205, 3452, '      Aurich, Landkreis'],
#  [128.05241240340416, 5970, '      Siegen-Wittgenstein, Kreis'],
#  [127.78423223526158, 7335, '      Kaiserslautern, Landkreis'],
#  [127.78416579971861, 6434, '      Hochtaunuskreis'],
#  [127.43428287527036, 9576, '      Roth, Landkreis'],
#  [127.14669390311417, 16072, '      Sonneberg, Kreis'],
#  [126.88996608406433, 9577, '      Weißenburg-Gunzenhausen, Landkreis'],
#  [126.62010197358052, 96, '    Unterfranken, Regierungsbezirk'],
#  [126.55908621131846, 9274, '      Landshut, Landkreis'],
#  [126.11375457957752, 3462, '      Wittmund, Landkreis'],
#  [125.99298831064232, 31, '    Braunschweig, Stat. Region'],
#  [125.9371274800186, 7137, '      Mayen-Koblenz, Landkreis'],
#  [125.55757097457172, 9277, '      Rottal-Inn, Landkreis'],
#  [125.4342547556962, 12070, '      Prignitz, Landkreis'],
#  [124.89678625635906, 7143, '      Westerwaldkreis'],
#  [124.86418517435663, 92, '    Niederbayern, Regierungsbezirk'],
#  [124.76646083349806, 9187, '      Rosenheim, Landkreis'],
#  [124.67960307605972, 8426, '      Biberach, Landkreis'],
#  [124.19286225295309, 7231, '      Bernkastel-Wittlich, Landkreis'],
#  [123.89495777837044, 9273, '      Kelheim, Landkreis'],
#  [123.71374462900519, 9772, '      Augsburg, Landkreis'],
#  [123.51960289434834, 12067, '      Oder-Spree, Landkreis'],
#  [123.48691539562515, 7138, '      Neuwied, Landkreis'],
#  [123.45576883485967, 9572, '      Erlangen-Höchstadt, Landkreis'],
#  [123.23623667677919, 5170, '      Wesel, Kreis'],
#  [123.13684419156988, 16073, '      Saalfeld-Rudolstadt, Kreis'],
#  [123.10265034135682, 7131, '      Ahrweiler, Landkreis'],
#  [123.05849877105999, 3456, '      Grafschaft Bentheim, Landkreis'],
#  [123.01079861096298, 1057, '      Plön, Landkreis'],
#  [122.7783417663843, 3454, '      Emsland, Landkreis'],
#  [121.98885843183791, 94, '    Oberfranken, Regierungsbezirk'],
#  [121.76164284692567, 16071, '      Weimarer Land, Kreis'],
#  [121.38395769502085, 8236, '      Enzkreis, Landkreis'],
#  [121.24796941553325, 9184, '      München, Landkreis'],
#  [121.09546956860879, 16066, '      Schmalkalden-Meiningen, Kreis'],
#  [120.92591000873193, 5962, '      Märkischer Kreis'],
#  [120.48699232798424, 8135, '      Heidenheim, Landkreis'],
#  [120.18267604516666, 6631, '      Fulda, Landkreis'],
#  [119.99803499292511, 6632, '      Hersfeld-Rotenburg, Landkreis'],
#  [119.88013832357944, 3459, '      Osnabrück, Landkreis'],
#  [119.85810472193015, 3457, '      Leer, Landkreis'],
#  [119.73110451555942, 7332, '      Bad Dürkheim, Landkreis'],
#  [119.71175998750084, 9777, '      Ostallgäu, Landkreis'],
#  [119.09989803927749, 7333, '      Donnersbergkreis'],
#  [119.07449406524529, 12073, '      Uckermark, Landkreis'],
#  [118.71772137951007, 8425, '      Alb-Donau-Kreis, Landkreis'],
#  [118.49683465377268, 10, '  Saarland'],
#  [117.79149590370042, 16064, '      Unstrut-Hainich-Kreis'],
#  [117.69953830842451, 9190, '      Weilheim-Schongau, Landkreis'],
#  [117.54205056473148, 5122, '      Solingen, kreisfreie Stadt'],
#  [117.54062311763471, 9189, '      Traunstein, Landkreis'],
#  [117.4068085615985, 5166, '      Viersen, Kreis'],
#  [117.29633820348931, 7141, '      Rhein-Lahn-Kreis'],
#  [117.22200228276091, 3461, '      Wesermarsch, Landkreis'],
#  [117.2156495602502, 71, '    Koblenz, Stat. Region'],
#  [117.03215823600442, 15090, '      Stendal, Landkreis'],
#  [116.61729501420473, 9574, '      Nürnberger Land, Landkreis'],
#  [116.43017413511268, 9171, '      Altötting, Landkreis'],
#  [116.23748358799003, 3255, '      Holzminden, Landkreis'],
#  [116.18200469262922, 12068, '      Ostprignitz-Ruppin, Landkreis'],
#  [115.74485532013716, 6634, '      Schwalm-Eder-Kreis'],
#  [115.6215776106427, 7232, '      Eifelkreis Bitburg-Prüm'],
#  [115.32441771716799, 5570, '      Warendorf, Kreis'],
#  [115.30990608464163, 16077, '      Altenburger Land, Kreis'],
#  [115.0589031015196, 9463, '      Coburg'],
#  [114.51588904610935, 8117, '      Göppingen, Landkreis'],
#  [113.71769344959569, 1055, '      Ostholstein, Landkreis'],
#  [113.57935583868317, 12072, '      Teltow-Fläming, Landkreis'],
#  [113.49757192298159, 1059, '      Schleswig-Flensburg, Landkreis'],
#  [113.29077896397007, 16075, '      Saale-Orla-Kreis'],
#  [113.16930537558005, 9186, '      Pfaffenhofen a.d.Ilm, Landkreis'],
#  [112.82480659496639, 7134, '      Birkenfeld, Landkreis'],
#  [112.7895104322954, 8327, '      Tuttlingen, Landkreis'],
#  [112.67528408307624, 10043, '      Neunkirchen, Landkreis'],
#  [112.6027502200966, 9771, '      Aichach-Friedberg, Landkreis'],
#  [112.5538286008101, 9780, '      Oberallgäu, Landkreis'],
#  [112.499649189043, 9183, '      Mühldorf a.Inn, Landkreis'],
#  [112.42761081247909, 9776, '      Lindau (Bodensee), Landkreis'],
#  [112.32748029994491, 8417, '      Zollernalbkreis, Landkreis'],
#  [112.25269286449759, 7339, '      Mainz-Bingen, Landkreis'],
#  [112.14346316920864, 8436, '      Ravensburg, Landkreis'],
#  [111.94291391387424, 1058, '      Rendsburg-Eckernförde, Landkreis'],
#  [111.32854535313743, 9573, '      Fürth, Landkreis'],
#  [111.1683534076484, 6532, '      Lahn-Dill-Kreis'],
#  [110.14892632908976, 15, '  Sachsen-Anhalt'],
#  [110.00135794281789, 3352, '      Cuxhaven, Landkreis'],
#  [109.97785937386243, 9177, '      Erding, Landkreis'],
#  [109.50456569457953, 5566, '      Steinfurt, Kreis'],
#  [109.20679779769068, 9375, '      Regensburg, Landkreis'],
#  [107.97644456120884, 5911, '      Bochum, kreisfreie Stadt'],
#  [107.66446235927606, 16074, '      Saale-Holzland-Kreis'],
#  [107.5385029418104, 7331, '      Alzey-Worms, Landkreis'],
#  [107.35284416049325, 3460, '      Vechta, Landkreis'],
#  [106.64852964351024, 5358, '      Düren, Kreis'],
#  [106.58562491553158, 12063, '      Havelland, Landkreis'],
#  [105.54320500977747, 72, '    Trier, Stat. Region'],
#  [105.1296499769083, 9561, '      Ansbach'],
#  [104.93150211102625, 1061, '      Steinburg, Landkreis'],
#  [104.9213014220229, 5770, '      Minden-Lübbecke, Kreis'],
#  [104.85062209643127, 7334, '      Germersheim, Landkreis'],
#  [104.17986697248, 7133, '      Bad Kreuznach, Landkreis'],
#  [103.79725217228054, 16070, '      Ilm-Kreis'],
#  [103.67282528869345, 34, '    Weser-Ems, Stat. Region'],
#  [103.2830058912923, 59, '    Arnsberg, Regierungsbezirk'],
#  [103.1621561731223, 84, '    Tübingen, Regierungsbezirk'],
#  [103.12777505095107, 5954, '      Ennepe-Ruhr-Kreis'],
#  [103.08551906793889, 8317, '      Ortenaukreis, Landkreis'],
#  [102.96029998287327, 6636, '      Werra-Meißner-Kreis'],
#  [102.91237508596367, 5562, '      Recklinghausen, Kreis'],
#  [102.89699190419356, 7338, '      Rhein-Pfalz-Kreis'],
#  [102.30100889123412, 7320, '      Zweibrücken, kreisfreie Stadt'],
#  [102.04545643206961, 12065, '      Oberhavel, Landkreis'],
#  [101.66373442843366, 3154, '      Helmstedt, Landkreis'],
#  [101.4685095098024, 16067, '      Gotha, Kreis'],
#  [101.43084812038262, 8415, '      Reutlingen, Landkreis'],
#  [100.17483641435308, 5382, '      Rhein-Sieg-Kreis'],
#  [100.16345774996205, 3451, '      Ammerland, Landkreis'],
#  [99.40387660164504, 97, '    Schwaben, Regierungsbezirk'],
#  [99.22295078801096, 3158, '      Wolfenbüttel, Landkreis'],
#  [98.9427112624985, 3252, '      Hameln-Pyrmont, Landkreis'],
#  [98.80238533405651, 5774, '      Paderborn, Kreis'],
#  [98.19993073230114, 6437, '      Odenwaldkreis'],
#  [97.62308477839917, 3256, '      Nienburg (Weser), Landkreis'],
#  [97.21093574108227, 6533, '      Limburg-Weilburg, Landkreis'],
#  [97.20395387097608, 7, '  Rheinland-Pfalz'],
#  [96.91878582907452, 8226, '      Rhein-Neckar-Kreis, Landkreis'],
#  [96.5321738616293, 8216, '      Rastatt, Landkreis'],
#  [96.44028154048164, 16062, '      Nordhausen, Kreis'],
#  [96.11923644299998, 66, '    Kassel, Regierungsbezirk'],
#  [96.04167206682041, 5512, '      Bottrop, kreisfreie Stadt'],
#  [95.92961557927197, 9565, '      Schwabach'],
#  [95.74176133638491, 9362, '      Regensburg'],
#  [95.36622376955495, 8435, '      Bodenseekreis, Landkreis'],
#  [95.3599314861516, 8337, '      Waldshut, Landkreis'],
#  [95.31905400692824, 12064, '      Märkisch-Oderland, Landkreis'],
#  [94.83276042972932, 13, '  Mecklenburg-Vorpommern'],
#  [94.8019706830006, 1051, '      Dithmarschen, Landkreis'],
#  [94.6922372102432, 3358, '      Heidekreis, Landkreis'],
#  [94.6506514951875, 6633, '      Kassel, Landkreis'],
#  [94.62972064026837, 5766, '      Lippe, Kreis'],
#  [94.57469818855344, 55, '    Münster, Regierungsbezirk'],
#  [94.53068994748457, 3351, '      Celle, Landkreis'],
#  [94.23567622943972, 8336, '      Lörrach, Landkreis'],
#  [94.03123012858885, 8115, '      Böblingen, Landkreis'],
#  [93.73915445917487, 5158, '      Mettmann, Kreis'],
#  [93.63865237870505, 6534, '      Marburg-Biedenkopf, Landkreis'],
#  [93.21233458081042, 3, '  Niedersachsen'],
#  [93.18249175306926, 9, '  Bayern'],
#  [92.37757641378562, 9775, '      Neu-Ulm, Landkreis'],
#  [92.31980625257665, 3354, '      Lüchow-Dannenberg, Landkreis'],
#  [92.1819809379378, 12, '  Brandenburg'],
#  [92.05547202871799, 9182, '      Miesbach, Landkreis'],
#  [92.0175014433778, 65, '    Gießen, Regierungsbezirk'],
#  [92.01122484415703, 5758, '      Herford, Kreis'],
#  [91.9166921907235, 12061, '      Dahme-Spreewald, Landkreis'],
#  [91.83121976138239, 3251, '      Diepholz, Landkreis'],
#  [91.83099036806038, 3151, '      Gifhorn, Landkreis'],
#  [91.7406809796413, 3360, '      Uelzen, Landkreis'],
#  [91.55735370994887, 9172, '      Berchtesgadener Land, Landkreis'],
#  [91.32755720430487, 33, '    Lüneburg, Stat. Region'],
#  [90.7998924598723, 16, '  Thüringen'],
#  [90.74557021205248, 1054, '      Nordfriesland, Landkreis'],
#  [90.29881486008287, 8326, '      Schwarzwald-Baar-Kreis, Landkreis'],
#  [90.28210774492584, 3453, '      Cloppenburg, Landkreis'],
#  [90.14440928219716, 9174, '      Dachau, Landkreis'],
#  [89.8651346098527, 8119, '      Rems-Murr-Kreis, Landkreis'],
#  [89.8018531562098, 3153, '      Goslar, Landkreis'],
#  [88.64382088184118, 3359, '      Stade, Landkreis'],
#  [88.09649709040264, 81, '    Stuttgart, Regierungsbezirk'],
#  [87.59448397793699, 3254, '      Hildesheim, Landkreis'],
#  [87.40066378023994, 57, '    Detmold, Regierungsbezirk'],
#  [87.04100071674213, 3157, '      Peine, Landkreis'],
#  [86.40404182102839, 6439, '      Rheingau-Taunus-Kreis'],
#  [85.6100313471926, 3356, '      Osterholz, Landkreis'],
#  [85.46426157723829, 8316, '      Emmendingen, Landkreis'],
#  [85.0326097265455, 6432, '      Darmstadt-Dieburg, Landkreis'],
#  [84.57064665189398, 8, '  Baden-Württemberg, Land'],
#  [84.487065450991, 16054, '      Suhl, kreisfreie Stadt'],
#  [84.48175294356224, 3361, '      Verden, Landkreis'],
#  [83.61607300791434, 8215, '      Karlsruhe, Landkreis'],
#  [83.24302183584257, 5754, '      Gütersloh, Kreis'],
#  [83.18394337905977, 6431, '      Bergstraße, Landkreis'],
#  [82.51565265377837, 3458, '      Oldenburg, Landkreis'],
#  [82.28144778209946, 9661, '      Aschaffenburg'],
#  [82.06958751248305, 5362, '      Rhein-Erft-Kreis'],
#  [81.98763804418593, 6440, '      Wetteraukreis'],
#  [81.71327791081455, 5378, '      Rheinisch-Bergischer Kreis'],
#  [81.03411255653953, 5, '  Nordrhein-Westfalen'],
#  [80.97205735605462, 3402, '      Emden, kreisfreie Stadt'],
#  [80.73858460338329, 5162, '      Rhein-Kreis Neuss'],
#  [80.7325975880774, 83, '    Freiburg, Regierungsbezirk'],
#  [80.59867926637833, 73, '    Rheinhessen-Pfalz, Stat. Region'],
#  [80.50527678508718, 3405, '      Wilhelmshaven, kreisfreie Stadt'],
#  [79.9970923809002, 0, 'Deutschland'],
#  [79.70843509323345, 9363, '      Weiden i.d.OPf.'],
#  [79.61532469684641, 9173, '      Bad Tölz-Wolfratshausen, Landkreis'],
#  [79.22693270804626, 8416, '      Tübingen, Landkreis'],
#  [78.97673471996359, 6435, '      Main-Kinzig-Kreis'],
#  [78.14901393065719, 5915, '      Hamm, kreisfreie Stadt'],
#  [78.06755125922757, 9180, '      Garmisch-Partenkirchen, Landkreis'],
#  [77.92547719731266, 3101, '      Braunschweig, kreisfreie Stadt'],
#  [77.86679012855416, 8118, '      Ludwigsburg, Landkreis'],
#  [77.02546816471579, 5114, '      Krefeld, kreisfreie Stadt'],
#  [76.20390699471193, 9178, '      Freising, Landkreis'],
#  [75.78086320050403, 9263, '      Straubing'],
#  [75.17513395980768, 5119, '      Oberhausen, kreisfreie Stadt'],
#  [74.92167814224211, 95, '    Mittelfranken, Regierungsbezirk'],
#  [74.34739937079428, 8315, '      Breisgau-Hochschwarzwald, Landkreis'],
#  [72.68622255422713, 9762, '      Kaufbeuren'],
#  [72.52760581096118, 12069, '      Potsdam-Mittelmark, Landkreis'],
#  [71.11944076564362, 9464, '      Hof'],
#  [70.83124463258685, 8116, '      Esslingen, Landkreis'],
#  [70.39108154541537, 14, '  Sachsen'],
#  [70.37437671213445, 3353, '      Harburg, Landkreis'],
#  [70.16976563242974, 82, '    Karlsruhe, Regierungsbezirk'],
#  [69.69121639648222, 1, '  Schleswig-Holstein'],
#  [69.38704339086587,
#   7316,
#   '      Neustadt an der Weinstraße, kreisfreie Stadt'],
#  [69.32809971316226, 9175, '      Ebersberg, Landkreis'],
#  [69.2720655282136, 9361, '      Amberg'],
#  [69.15409057108627, 9188, '      Starnberg, Landkreis'],
#  [68.82947956139418, 12060, '      Barnim, Landkreis'],
#  [68.78751924035907, 9764, '      Memmingen'],
#  [68.3749833742001, 51, '    Düsseldorf, Regierungsbezirk'],
#  [67.70655554944551, 3355, '      Lüneburg, Landkreis'],
#  [66.64643579672008, 10041, '      Saarbrücken, Regionalverband'],
#  [66.03184255288727, 53, '    Köln, Regierungsbezirk'],
#  [65.88507093609496, 5916, '      Herne, kreisfreie Stadt'],
#  [65.1747787892615, 8211, '      Baden-Baden, Stadtkreis'],
#  [63.97381294100586, 5120, '      Remscheid, kreisfreie Stadt'],
#  [63.897551673976636, 6, '  Hessen'],
#  [63.393604408996225, 91, '    Oberbayern, Regierungsbezirk'],
#  [60.979353248632094, 9662, '      Schweinfurt'],
#  [60.77667079498781, 3404, '      Osnabrück, kreisfreie Stadt'],
#  [60.253470335819884, 1062, '      Stormarn, Landkreis'],
#  [60.23919154904337, 5316, '      Leverkusen, kreisfreie Stadt'],
#  [58.575583309584204, 5914, '      Hagen, kreisfreie Stadt'],
#  [58.46274258772337, 8335, '      Konstanz, Landkreis'],
#  [57.901624190625455, 32, '    Hannover, Stat. Region'],
#  [57.44312777067273, 1053, '      Herzogtum Lauenburg, Landkreis'],
#  [53.95639209136789, 5116, '      Mönchengladbach, kreisfreie Stadt'],
#  [53.31552903849138, 7318, '      Speyer, kreisfreie Stadt'],
#  [52.778945590386286, 4012, '      Bremerhaven, kreisfreie Stadt'],
#  [52.06095254451458, 8421, '      Ulm, Stadtkreis'],
#  [50.886912823035004, 6531, '      Gießen, Landkreis'],
#  [50.75643462476819, 5117, '      Mülheim an der Ruhr, kreisfreie Stadt'],
#  [50.69951909864534, 1001, '      Flensburg, kreisfreie Stadt'],
#  [50.379372108603036, 3102, '      Salzgitter, kreisfreie Stadt'],
#  [50.3476799365846, 5513, '      Gelsenkirchen, kreisfreie Stadt'],
#  [49.94993639968959, 9763, '      Kempten (Allgäu)'],
#  [49.87843047889129, 7311, '      Frankenthal (Pfalz), kreisfreie Stadt'],
#  [49.752949605449885, 7319, '      Worms, kreisfreie Stadt'],
#  [48.75866026025142, 3403, '      Oldenburg (Oldenburg), kreisfreie Stadt'],
#  [47.55360197062123,
#   12051,
#   '      Brandenburg an der Havel, kreisfreie Stadt'],
#  [47.15859163532923, 1056, '      Pinneberg, Landkreis'],
#  [47.12149885656072, 7111, '      Koblenz, kreisfreie Stadt'],
#  [45.98392416136011, 5314, '      Bonn, kreisfreie Stadt'],
#  [45.81281835189429, 64, '    Darmstadt, Regierungsbezirk'],
#  [45.73726671771067, 3257, '      Schaumburg, Landkreis'],
#  [45.20519755181135, 7317, '      Pirmasens, kreisfreie Stadt'],
#  [44.60707505568581, 5913, '      Dortmund, kreisfreie Stadt'],
#  [44.44291941198543, 9163, '      Rosenheim'],
#  [43.208909247026895, 7313, '      Landau in der Pfalz, kreisfreie Stadt'],
#  [41.198741042275174, 12052, '      Cottbus, kreisfreie Stadt'],
#  [39.578937025010646, 9461, '      Bamberg'],
#  [38.752508836039, 1004, '      Neumünster, kreisfreie Stadt'],
#  [37.32413629003497, 9179, '      Fürstenfeldbruck, Landkreis'],
#  [36.69970459597096, 5124, '      Wuppertal, kreisfreie Stadt'],
#  [35.8091842584858, 8231, '      Pforzheim, Stadtkreis'],
#  [34.763531770990085, 16052, '      Gera, kreisfreie Stadt'],
#  [34.71762754235931, 9663, '      Würzburg'],
#  [34.5401019869783, 9262, '      Passau'],
#  [34.53803643771869, 3241, '      Region Hannover, Landkreis'],
#  [33.916381250298514, 5112, '      Duisburg, kreisfreie Stadt'],
#  [33.90859313330094, 5113, '      Essen, kreisfreie Stadt'],
#  [33.897964191749, 6438, '      Offenbach, Landkreis'],
#  [33.60637678704717, 9462, '      Bayreuth'],
#  [33.48379087322411, 8222, '      Mannheim, Stadtkreis'],
#  [32.77229487022856, 16055, '      Weimar, kreisfreie Stadt'],
#  [31.020727323821916, 5711, '      Bielefeld, kreisfreie Stadt'],
#  [30.007512048639967, 7211, '      Trier, kreisfreie Stadt'],
#  [29.149976637436907, 3401, '      Delmenhorst, kreisfreie Stadt'],
#  [29.112795110685568, 12053, '      Frankfurt (Oder), kreisfreie Stadt'],
#  [29.029295867543965, 1060, '      Segeberg, Landkreis'],
#  [27.73727892862337, 5334002, '      Aachen, krfr. Stadt'],
#  [26.586982930112015, 7312, '      Kaiserslautern, kreisfreie Stadt'],
#  [25.66012205279469, 15003, '      Magdeburg, kreisfreie Stadt'],
#  [20.667898246545462, 9563, '      Fürth'],
#  [19.562905708393373, 9261, '      Landshut'],
#  [17.882037328682713, 2, '  Hamburg'],
#  [17.787732254434673, 6433, '      Groß-Gerau, Landkreis'],
#  [16.57847955023192,
#   13004,
#   '      Schwerin, Landeshauptstadt, kreisfreie Stadtk'],
#  [16.45601054483427, 1003, '      Lübeck, Hansestadt, kreisfreie Stadt'],
#  [14.914368806976768, 7314, '      Ludwigshafen am Rhein, kreisfreie Stadt'],
#  [14.63703097080105, 1002, '      Kiel, Landeshauptstadt, kreisfreie Stadt'],
#  [12.380768755099098, 8111, '      Stuttgart, Landeshauptstadt, Stadtkreis'],
#  [11.490007191582436, 6611, '      Kassel, kreisfreie Stadt'],
#  [11.366605236231067, 9562, '      Erlangen'],
#  [8.625640915490749, 5111, '      Düsseldorf, kreisfreie Stadt'],
#  [7.076847933388706, 9761, '      Augsburg'],
#  [4.927842837702997, 4, '  Bremen'],
#  [1.5695640920063738, 15002, '      Halle (Saale), kreisfreie Stadt'],
#  [1.564655398197317, 9564, '      Nürnberg'],
#  [-2.5143203362691793, 16063, '      Wartburgkreis'],
#  [-3.692714662188962, 5515, '      Münster, kreisfreie Stadt'],
#  [-5.641943301293452, 16051, '      Erfurt, kreisfreie Stadt'],
#  [-5.814716282264726, 4011, '      Bremen, kreisfreie Stadt'],
#  [-6.956663653432145, 6412, '      Frankfurt am Main, kreisfreie Stadt'],
#  [-6.95678569722304, 8121, '      Heilbronn, Universitätsstadt, Stadtkreis'],
#  [-9.398085978338486, 8311, '      Freiburg im Breisgau, Stadtkreis'],
#  [-11.738968601181398, 12054, '      Potsdam, kreisfreie Stadt'],
#  [-12.508675289273185, 5315, '      Köln, kreisfreie Stadt'],
#  [-13.937879977773207,
#   13003,
#   '      Rostock, Hanse- und Universitätsstadt, kreisfreie Stadt'],
#  [-17.227143908177197, 11, '  Berlin'],
#  [-21.44574498607591, 7315, '      Mainz, kreisfreie Stadt'],
#  [-24.961842606099594, 9162, '      München, Landeshauptstadt'],
#  [-26.50470679689022, 16053, '      Jena, kreisfreie Stadt'],
#  [-28.893599236178602, 8212, '      Karlsruhe, Stadtkreis'],
#  [-36.27953255023061, 6413, '      Offenbach am Main, kreisfreie Stadt'],
#  [-51.20733239611286, 8221, '      Heidelberg, Stadtkreis'],
#  [-53.771481703267, 6411, '      Darmstadt, kreisfreie Stadt'],
#  [-69.10693564547728,
#   6414,
#   '      Wiesbaden, Landeshauptstadt, kreisfreie Stadt']]

# %%
get_most_different_cities_by_slope(True)
# Out:
# [[100.53178242170591, 5366, '      Euskirchen, Kreis'],
#  [86.16600373264441, 3103, '      Wolfsburg, kreisfreie Stadt'],
#  [77.25558197971378, 9184, '      München, Landkreis'],
#  [70.86738530019072, 6433, '      Groß-Gerau, Landkreis'],
#  [65.62016404223293,
#   6414,
#   '      Wiesbaden, Landeshauptstadt, kreisfreie Stadt'],
#  [58.113901282729195, 9362, '      Regensburg'],
#  [36.301830813116815, 5314, '      Bonn, kreisfreie Stadt'],
#  [33.58749493060507, 5515, '      Münster, kreisfreie Stadt'],
#  [31.856070800471354, 9661, '      Aschaffenburg'],
#  [30.673673424258006, 9763, '      Kempten (Allgäu)'],
#  [27.995013069890245, 9279, '      Dingolfing-Landau, Landkreis'],
#  [27.49358194866716, 6436, '      Main-Taunus-Kreis'],
#  [26.664917434562255, 16054, '      Suhl, kreisfreie Stadt'],
#  [26.23096250645361, 16055, '      Weimar, kreisfreie Stadt'],
#  [26.169288072535622, 1001, '      Flensburg, kreisfreie Stadt'],
#  [25.82480318367041, 9464, '      Hof'],
#  [25.796314296291786, 5558, '      Coesfeld, Kreis'],
#  [25.62589570320844, 9663, '      Würzburg'],
#  [24.15716652717187, 9161, '      Ingolstadt'],
#  [24.032204557754653, 1057, '      Plön, Landkreis'],
#  [24.011564376153107, 8235, '      Calw, Landkreis'],
#  [23.30759366868145, 6411, '      Darmstadt, kreisfreie Stadt'],
#  [23.222465747833233, 9261, '      Landshut'],
#  [22.81734560416889, 8221, '      Heidelberg, Stadtkreis'],
#  [22.811470714876105, 8222, '      Mannheim, Stadtkreis'],
#  [22.552734534513228, 3404, '      Osnabrück, kreisfreie Stadt'],
#  [22.14302297392302, 7317, '      Pirmasens, kreisfreie Stadt'],
#  [22.113719634261972, 7211, '      Trier, kreisfreie Stadt'],
#  [21.712462093773688, 9162, '      München, Landeshauptstadt'],
#  [21.1415920954197, 3101, '      Braunschweig, kreisfreie Stadt'],
#  [20.625572304577116, 16053, '      Jena, kreisfreie Stadt'],
#  [20.29085023688502, 9563, '      Fürth'],
#  [19.907720154465284, 7232, '      Eifelkreis Bitburg-Prüm'],
#  [19.52707325152252, 5711, '      Bielefeld, kreisfreie Stadt'],
#  [19.267489046585187, 9461, '      Bamberg'],
#  [18.722706613466716, 5122, '      Solingen, kreisfreie Stadt'],
#  [18.578525129737987, 5911, '      Bochum, kreisfreie Stadt'],
#  [18.443962432795185, 9361, '      Amberg'],
#  [18.040262660549992, 7320, '      Zweibrücken, kreisfreie Stadt'],
#  [17.314357467114448, 5114, '      Krefeld, kreisfreie Stadt'],
#  [17.255601441551175, 7111, '      Koblenz, kreisfreie Stadt'],
#  [16.662626967577182, 3405, '      Wilhelmshaven, kreisfreie Stadt'],
#  [16.513672207037487, 5978, '      Unna, Kreis'],
#  [16.47974617279912, 8237, '      Freudenstadt, Landkreis'],
#  [16.447887931475975, 8125, '      Heilbronn, Landkreis'],
#  [16.434710776430478, 5315, '      Köln, kreisfreie Stadt'],
#  [16.182817066616295, 5916, '      Herne, kreisfreie Stadt'],
#  [16.078209603277674, 8121, '      Heilbronn, Universitätsstadt, Stadtkreis'],
#  [16.046796389417256, 9183, '      Mühldorf a.Inn, Landkreis'],
#  [16.004955020821697, 12054, '      Potsdam, kreisfreie Stadt'],
#  [15.769588822990006, 7315, '      Mainz, kreisfreie Stadt'],
#  [15.586902353644655, 9761, '      Augsburg'],
#  [15.312603642858999, 3354, '      Lüchow-Dannenberg, Landkreis'],
#  [15.280658534935423,
#   13004,
#   '      Schwerin, Landeshauptstadt, kreisfreie Stadtk'],
#  [15.27997981279214, 16056, '      Eisenach, kreisfreie Stadt'],
#  [15.169572077324256, 6412, '      Frankfurt am Main, kreisfreie Stadt'],
#  [15.074059629664307, 12067, '      Oder-Spree, Landkreis'],
#  [14.853124909702645, 7140, '      Rhein-Hunsrück-Kreis'],
#  [14.522283225463635, 9463, '      Coburg'],
#  [14.520031789736814, 72, '    Trier, Stat. Region'],
#  [14.461613285630245, 5513, '      Gelsenkirchen, kreisfreie Stadt'],
#  [14.396114161115406, 3357, '      Rotenburg (Wümme), Landkreis'],
#  [14.267756538841335, 7235, '      Trier-Saarburg, Landkreis'],
#  [14.236378655092802, 8211, '      Baden-Baden, Stadtkreis'],
#  [14.227683088346033, 8126, '      Hohenlohekreis, Landkreis'],
#  [14.165341107478794, 9262, '      Passau'],
#  [14.078407108393188, 5966, '      Olpe, Kreis'],
#  [13.589178389676956, 9764, '      Memmingen'],
#  [13.538075525719519, 8437, '      Sigmaringen, Landkreis'],
#  [13.466152865803126, 9673, '      Rhön-Grabfeld, Landkreis'],
#  [13.425277586884096, 9377, '      Tirschenreuth, Landkreis'],
#  [13.408310033847025,
#   5334,
#   '      Städteregion Aachen (einschl. Stadt Aachen)'],
#  [13.384323290741433, 5512, '      Bottrop, kreisfreie Stadt'],
#  [13.36697202682638, 8212, '      Karlsruhe, Stadtkreis'],
#  [13.348311917024244, 8421, '      Ulm, Stadtkreis'],
#  [13.225687526910878, 6534, '      Marburg-Biedenkopf, Landkreis'],
#  [13.133745291715684, 8335, '      Konstanz, Landkreis'],
#  [13.09916270140584, 1060, '      Segeberg, Landkreis'],
#  [13.06509745896524, 16074, '      Saale-Holzland-Kreis'],
#  [12.941028809417604, 14713, '      Leipzig, Stadt'],
#  [12.857787720749773, 8311, '      Freiburg im Breisgau, Stadtkreis'],
#  [12.681785351073058,
#   12051,
#   '      Brandenburg an der Havel, kreisfreie Stadt'],
#  [12.66409322748775, 12073, '      Uckermark, Landkreis'],
#  [12.509792287532061, 9174, '      Dachau, Landkreis'],
#  [12.495658051758495, 9276, '      Regen, Landkreis'],
#  [12.481371253806275, 5758, '      Herford, Kreis'],
#  [12.441233508988768, 7233, '      Vulkaneifel, Landkreis'],
#  [12.416173955050505, 5117, '      Mülheim an der Ruhr, kreisfreie Stadt'],
#  [12.301975678900314, 9272, '      Freyung-Grafenau, Landkreis'],
#  [12.264655682854004, 7312, '      Kaiserslautern, kreisfreie Stadt'],
#  [12.233084496781567, 1055, '      Ostholstein, Landkreis'],
#  [12.197612068253655, 3255, '      Holzminden, Landkreis'],
#  [12.179194562474468, 3353, '      Harburg, Landkreis'],
#  [12.174888905517832, 15002, '      Halle (Saale), kreisfreie Stadt'],
#  [12.170154260812353, 5358, '      Düren, Kreis'],
#  [12.148287940368911, 6413, '      Offenbach am Main, kreisfreie Stadt'],
#  [12.118509234289402, 7143, '      Westerwaldkreis'],
#  [12.014605333352984, 9372, '      Cham, Landkreis'],
#  [12.010603026970971, 5120, '      Remscheid, kreisfreie Stadt'],
#  [11.970328552907676, 10044, '      Saarlouis, Landkreis'],
#  [11.941293952294473, 5112, '      Duisburg, kreisfreie Stadt'],
#  [11.892374984608066, 1062, '      Stormarn, Landkreis'],
#  [11.741601018982124, 5378, '      Rheinisch-Bergischer Kreis'],
#  [11.660644215356992, 9181, '      Landsberg am Lech, Landkreis'],
#  [11.589537785533622, 147, '    Leipzig, Stat. Region'],
#  [11.555492941201457, 11, '  Berlin'],
#  [11.55503825315261, 5974, '      Soest, Kreis'],
#  [11.523258118519857, 3102, '      Salzgitter, kreisfreie Stadt'],
#  [11.508375415198197, 5111, '      Düsseldorf, kreisfreie Stadt'],
#  [11.478039090679506, 1003, '      Lübeck, Hansestadt, kreisfreie Stadt'],
#  [11.434746395808224, 9271, '      Deggendorf, Landkreis'],
#  [11.311314588828944, 8416, '      Tübingen, Landkreis'],
#  [11.306442508981217, 5382, '      Rhein-Sieg-Kreis'],
#  [11.228806018066152, 5914, '      Hagen, kreisfreie Stadt'],
#  [11.205258958247764, 1004, '      Neumünster, kreisfreie Stadt'],
#  [11.169177818761233, 8436, '      Ravensburg, Landkreis'],
#  [11.136201682654544, 4011, '      Bremen, kreisfreie Stadt'],
#  [11.097461853624315, 9472, '      Bayreuth, Landkreis'],
#  [11.00768810906349, 8225, '      Neckar-Odenwald-Kreis, Landkreis'],
#  [10.982399807507173, 5958, '      Hochsauerlandkreis'],
#  [10.94263134710985, 3402, '      Emden, kreisfreie Stadt'],
#  [10.921532282161545, 2, '  Hamburg'],
#  [10.849668748297423, 3358, '      Heidekreis, Landkreis'],
#  [10.781817419508759, 9476, '      Kronach, Landkreis'],
#  [10.773806016136245, 9778, '      Unterallgäu, Landkreis'],
#  [10.769181147662598, 9374, '      Neustadt a.d.Waldnaab, Landkreis'],
#  [10.71976304714168, 3452, '      Aurich, Landkreis'],
#  [10.702267698252376, 6434, '      Hochtaunuskreis'],
#  [10.597644207224075, 5762, '      Höxter, Kreis'],
#  [10.565340170894144, 9477, '      Kulmbach, Landkreis'],
#  [10.561555792768639, 9662, '      Schweinfurt'],
#  [10.538945149075841, 5374, '      Oberbergischer Kreis'],
#  [10.534303398793789, 10046, '      St. Wendel, Landkreis'],
#  [10.502747939402933, 7333, '      Donnersbergkreis'],
#  [10.43506281676813,
#   9575,
#   '      Neustadt a.d.Aisch-Bad Windsheim, Landkreis'],
#  [10.378879649079451, 8115, '      Böblingen, Landkreis'],
#  [10.373311196440424, 7231, '      Bernkastel-Wittlich, Landkreis'],
#  [10.310796346476694, 6437, '      Odenwaldkreis'],
#  [10.21720158551244, 7137, '      Mayen-Koblenz, Landkreis'],
#  [10.196884362517947, 5570, '      Warendorf, Kreis'],
#  [10.180445700444494, 5158, '      Mettmann, Kreis'],
#  [10.154689057088753, 5554, '      Borken, Kreis'],
#  [10.14019150518365, 16051, '      Erfurt, kreisfreie Stadt'],
#  [10.11439931860338, 7135, '      Cochem-Zell, Landkreis'],
#  [10.097458000117609, 9187, '      Rosenheim, Landkreis'],
#  [10.02453248331573, 9473, '      Coburg, Landkreis'],
#  [10.020059978956272, 14511, '      Chemnitz, Stadt'],
#  [9.809103979942288, 5370, '      Heinsberg, Kreis'],
#  [9.79625379528196, 7318, '      Speyer, kreisfreie Stadt'],
#  [9.785808714142227, 9479, '      Wunsiedel i.Fichtelgebirge, Landkreis'],
#  [9.785777430541755, 3453, '      Cloppenburg, Landkreis'],
#  [9.76406984904403, 91, '    Oberbayern, Regierungsbezirk'],
#  [9.732103118706485, 1053, '      Herzogtum Lauenburg, Landkreis'],
#  [9.723913562409615, 6535, '      Vogelsbergkreis'],
#  [9.709767691414408, 6532, '      Lahn-Dill-Kreis'],
#  [9.697398739614963, 7331, '      Alzey-Worms, Landkreis'],
#  [9.604955846351649, 7133, '      Bad Kreuznach, Landkreis'],
#  [9.590819816424453, 3460, '      Vechta, Landkreis'],
#  [9.556154184937387, 16071, '      Weimarer Land, Kreis'],
#  [9.502154339245095, 10045, '      Saarpfalz-Kreis'],
#  [9.43984812274847, 7313, '      Landau in der Pfalz, kreisfreie Stadt'],
#  [9.405461004457635, 9561, '      Ansbach'],
#  [9.378619637494834, 7138, '      Neuwied, Landkreis'],
#  [9.342351033049841, 1061, '      Steinburg, Landkreis'],
#  [9.307877857370848, 6431, '      Bergstraße, Landkreis'],
#  [9.301429594730157, 3155, '      Northeim, Landkreis'],
#  [9.29691130541275, 5970, '      Siegen-Wittgenstein, Kreis'],
#  [9.296479405302245, 93, '    Oberpfalz, Regierungsbezirk'],
#  [9.244747053045314, 6635, '      Waldeck-Frankenberg, Landkreis'],
#  [9.243343239870029,
#   13003,
#   '      Rostock, Hanse- und Universitätsstadt, kreisfreie Stadt'],
#  [9.186674404629773, 7311, '      Frankenthal (Pfalz), kreisfreie Stadt'],
#  [8.979356127605465, 7336, '      Kusel, Landkreis'],
#  [8.960758212613195, 9471, '      Bamberg, Landkreis'],
#  [8.956907287013028, 4, '  Bremen'],
#  [8.951546256937066, 4012, '      Bremerhaven, kreisfreie Stadt'],
#  [8.945522246924757, 9674, '      Haßberge, Landkreis'],
#  [8.944305593155796, 3403, '      Oldenburg (Oldenburg), kreisfreie Stadt'],
#  [8.940551668054644, 9577, '      Weißenburg-Gunzenhausen, Landkreis'],
#  [8.93297918226571, 8135, '      Heidenheim, Landkreis'],
#  [8.88143094319389, 12060, '      Barnim, Landkreis'],
#  [8.86788635507782, 3462, '      Wittmund, Landkreis'],
#  [8.796709099776374, 71, '    Koblenz, Stat. Region'],
#  [8.796071248061866, 9475, '      Hof, Landkreis'],
#  [8.771915500602912, 9672, '      Bad Kissingen, Landkreis'],
#  [8.722464895593678, 55, '    Münster, Regierungsbezirk'],
#  [8.715198346451574, 7314, '      Ludwigshafen am Rhein, kreisfreie Stadt'],
#  [8.684978198324293, 3455, '      Friesland, Landkreis'],
#  [8.670042474430492, 5154, '      Kleve, Kreis'],
#  [8.657774407263487, 3151, '      Gifhorn, Landkreis'],
#  [8.643108280009933, 8136, '      Ostalbkreis, Landkreis'],
#  [8.634965814355741, 57, '    Detmold, Regierungsbezirk'],
#  [8.62742419309198, 9678, '      Schweinfurt, Landkreis'],
#  [8.614602899931157, 9565, '      Schwabach'],
#  [8.608728414897845, 12053, '      Frankfurt (Oder), kreisfreie Stadt'],
#  [8.597785111472257, 9562, '      Erlangen'],
#  [8.586878382116149, 9185, '      Neuburg-Schrobenhausen, Landkreis'],
#  [8.515638516153114, 9371, '      Amberg-Sulzbach, Landkreis'],
#  [8.509857219346193, 9677, '      Main-Spessart, Landkreis'],
#  [8.457130214682328, 3459, '      Osnabrück, Landkreis'],
#  [8.443283394615404, 1051, '      Dithmarschen, Landkreis'],
#  [8.379926556041319, 1058, '      Rendsburg-Eckernförde, Landkreis'],
#  [8.344736592948296, 6533, '      Limburg-Weilburg, Landkreis'],
#  [8.271589957029814, 9676, '      Miltenberg, Landkreis'],
#  [8.253407741402658, 8111, '      Stuttgart, Landeshauptstadt, Stadtkreis'],
#  [8.20775368794241, 14612, '      Dresden, Stadt'],
#  [8.199901173880436, 5915, '      Hamm, kreisfreie Stadt'],
#  [8.191747616805614, 15001, '      Dessau-Roßlau, kreisfreie Stadt'],
#  [8.188905367895648, 3158, '      Wolfenbüttel, Landkreis'],
#  [8.178391137844324, 9474, '      Forchheim, Landkreis'],
#  [8.154921517354142, 8226, '      Rhein-Neckar-Kreis, Landkreis'],
#  [8.149651858398721, 9263, '      Straubing'],
#  [8.109948849387834, 10042, '      Merzig-Wadern, Landkreis'],
#  [8.102233361569947, 31, '    Braunschweig, Stat. Region'],
#  [8.09215450655019, 9176, '      Eichstätt, Landkreis'],
#  [8.089665219716698, 5362, '      Rhein-Erft-Kreis'],
#  [8.037313669075923, 9779, '      Donau-Ries, Landkreis'],
#  [8.030967454273075, 3360, '      Uelzen, Landkreis'],
#  [8.013789662946985, 5754, '      Gütersloh, Kreis'],
#  [8.012962568234006, 9777, '      Ostallgäu, Landkreis'],
#  [8.002757415502483, 9478, '      Lichtenfels, Landkreis'],
#  [7.973420495272814, 7141, '      Rhein-Lahn-Kreis'],
#  [7.946371103975299, 16069, '      Hildburghausen, Kreis'],
#  [7.8971990084247885, 5566, '      Steinfurt, Kreis'],
#  [7.885801335211878, 9278, '      Straubing-Bogen, Landkreis'],
#  [7.834718515519725, 3157, '      Peine, Landkreis'],
#  [7.833570516074122, 84, '    Tübingen, Regierungsbezirk'],
#  [7.826363795628541, 16061, '      Eichsfeld, Kreis'],
#  [7.824910604540343, 6634, '      Schwalm-Eder-Kreis'],
#  [7.805014443602934, 8325, '      Rottweil, Landkreis'],
#  [7.796097341952457, 9275, '      Passau, Landkreis'],
#  [7.7921716636862115, 12061, '      Dahme-Spreewald, Landkreis'],
#  [7.745113804314539, 3457, '      Leer, Landkreis'],
#  [7.74316610426077, 8415, '      Reutlingen, Landkreis'],
#  [7.72079730743841, 9774, '      Günzburg, Landkreis'],
#  [7.697329438123283, 12066, '      Oberspreewald-Lausitz, Landkreis'],
#  [7.604173511673068, 9671, '      Aschaffenburg, Landkreis'],
#  [7.566139717541097, 3352, '      Cuxhaven, Landkreis'],
#  [7.557041098491519, 10041, '      Saarbrücken, Regionalverband'],
#  [7.54458782372598, 7339, '      Mainz-Bingen, Landkreis'],
#  [7.467369080884593, 5119, '      Oberhausen, kreisfreie Stadt'],
#  [7.465561870173465, 7337, '      Südliche Weinstraße, Landkreis'],
#  [7.459359721941687, 8417, '      Zollernalbkreis, Landkreis'],
#  [7.451006263456433, 12071, '      Spree-Neiße, Landkreis'],
#  [7.4193424821885845, 9573, '      Fürth, Landkreis'],
#  [7.416091978594202, 1002, '      Kiel, Landeshauptstadt, kreisfreie Stadt'],
#  [7.386079527883954, 3356, '      Osterholz, Landkreis'],
#  [7.38523816280853, 94, '    Oberfranken, Regierungsbezirk'],
#  [7.33459960548873, 16067, '      Gotha, Kreis'],
#  [7.317244097533937, 8231, '      Pforzheim, Stadtkreis'],
#  [7.298645165804396, 3461, '      Wesermarsch, Landkreis'],
#  [7.290910779048459, 3154, '      Helmstedt, Landkreis'],
#  [7.2886159332366285, 7340, '      Südwestpfalz, Landkreis'],
#  [7.275207401535692, 12062, '      Elbe-Elster, Landkreis'],
#  [7.265630558506846, 3458, '      Oldenburg, Landkreis'],
#  [7.246281369283055, 5166, '      Viersen, Kreis'],
#  [7.238230757830756, 9171, '      Altötting, Landkreis'],
#  [7.236263255004064, 16066, '      Schmalkalden-Meiningen, Kreis'],
#  [7.1806520928369855, 53, '    Köln, Regierungsbezirk'],
#  [7.163162568731032, 9189, '      Traunstein, Landkreis'],
#  [7.14339377999195, 12069, '      Potsdam-Mittelmark, Landkreis'],
#  [7.127883398561693, 5170, '      Wesel, Kreis'],
#  [7.123077299800372, 7, '  Rheinland-Pfalz'],
#  [7.089143773862175,
#   7316,
#   '      Neustadt an der Weinstraße, kreisfreie Stadt'],
#  [7.082311106467354, 5770, '      Minden-Lübbecke, Kreis'],
#  [7.046562882193319, 3153, '      Goslar, Landkreis'],
#  [6.9890515964076245, 9163, '      Rosenheim'],
#  [6.940907701870995, 5766, '      Lippe, Kreis'],
#  [6.91851275394762, 6438, '      Offenbach, Landkreis'],
#  [6.878505197588042, 16068, '      Sömmerda, Kreis'],
#  [6.870918429976755, 6531, '      Gießen, Landkreis'],
#  [6.859579465491059, 5116, '      Mönchengladbach, kreisfreie Stadt'],
#  [6.805308758083016, 8128, '      Main-Tauber-Kreis, Landkreis'],
#  [6.803708183250677, 5962, '      Märkischer Kreis'],
#  [6.773033863365128, 9571, '      Ansbach, Landkreis'],
#  [6.724654170119222, 9373, '      Neumarkt i.d.OPf., Landkreis'],
#  [6.701915486716819, 8435, '      Bodenseekreis, Landkreis'],
#  [6.692437757016657, 9273, '      Kelheim, Landkreis'],
#  [6.688549706677796, 9772, '      Augsburg, Landkreis'],
#  [6.679939039399663, 7132, '      Altenkirchen (Westerwald), Landkreis'],
#  [6.665536670133299, 3252, '      Hameln-Pyrmont, Landkreis'],
#  [6.663728505816049, 9675, '      Kitzingen, Landkreis'],
#  [6.6622149852654795, 8426, '      Biberach, Landkreis'],
#  [6.658454039437565, 9776, '      Lindau (Bodensee), Landkreis'],
#  [6.609051705448197, 14, '  Sachsen'],
#  [6.607644770563256, 8236, '      Enzkreis, Landkreis'],
#  [6.605776774616555, 7332, '      Bad Dürkheim, Landkreis'],
#  [6.583992783079344, 9277, '      Rottal-Inn, Landkreis'],
#  [6.571262897969068, 5316, '      Leverkusen, kreisfreie Stadt'],
#  [6.569358288652539, 8216, '      Rastatt, Landkreis'],
#  [6.549807870929261, 16052, '      Gera, kreisfreie Stadt'],
#  [6.544893219996237, 9186, '      Pfaffenhofen a.d.Ilm, Landkreis'],
#  [6.531254256083492, 97, '    Schwaben, Regierungsbezirk'],
#  [6.5311440735507285, 6632, '      Hersfeld-Rotenburg, Landkreis'],
#  [6.527557645547102, 7134, '      Birkenfeld, Landkreis'],
#  [6.467056558583515, 7335, '      Kaiserslautern, Landkreis'],
#  [6.449932471207167, 9190, '      Weilheim-Schongau, Landkreis'],
#  [6.393823065960503, 8117, '      Göppingen, Landkreis'],
#  [6.370647197333724, 13, '  Mecklenburg-Vorpommern'],
#  [6.359188349266572, 1059, '      Schleswig-Flensburg, Landkreis'],
#  [6.354237732662807, 3456, '      Grafschaft Bentheim, Landkreis'],
#  [6.3458407231231355, 6631, '      Fulda, Landkreis'],
#  [6.3288644884242755, 14729, '      Leipzig, Landkreis'],
#  [6.3197957623772485, 12063, '      Havelland, Landkreis'],
#  [6.3112912074120855, 9576, '      Roth, Landkreis'],
#  [6.2875931062711805, 9180, '      Garmisch-Partenkirchen, Landkreis'],
#  [6.266399194640717, 12072, '      Teltow-Fläming, Landkreis'],
#  [6.237303991985156, 92, '    Niederbayern, Regierungsbezirk'],
#  [6.216256136233497, 3256, '      Nienburg (Weser), Landkreis'],
#  [6.191989047721965, 8425, '      Alb-Donau-Kreis, Landkreis'],
#  [6.150097858217781, 5113, '      Essen, kreisfreie Stadt'],
#  [6.149712999178571, 6633, '      Kassel, Landkreis'],
#  [6.147821599308743, 8327, '      Tuttlingen, Landkreis'],
#  [6.099773939222521, 12064, '      Märkisch-Oderland, Landkreis'],
#  [6.084228970134883, 16062, '      Nordhausen, Kreis'],
#  [6.065913585303827,
#   14628,
#   '      Sächsische Schweiz-Osterzgebirge, Landkreis'],
#  [6.059318776698185, 1054, '      Nordfriesland, Landkreis'],
#  [6.02635252319277, 15081, '      Altmarkkreis Salzwedel'],
#  [5.988461369357074, 34, '    Weser-Ems, Stat. Region'],
#  [5.971436142857687, 12, '  Brandenburg'],
#  [5.9521255948011556, 5774, '      Paderborn, Kreis'],
#  [5.9488188384573695, 7131, '      Ahrweiler, Landkreis'],
#  [5.939726458633502, 8317, '      Ortenaukreis, Landkreis'],
#  [5.938695270804267, 96, '    Unterfranken, Regierungsbezirk'],
#  [5.925939924589122, 59, '    Arnsberg, Regierungsbezirk'],
#  [5.925008710493441, 15091, '      Wittenberg, Landkreis'],
#  [5.919171101323406, 3355, '      Lüneburg, Landkreis'],
#  [5.897499560911913, 9177, '      Erding, Landkreis'],
#  [5.867523366277632, 10043, '      Neunkirchen, Landkreis'],
#  [5.82329085223232, 9773, '      Dillingen a.d.Donau, Landkreis'],
#  [5.817644477425433, 8127, '      Schwäbisch Hall, Landkreis'],
#  [5.8133336696366325, 82, '    Karlsruhe, Regierungsbezirk'],
#  [5.772693149268297, 146, '    Dresden, Stat. Region'],
#  [5.73460982774626, 7334, '      Germersheim, Landkreis'],
#  [5.730576053781417, 12068, '      Ostprignitz-Ruppin, Landkreis'],
#  [5.715538330938792, 12065, '      Oberhavel, Landkreis'],
#  [5.713142182503977, 5913, '      Dortmund, kreisfreie Stadt'],
#  [5.674621327108873, 33, '    Lüneburg, Stat. Region'],
#  [5.643670904755944, 16064, '      Unstrut-Hainich-Kreis'],
#  [5.636286483011916, 14522, '      Mittelsachsen, Landkreis'],
#  [5.551002214855146, 15085, '      Harz, Landkreis'],
#  [5.476318509244337, 9376, '      Schwandorf, Landkreis'],
#  [5.457725704349489, 3454, '      Emsland, Landkreis'],
#  [5.447859586015424, 12052, '      Cottbus, kreisfreie Stadt'],
#  [5.397824024757975, 6432, '      Darmstadt-Dieburg, Landkreis'],
#  [5.387532243131088, 9564, '      Nürnberg'],
#  [5.374316175206659, 14730, '      Nordsachsen, Landkreis'],
#  [5.370474704199561, 8326, '      Schwarzwald-Baar-Kreis, Landkreis'],
#  [5.349345518774621, 16070, '      Ilm-Kreis'],
#  [5.338169583702572, 9574, '      Nürnberger Land, Landkreis'],
#  [5.327599870421072, 9572, '      Erlangen-Höchstadt, Landkreis'],
#  [5.316964984310052, 9175, '      Ebersberg, Landkreis'],
#  [5.313579327380456, 15087, '      Mansfeld-Südharz, Landkreis'],
#  [5.305800595331123, 9780, '      Oberallgäu, Landkreis'],
#  [5.301529009923024, 8336, '      Lörrach, Landkreis'],
#  [5.270643736920428, 16076, '      Greiz, Kreis'],
#  [5.266446039372772, 16, '  Thüringen'],
#  [5.224127353257583, 3, '  Niedersachsen'],
#  [5.208970130163495, 5954, '      Ennepe-Ruhr-Kreis'],
#  [5.18320575226934, 3401, '      Delmenhorst, kreisfreie Stadt'],
#  [5.163129344835338, 9679, '      Würzburg, Landkreis'],
#  [5.159794245455816, 15086, '      Jerichower Land, Landkreis'],
#  [5.130682526148656, 15003, '      Magdeburg, kreisfreie Stadt'],
#  [5.0841521099889055, 9, '  Bayern'],
#  [5.060160720619359, 9462, '      Bayreuth'],
#  [5.034257234267522, 9771, '      Aichach-Friedberg, Landkreis'],
#  [4.9825071215436605, 64, '    Darmstadt, Regierungsbezirk'],
#  [4.979757438926797, 3361, '      Verden, Landkreis'],
#  [4.972976672917046, 10, '  Saarland'],
#  [4.921488777662634, 5562, '      Recklinghausen, Kreis'],
#  [4.904016581503338, 3359, '      Stade, Landkreis'],
#  [4.864108201668141, 3251, '      Diepholz, Landkreis'],
#  [4.862003034954382, 83, '    Freiburg, Regierungsbezirk'],
#  [4.837322687440191, 16065, '      Kyffhäuserkreis'],
#  [4.7937398284212875, 9178, '      Freising, Landkreis'],
#  [4.769462285088955, 9274, '      Landshut, Landkreis'],
#  [4.757944417415648, 5124, '      Wuppertal, kreisfreie Stadt'],
#  [4.725873753190529, 9182, '      Miesbach, Landkreis'],
#  [4.700186595844219, 15083, '      Börde, Landkreis'],
#  [4.686677042385068, 8337, '      Waldshut, Landkreis'],
#  [4.669764024480357, 1056, '      Pinneberg, Landkreis'],
#  [4.649305935115686, 3257, '      Schaumburg, Landkreis'],
#  [4.644454710109855, 9363, '      Weiden i.d.OPf.'],
#  [4.6322767352541225, 14625, '      Bautzen, Landkreis'],
#  [4.607415779914411, 8315, '      Breisgau-Hochschwarzwald, Landkreis'],
#  [4.574444329741476, 9179, '      Fürstenfeldbruck, Landkreis'],
#  [4.563241083925204, 145, '    Chemnitz, Stat. Region'],
#  [4.541416473983451, 5162, '      Rhein-Kreis Neuss'],
#  [4.535723326007381, 9375, '      Regensburg, Landkreis'],
#  [4.493095772577699, 7338, '      Rhein-Pfalz-Kreis'],
#  [4.44556913346356, 73, '    Rheinhessen-Pfalz, Stat. Region'],
#  [4.41005871229137, 3254, '      Hildesheim, Landkreis'],
#  [4.387848588094247, 8119, '      Rems-Murr-Kreis, Landkreis'],
#  [4.3728439375964, 16072, '      Sonneberg, Kreis'],
#  [4.308436363559626, 9762, '      Kaufbeuren'],
#  [4.298466773617225, 8, '  Baden-Württemberg, Land'],
#  [4.269451415319433, 9188, '      Starnberg, Landkreis'],
#  [4.252387918534793, 14626, '      Görlitz, Landkreis'],
#  [4.191367738876419, 12070, '      Prignitz, Landkreis'],
#  [4.187676690919795, 6439, '      Rheingau-Taunus-Kreis'],
#  [4.124858392240429, 15, '  Sachsen-Anhalt'],
#  [4.088269546557892, 16063, '      Wartburgkreis'],
#  [4.044287135595036, 6440, '      Wetteraukreis'],
#  [4.004938493000144, 3351, '      Celle, Landkreis'],
#  [3.99331444715718, 7319, '      Worms, kreisfreie Stadt'],
#  [3.8919996222734707, 15082, '      Anhalt-Bitterfeld, Landkreis'],
#  [3.8754137601805105, 66, '    Kassel, Regierungsbezirk'],
#  [3.870016146557388, 9173, '      Bad Tölz-Wolfratshausen, Landkreis'],
#  [3.865279394850133, 16073, '      Saalfeld-Rudolstadt, Kreis'],
#  [3.8571457266661504, 8215, '      Karlsruhe, Landkreis'],
#  [3.852846249106952, 14521, '      Erzgebirgskreis'],
#  [3.8454006038377364, 9775, '      Neu-Ulm, Landkreis'],
#  [3.8040072655916544, 15084, '      Burgenlandkreis'],
#  [3.7295571915942523, 3451, '      Ammerland, Landkreis'],
#  [3.6187787559065527, 15090, '      Stendal, Landkreis'],
#  [3.5852599705257324, 8316, '      Emmendingen, Landkreis'],
#  [3.5652044764287094, 9172, '      Berchtesgadener Land, Landkreis'],
#  [3.4925759588673344, 65, '    Gießen, Regierungsbezirk'],
#  [3.4809832182142677, 14627, '      Meißen, Landkreis'],
#  [3.477302649126666, 16077, '      Altenburger Land, Kreis'],
#  [3.442412577332024, 81, '    Stuttgart, Regierungsbezirk'],
#  [3.4269583648173985, 3241, '      Region Hannover, Landkreis'],
#  [3.3795035410488747, 5, '  Nordrhein-Westfalen'],
#  [3.349099612103464, 15088, '      Saalekreis'],
#  [3.318835930381097, 14523, '      Vogtlandkreis'],
#  [3.285509935463749, 6636, '      Werra-Meißner-Kreis'],
#  [3.278492092517532, 6, '  Hessen'],
#  [3.2114379734997778, 8118, '      Ludwigsburg, Landkreis'],
#  [2.956378514382458, 16075, '      Saale-Orla-Kreis'],
#  [2.861027111081921, 6611, '      Kassel, kreisfreie Stadt'],
#  [2.7647973825179024, 1, '  Schleswig-Holstein'],
#  [2.733981532176108, 6435, '      Main-Kinzig-Kreis'],
#  [2.6635259422674995, 51, '    Düsseldorf, Regierungsbezirk'],
#  [2.482582750071163, 15089, '      Salzlandkreis'],
#  [2.353929731878842, 95, '    Mittelfranken, Regierungsbezirk'],
#  [2.0734442437376748, 8116, '      Esslingen, Landkreis'],
#  [1.5604832064157208, 14524, '      Zwickau, Landkreis'],
#  [1.2326274350954778, 32, '    Hannover, Stat. Region'],
#  [0.0, 0, 'Deutschland']]
