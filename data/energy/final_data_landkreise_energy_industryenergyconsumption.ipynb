# %%
### Download industry energy consumption data for Landkreise
### from regionalstatistik.de and compile into csv with Regions as rows
### and years as columns.

# %%
###https://www.regionalstatistik.de/genesis/online?operation=table&code=43531-01-02-4-B&levelindex=0&levelid=1658896529187#astructure
###download data for all regions and all years as "flat"

# %%
#import necessary libraries

import pandas as pd
import numpy as np

# %%
#helper function pivot original table
def createWideFormat(df,column, values):
    #pivot table to wide format data
    orte = df["AGS"].unique()

    pivot_total = pd.DataFrame()

    for ort in orte:
            snippet = df[df["AGS"] == ort]

            temp = pd.pivot_table(snippet, index='Jahr',columns=column, values=values)
            temp = temp.reset_index(level=0)

            temp["ort_ags"] = ort
            temp["ort_name"]= str(snippet["1_Auspraegung_Label"].iloc[0]).lstrip()

            pivot_total = pd.concat([pivot_total, temp])
            
    return pivot_total

# %%
#load data from csv
ie_df = pd.read_csv("data/industry.csv",delimiter=";",encoding="latin1")

ie_df
# Out:
#        Statistik_Code                                    Statistik_Label  \
# 0               43531  Jahreserhebung ü. die Energieverwendung der Be...
# 1               43531  Jahreserhebung ü. die Energieverwendung der Be...
# 2               43531  Jahreserhebung ü. die Energieverwendung der Be...
# 3               43531  Jahreserhebung ü. die Energieverwendung der Be...
# 4               43531  Jahreserhebung ü. die Energieverwendung der Be...
# ...               ...                                                ...
# 77467           43531  Jahreserhebung ü. die Energieverwendung der Be...
# 77468           43531  Jahreserhebung ü. die Energieverwendung der Be...
# 77469           43531  Jahreserhebung ü. die Energieverwendung der Be...
# 77470           43531  Jahreserhebung ü. die Energieverwendung der Be...
# 77471           43531  Jahreserhebung ü. die Energieverwendung der Be...
#
#       Zeit_Code Zeit_Label  Zeit 1_Merkmal_Code               1_Merkmal_Label  \
# 0          JAHR       Jahr  2020         KREISE  Kreise und kreisfreie Städte
# 1          JAHR       Jahr  2020         KREISE  Kreise und kreisfreie Städte
# 2          JAHR       Jahr  2020         KREISE  Kreise und kreisfreie Städte
# 3          JAHR       Jahr  2020         KREISE  Kreise und kreisfreie Städte
# 4          JAHR       Jahr  2020         KREISE  Kreise und kreisfreie Städte
# ...         ...        ...   ...            ...                           ...
# 77467      JAHR       Jahr  2003         KREISE  Kreise und kreisfreie Städte
# 77468      JAHR       Jahr  2003         KREISE  Kreise und kreisfreie Städte
# 77469      JAHR       Jahr  2003         KREISE  Kreise und kreisfreie Städte
# 77470      JAHR       Jahr  2003         KREISE  Kreise und kreisfreie Städte
# 77471      JAHR       Jahr  2003         KREISE  Kreise und kreisfreie Städte
#
#       1_Auspraegung_Code            1_Auspraegung_Label 2_Merkmal_Code  \
# 0                     DG                    Deutschland         ENRNW1
# 1                     DG                    Deutschland         ENRNW1
# 2                     DG                    Deutschland         ENRNW1
# 3                     DG                    Deutschland         ENRNW1
# 4                     DG                    Deutschland         ENRNW1
# ...                  ...                            ...            ...
# 77467              16077        Altenburger Land, Kreis         ENRNW1
# 77468              16077        Altenburger Land, Kreis         ENRNW1
# 77469              16077        Altenburger Land, Kreis         ENRNW1
# 77470              16077        Altenburger Land, Kreis         ENRNW1
# 77471              16077        Altenburger Land, Kreis         ENRNW1
#
#       2_Merkmal_Label 2_Auspraegung_Code     2_Auspraegung_Label  \
# 0       Energieträger          ENRGTRNW0               insgesamt
# 1       Energieträger          ENRGTRNW1                   Kohle
# 2       Energieträger          ENRGTRNW2                  Heizöl
# 3       Energieträger          ENRGTRNW3                  Erdgas
# 4       Energieträger          ENRGTRNW4    Erneuerbare Energien
# ...               ...                ...                     ...
# 77467   Energieträger          ENRGTRNW3                  Erdgas
# 77468   Energieträger          ENRGTRNW4    Erneuerbare Energien
# 77469   Energieträger          ENRGTRNW5                   Strom
# 77470   Energieträger          ENRGTRNW6                   Wärme
# 77471   Energieträger          ENRGTRNW7  Sonstige Energieträger
#
#       VBR001__Energieverbrauch_(einschl._nichtenergetischem_V.)__Tsd._MJ
# 0                                             3747109390
# 1                                              583625959
# 2                                               61319731
# 3                                             1168708514
# 4                                              153606273
# ...                                                  ...
# 77467                                             240813
# 77468                                                  -
# 77469                                             430856
# 77470                                                  .
# 77471                                                  .
#
# [77472 rows x 14 columns]

# %%
#rename AGS and year columns for merging with population
ie_df.rename({"1_Auspraegung_Code":"AGS","2_Auspraegung_Label":"Energietyp","Zeit":"Jahr","VBR001__Energieverbrauch_(einschl._nichtenergetischem_V.)__Tsd._MJ":"Energieverbrauch"},axis=1,inplace=True)

#set empty cells to nan and convert to numeric
ie_df["Energieverbrauch"] = ie_df["Energieverbrauch"].replace({'-':0,".":np.NaN})
ie_df["Energieverbrauch"] = pd.to_numeric(ie_df["Energieverbrauch"])

#create wide format data
pivot = createWideFormat(ie_df,"Energietyp","Energieverbrauch")

#calculate proportion of renewables
pivot["Anteil_Erneuerbar"] = pivot["Erneuerbare Energien"] / pivot["insgesamt"] * 100

#calculate secret part of data
pivot["Geheim"] = pivot['insgesamt']-pivot[['Erdgas', 'Erneuerbare Energien', 'Heizöl', 'Kohle', 'Sonstige Energieträger','Strom','Wärme']].sum(axis=1)
pivot["Geheim"] = pivot["Geheim"].apply(lambda x: x if x > 3 else 0)
pivot["Anteil_Geheim"] = pivot["Geheim"] / pivot["insgesamt"] * 100
pivot.loc[pivot['insgesamt']== 0, 'Anteil_Geheim'] = 100
pivot.loc[pivot['insgesamt'].isnull(), 'Anteil_Geheim'] = 100
pivot["Anteil_Geheim"]

#correct AGS for Deutschland
pivot['ort_ags']=pivot['ort_ags'].replace('DG',0)

pivot['ort_ags']=pd.to_numeric(pivot['ort_ags'])

pivot[pivot.ort_ags == 3103]
# Out:
# Energietyp  Jahr  Erdgas  Erneuerbare Energien   Heizöl  Kohle  \
# 0           2003     NaN                   0.0      NaN    0.0
# 1           2004     NaN                   0.0  33081.0    0.0
# 2           2005     NaN                   0.0  13857.0    0.0
# 3           2006     NaN                   0.0  33558.0    NaN
# 4           2007     NaN                   0.0      NaN    NaN
# 5           2008     NaN                   0.0      NaN    NaN
# 6           2009     NaN                   0.0  16917.0    NaN
# 7           2010     NaN                   0.0      NaN    NaN
# 8           2011     NaN                   0.0      NaN    NaN
# 9           2012     NaN                   0.0  13880.0    NaN
# 10          2013     NaN                   0.0      NaN    NaN
# 11          2015     NaN                   NaN      NaN    NaN
# 12          2016     NaN                   NaN      NaN    NaN
# 13          2017     NaN                   NaN      NaN    NaN
# 14          2018     NaN                   NaN      NaN    NaN
# 15          2020     NaN                   0.0      NaN    NaN
#
# Energietyp  Sonstige Energieträger  Strom     Wärme  insgesamt  ort_ags  \
# 0                              NaN    NaN   23518.0        NaN     3103
# 1                              NaN    NaN       NaN        NaN     3103
# 2                              NaN    NaN  436693.0        NaN     3103
# 3                              NaN    NaN  434583.0        NaN     3103
# 4                              NaN    NaN       NaN        NaN     3103
# 5                              NaN    NaN       NaN        NaN     3103
# 6                              NaN    NaN  433217.0        NaN     3103
# 7                              NaN    NaN   33980.0        NaN     3103
# 8                              NaN    NaN   30752.0        NaN     3103
# 9                              NaN    NaN       NaN        NaN     3103
# 10                             NaN    NaN       NaN        NaN     3103
# 11                             NaN    NaN   34652.0        NaN     3103
# 12                             NaN    NaN   16612.0        NaN     3103
# 13                             NaN    NaN   10608.0        NaN     3103
# 14                             NaN    NaN   28246.0        NaN     3103
# 15                             NaN    NaN       NaN        NaN     3103
#
# Energietyp                     ort_name  Anteil_Erneuerbar  Geheim  \
# 0           Wolfsburg, kreisfreie Stadt                NaN     0.0
# 1           Wolfsburg, kreisfreie Stadt                NaN     0.0
# 2           Wolfsburg, kreisfreie Stadt                NaN     0.0
# 3           Wolfsburg, kreisfreie Stadt                NaN     0.0
# 4           Wolfsburg, kreisfreie Stadt                NaN     0.0
# 5           Wolfsburg, kreisfreie Stadt                NaN     0.0
# 6           Wolfsburg, kreisfreie Stadt                NaN     0.0
# 7           Wolfsburg, kreisfreie Stadt                NaN     0.0
# 8           Wolfsburg, kreisfreie Stadt                NaN     0.0
# 9           Wolfsburg, kreisfreie Stadt                NaN     0.0
# 10          Wolfsburg, kreisfreie Stadt                NaN     0.0
# 11          Wolfsburg, kreisfreie Stadt                NaN     0.0
# 12          Wolfsburg, kreisfreie Stadt                NaN     0.0
# 13          Wolfsburg, kreisfreie Stadt                NaN     0.0
# 14          Wolfsburg, kreisfreie Stadt                NaN     0.0
# 15          Wolfsburg, kreisfreie Stadt                NaN     0.0
#
# Energietyp  Anteil_Geheim
# 0                   100.0
# 1                   100.0
# 2                   100.0
# 3                   100.0
# 4                   100.0
# 5                   100.0
# 6                   100.0
# 7                   100.0
# 8                   100.0
# 9                   100.0
# 10                  100.0
# 11                  100.0
# 12                  100.0
# 13                  100.0
# 14                  100.0
# 15                  100.0

# %%
#save test dataframe to file
#pivot.to_csv("data/test_data_landkreis_energy_industryenergy.csv")

# %%
#filter secret landkreise

#get landkreise with 0 in total energy in more than 6 years since 2010
recents = pivot[pivot['Jahr'] >= 2010]
recents["has_data"] = recents["insgesamt"] > 0

groups = recents.groupby(['ort_ags']).sum()
without_data = groups[groups.has_data <= 4].index

without_data
# Out:
# /var/folders/6w/mz49x3ds0b18vg8p9jx7wg0r0000gn/T/ipykernel_8804/2394072174.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recents["has_data"] = recents["insgesamt"] > 0
# /var/folders/6w/mz49x3ds0b18vg8p9jx7wg0r0000gn/T/ipykernel_8804/2394072174.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   groups = recents.groupby(['ort_ags']).sum()
# Int64Index([     141,      142,      143,      151,      152,      153,
#                 1061,     3102,     3103,     3157,
#             ...
#             11003003, 11004004, 11005005, 11006006, 11007007, 11008008,
#             11009009, 11010010, 11011011, 11012012],
#            dtype='int64', name='ort_ags', length=125)

# %%
#change year column to string to facilitate renaming columns after second pivot
pivot['Jahr'] = pivot['Jahr'].astype(str)

#pivot data to include years and energy types as columns
piv_df = pivot.pivot(index=["ort_ags","ort_name"],columns="Jahr",values=['Erdgas', 'Erneuerbare Energien', 'Heizöl', 'Kohle',
       'Sonstige Energieträger', 'Strom', 'Wärme','Geheim', 'insgesamt', 'Anteil_Erneuerbar',"Anteil_Geheim"])

#collapse levels of column names and join energy type to year
piv_df.columns = piv_df.columns.map('_'.join)

#prepend all columns with indicator name
piv_df=piv_df.add_prefix('energy_industry_consumption_')

#reset index to recreate AGS and Name columns
piv_df.reset_index(inplace=True)

#rename regional id and name and strip whitespace from Name column
piv_df.rename(columns={'ort_name':'Name','ort_ags':'AGS'},inplace=True)
piv_df['Name']=piv_df['Name'].str.strip()
piv_df['AGS']=pd.to_numeric(piv_df['AGS'])

#store if AGS has only secret data
piv_df['energy_industry_consumption_has_regional_data'] = True 
piv_df.loc[piv_df['AGS'].isin(without_data), 'energy_industry_consumption_has_regional_data'] = False

#set AGS as index
piv_df.set_index('AGS',inplace=True)
piv_df.sort_index(inplace=True)

##tsd mjoule to tjoule (1000*10^-6=0.001)
cols = [col for col in piv_df.columns if not "Anteil" in col]
mask = piv_df[cols].columns.difference(["Name","Unit",'energy_industry_consumption_has_regional_data'])
#piv_df[mask] = piv_df[mask].applymap(lambda x: x*0.001)

#unit of measure
piv_df["Unit"] = "GJoule"

piv_df
# Out:
#                                 Name  energy_industry_consumption_Erdgas_2003  \
# AGS
# 0                        Deutschland                             1.013851e+09
# 1                 Schleswig-Holstein                             1.671949e+07
# 2                            Hamburg                             2.083285e+07
# 3                      Niedersachsen                             1.382405e+08
# 4                             Bremen                             1.379781e+07
# ...                              ...                                      ...
# 11008008             Berlin-Neukölln                             0.000000e+00
# 11009009     Berlin-Treptow-Köpenick                             0.000000e+00
# 11010010  Berlin-Marzahn-Hellersdorf                             0.000000e+00
# 11011011          Berlin-Lichtenberg                             0.000000e+00
# 11012012        Berlin-Reinickendorf                             0.000000e+00
#
#           energy_industry_consumption_Erdgas_2004  \
# AGS
# 0                                    1.035524e+09
# 1                                    1.595202e+07
# 2                                    2.269981e+07
# 3                                    1.406649e+08
# 4                                    1.342768e+07
# ...                                           ...
# 11008008                             0.000000e+00
# 11009009                             0.000000e+00
# 11010010                             0.000000e+00
# 11011011                             0.000000e+00
# 11012012                             0.000000e+00
#
#           energy_industry_consumption_Erdgas_2005  \
# AGS
# 0                                    1.042020e+09
# 1                                    1.649519e+07
# 2                                    1.969420e+07
# 3                                    1.494298e+08
# 4                                    1.190057e+07
# ...                                           ...
# 11008008                             0.000000e+00
# 11009009                             0.000000e+00
# 11010010                             0.000000e+00
# 11011011                             0.000000e+00
# 11012012                             0.000000e+00
#
#           energy_industry_consumption_Erdgas_2006  \
# AGS
# 0                                    1.038921e+09
# 1                                    1.624940e+07
# 2                                    2.205925e+07
# 3                                    1.391713e+08
# 4                                    1.350348e+07
# ...                                           ...
# 11008008                             0.000000e+00
# 11009009                             0.000000e+00
# 11010010                             0.000000e+00
# 11011011                             0.000000e+00
# 11012012                             0.000000e+00
#
#           energy_industry_consumption_Erdgas_2007  \
# AGS
# 0                                    1.067395e+09
# 1                                    1.728819e+07
# 2                                    2.176798e+07
# 3                                    1.378556e+08
# 4                                    1.351306e+07
# ...                                           ...
# 11008008                             0.000000e+00
# 11009009                             0.000000e+00
# 11010010                             0.000000e+00
# 11011011                             0.000000e+00
# 11012012                             0.000000e+00
#
#           energy_industry_consumption_Erdgas_2008  \
# AGS
# 0                                    1.063796e+09
# 1                                    1.759618e+07
# 2                                    2.145118e+07
# 3                                    1.382421e+08
# 4                                    1.355372e+07
# ...                                           ...
# 11008008                             0.000000e+00
# 11009009                             0.000000e+00
# 11010010                             0.000000e+00
# 11011011                             0.000000e+00
# 11012012                             0.000000e+00
#
#           energy_industry_consumption_Erdgas_2009  \
# AGS
# 0                                     961175019.0
# 1                                      17799405.0
# 2                                      18353140.0
# 3                                     127744815.0
# 4                                      11043752.0
# ...                                           ...
# 11008008                                      0.0
# 11009009                                      0.0
# 11010010                                      0.0
# 11011011                                      0.0
# 11012012                                      0.0
#
#           energy_industry_consumption_Erdgas_2010  \
# AGS
# 0                                    1.083953e+09
# 1                                    2.159016e+07
# 2                                    2.125804e+07
# 3                                    1.380326e+08
# 4                                    1.261753e+07
# ...                                           ...
# 11008008                             0.000000e+00
# 11009009                             0.000000e+00
# 11010010                             0.000000e+00
# 11011011                             0.000000e+00
# 11012012                             0.000000e+00
#
#           energy_industry_consumption_Erdgas_2011  ...  \
# AGS                                                ...
# 0                                    1.075943e+09  ...
# 1                                    2.329601e+07  ...
# 2                                    1.908914e+07  ...
# 3                                    1.378759e+08  ...
# 4                                    1.202208e+07  ...
# ...                                           ...  ...
# 11008008                             0.000000e+00  ...
# 11009009                             0.000000e+00  ...
# 11010010                             0.000000e+00  ...
# 11011011                             0.000000e+00  ...
# 11012012                             0.000000e+00  ...
#
#           energy_industry_consumption_Anteil_Geheim_2013  \
# AGS
# 0                                               0.000000
# 1                                              18.313509
# 2                                               1.117061
# 3                                              31.274519
# 4                                               0.000000
# ...                                                  ...
# 11008008                                      100.000000
# 11009009                                      100.000000
# 11010010                                      100.000000
# 11011011                                      100.000000
# 11012012                                      100.000000
#
#           energy_industry_consumption_Anteil_Geheim_2014  \
# AGS
# 0                                               0.000000
# 1                                               8.378238
# 2                                               7.196770
# 3                                              33.558165
# 4                                              74.365769
# ...                                                  ...
# 11008008                                      100.000000
# 11009009                                      100.000000
# 11010010                                      100.000000
# 11011011                                      100.000000
# 11012012                                      100.000000
#
#           energy_industry_consumption_Anteil_Geheim_2015  \
# AGS
# 0                                               0.000000
# 1                                              10.422590
# 2                                               7.154508
# 3                                              31.015897
# 4                                              76.768027
# ...                                                  ...
# 11008008                                      100.000000
# 11009009                                      100.000000
# 11010010                                      100.000000
# 11011011                                      100.000000
# 11012012                                      100.000000
#
#           energy_industry_consumption_Anteil_Geheim_2016  \
# AGS
# 0                                               0.000000
# 1                                               6.825056
# 2                                               6.728502
# 3                                              35.914885
# 4                                              76.962388
# ...                                                  ...
# 11008008                                      100.000000
# 11009009                                      100.000000
# 11010010                                      100.000000
# 11011011                                      100.000000
# 11012012                                      100.000000
#
#           energy_industry_consumption_Anteil_Geheim_2017  \
# AGS
# 0                                               0.000000
# 1                                               0.000000
# 2                                              32.699227
# 3                                              34.860399
# 4                                              73.927717
# ...                                                  ...
# 11008008                                             NaN
# 11009009                                             NaN
# 11010010                                             NaN
# 11011011                                             NaN
# 11012012                                             NaN
#
#           energy_industry_consumption_Anteil_Geheim_2018  \
# AGS
# 0                                               0.000000
# 1                                              18.834137
# 2                                               2.399027
# 3                                              37.948640
# 4                                              76.230458
# ...                                                  ...
# 11008008                                             NaN
# 11009009                                             NaN
# 11010010                                             NaN
# 11011011                                             NaN
# 11012012                                             NaN
#
#           energy_industry_consumption_Anteil_Geheim_2019  \
# AGS
# 0                                               0.000000
# 1                                              18.773342
# 2                                              32.885934
# 3                                              37.972722
# 4                                              75.283260
# ...                                                  ...
# 11008008                                             NaN
# 11009009                                             NaN
# 11010010                                             NaN
# 11011011                                             NaN
# 11012012                                             NaN
#
#           energy_industry_consumption_Anteil_Geheim_2020  \
# AGS
# 0                                               0.000000
# 1                                              22.721961
# 2                                              32.488468
# 3                                              36.575043
# 4                                              75.190047
# ...                                                  ...
# 11008008                                             NaN
# 11009009                                             NaN
# 11010010                                             NaN
# 11011011                                             NaN
# 11012012                                             NaN
#
#           energy_industry_consumption_has_regional_data    Unit
# AGS
# 0                                                  True  GJoule
# 1                                                  True  GJoule
# 2                                                  True  GJoule
# 3                                                  True  GJoule
# 4                                                  True  GJoule
# ...                                                 ...     ...
# 11008008                                          False  GJoule
# 11009009                                          False  GJoule
# 11010010                                          False  GJoule
# 11011011                                          False  GJoule
# 11012012                                          False  GJoule
#
# [538 rows x 201 columns]

# %%
#save dataframe to file
piv_df.to_csv("data/final_data_landkreis_energy_industryenergy.csv")

# %%
## DATASNIPPET FOR TESTING

barnim = pivot[pivot.ort_ags == 10045]
barnim.drop(["ort_ags","ort_name","insgesamt"],axis= 1,inplace=True)

melt = pd.melt(barnim,id_vars=["Jahr"])
melt = melt.fillna(0)
melt['value']=pd.to_numeric(melt['value'])
melt = melt[melt["Energietyp"] != "Anteil_Erneuerbar"]

renewables = ["Wärme","Strom","Erneuerbare Energien"]
melt["Energiekategorie"] = np.where(melt.Energietyp.isin(renewables), 'renewable', 'fossil')
melt.to_csv("data/snippet/energy_industry_barnim.csv")
melt

barnim.to_csv("data/snippet/energy_industry_barnim_wide.csv")
melt
# Out:
# /var/folders/6w/mz49x3ds0b18vg8p9jx7wg0r0000gn/T/ipykernel_8804/52251844.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   barnim.drop(["ort_ags","ort_name","insgesamt"],axis= 1,inplace=True)
#      Jahr     Energietyp         value Energiekategorie
# 0    2003         Erdgas  2.104987e+06           fossil
# 1    2004         Erdgas  2.125962e+06           fossil
# 2    2005         Erdgas  2.205134e+06           fossil
# 3    2006         Erdgas  2.260986e+06           fossil
# 4    2007         Erdgas  2.217532e+06           fossil
# ..    ...            ...           ...              ...
# 115  2010  Anteil_Geheim  6.419762e+00           fossil
# 116  2011  Anteil_Geheim  7.445819e+00           fossil
# 117  2018  Anteil_Geheim  6.593957e+00           fossil
# 118  2019  Anteil_Geheim  0.000000e+00           fossil
# 119  2020  Anteil_Geheim  0.000000e+00           fossil
#
# [108 rows x 4 columns]
