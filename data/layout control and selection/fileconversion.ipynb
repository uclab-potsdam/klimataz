# %%
import pandas as pd;
# PATHS
# Changed structure for more legibility of sources
#agriculture (3)
agri1 = '../finaldata/la_final_data_bundesland_agriculture_animalcount.csv'
agri2 = '../finaldata/la_final_data_landkreis_agriculture_animalcount.csv'

#buildings (2)
bui1 = '../finaldata/ge_final_data_landkreis_newbuildings_renewables.csv'
bui2 = '../finaldata/ge_final_data_bundesland_heating.csv'

#mobility (3)
# mobi1 = '../finaldata/mo_final_data_landkreis_mobility_cartype.csv'
mobi2 = '../finaldata/mo_final_data_bundesland_mobility_mid.csv'
mobi3 = '../finaldata/mo_final_data_landkreis_mobility_fueltype.csv'

#waste (3)
was1 = '../finaldata/ab_final_data_landkreis_waste_organicwaste.csv'

#energy (3)
en1 = '../finaldata/en_final_data_bundesland_energy_primaryconsumption.csv'
en2 = '../finaldata/en_final_data_landkreis_energy_industryenergy.csv'

#combine all paths
paths = [mobi2,mobi3,agri2,agri1,bui1,bui2,en1,en2,was1]
paths
# Out:
# ['../finaldata/mo_final_data_bundesland_mobility_mid.csv',
#  '../finaldata/mo_final_data_landkreis_mobility_fueltype.csv',
#  '../finaldata/la_final_data_landkreis_agriculture_animalcount.csv',
#  '../finaldata/la_final_data_bundesland_agriculture_animalcount.csv',
#  '../finaldata/ge_final_data_landkreis_newbuildings_renewables.csv',
#  '../finaldata/ge_final_data_bundesland_heating.csv',
#  '../finaldata/en_final_data_bundesland_energy_primaryconsumption.csv',
#  '../finaldata/en_final_data_landkreis_energy_industryenergy.csv',
#  '../finaldata/ab_final_data_landkreis_waste_organicwaste.csv']

# %%
import json
import numpy as np
import os

#decision to split by lk, not by section, to have smaller slices of data 
#max slice of 5 section / 5 landkreise, min slice of 5 sections / 1 landkreis 
#not max slice of 5 sections / 400 landkreise, min slice of 1 section / 400 landkreise
            
#1001
    #ags
    #bundesland
    #score
    #En
        #score
        #primary_energy 
            #regional
            #data
            #benchmark
            #unit
        #industry
            #regional
            #data
            #benchmark
            #unit

#1. Create pipeline to fetch snippets of data for each location and indicator
#2. TODO: Define a hierarchy for indicators
#3. Create dynamic labels to differentiate datasets
#4. Check if regional data are available for each landkreis to store it as a parameter

sections={"mobility":"Mo","agriculture":"La","energy":"En","waste":"Ab","buildings":"Ge"}

def getDictionaryWithPrefix(df):
    #set index, condition to catch error in case AGS column is not defined
    if 'AGS' in df.columns:
        df.set_index('AGS',inplace=True)
    
    #fill nan with jsonable format
    df = df.fillna(np.nan).replace([np.nan], [None])
    
    #drop name column
    df.drop(columns=["Name"],axis=1,inplace=True)
    
    #get dynamic labels to differentiate datasets
    #get prefix
    columns = df.columns.tolist()
    #remove column Unit to avoid data mash-up (dirtydirty)
    if "Unit" in columns:
        columns.remove("Unit")
    prefix = os.path.commonprefix(columns)  
    print(prefix)
    #TODO: create hiearchy from prefixes
    section_eng = prefix.split('_')[0]
    section = sections[section_eng]

    #remove prefix from column names
    df.columns = df.columns.str.removeprefix(prefix)
    
    #remove section from prefix
    prefix = prefix.removeprefix(section_eng)

    #create dict from dataframe
    data_dict = df.T.to_dict('dict')
    
    return section,prefix,data_dict 


def generate_json(paths,last_year):

    landkreisData = {}

    indicators = []
    dicts = []
    indicator_sections = []
    
    #get current ags list from population data from regionalstatisik
    population = pd.read_csv("../general_data/population.csv",delimiter=";",encoding="latin1")
    population.rename({"1_Auspraegung_Code":"AGS"},axis=1,inplace=True)
    population["AGS"].replace({"DG":0},inplace=True)
    population["AGS"] = pd.to_numeric(population["AGS"])
    population["Zeit"] = population["Zeit"].str.replace(".","/",regex=True)
    population['Zeit'] =  pd.to_datetime(population['Zeit'],dayfirst=True)
    population['Jahr'] = population['Zeit'].dt.year

    #rows with no population data in some year before is changed ags
    changedAGS = population[(population.BEVSTD__Bevoelkerungsstand__Anzahl == "-") & (population.Jahr != last_year)].AGS.unique()
    currentAGS = population.AGS.unique() #only current AGS are counted in this dataset

    population["BEVSTD__Bevoelkerungsstand__Anzahl"] = population["BEVSTD__Bevoelkerungsstand__Anzahl"].replace("-",np.NaN,regex=True)
    units = []
    #pipeline to fetch snippets of data for each location and indicator
    for path in paths:
        #read dataset
        print(path)
        df = pd.read_csv(path)
        #check if ags is in list of current ags    
        #df = df[~df['AGS'].isin(currentAGS)]
        #append footnotes for lk if only new data exists
        
        #Check if unit is defined in the dataset 
        if "Unit" in df.columns.tolist():
            # If yes appends itself to array
            unitValue = df["Unit"][1]
            units.append(unitValue)
            df.drop('Unit', axis=1, inplace=True)
        else:
            # If no appends dummy to array
            units.append("not defined at source")
        
        
        section,prefix,data_dict = getDictionaryWithPrefix(df)
        indicators.append(prefix)
        indicator_sections.append(section)
        dicts.append(data_dict)

    print("indicator: ",indicators)

    for ort in currentAGS:
        ort = int(ort)
        footnote = ""
        
        #handle new landkreise
        if(ort in changedAGS):
            s = population[population.AGS == ort]
            #get first datapoint for each
            first = s.BEVSTD__Bevoelkerungsstand__Anzahl.first_valid_index()
            footnote = "Diesen Landkreis gibt es erst seit " + str(population.iloc[first].Jahr)
        
        if(ort == 15003):
            print(footnote)
        
        #store bundesland of each landkreis
        if(ort < 17):
            bundesland = ort
        elif ort > 1000:
            bundesland = int(str(ort)[:-3])  #store bundesland from ags
        else:
            print("not included: ",ort)
            pass

        #create top level data for each location
        landkreisData[str(ort)] = {
            'ags':ort,
            'bundesland':bundesland,
            'score':2,
            'footnote':footnote,
            'Mo':{},
            'La':{},
            'Ge':{},
            'En':{},
            'Ab':{},
            }

        data = {}
        
        #iterate over indicators
        for i,ind in enumerate(indicators):
            ind_section = indicator_sections[i]
            #print(ind,ind_section)
#             print(ort)
            if(ort in dicts[i]):
                local_data = [{"key":index ,"year":item[0][-4:],"column":item[0][:-5],"value":item[1]} for index,item in enumerate(dicts[i][ort].items())]
                print(local_data)
                #create one entry per indicator
                #Check if regional data are available for each landkreis to store it as a parameter
                #Gets unit of measure from array of units based on i
                data[ind] = {
                    'benchmark':200,
                    'regional': True if ort > 17 else False,
                    'unit': units[i],
                    'data':local_data
                }
            
            else:
                #TODO: add bundesland level to all indicators, so this is only false for landkreise
                data[ind] = {
                    'regional':False,
                }

            #add data entry to location level
            #landkreisData[str(ort)][ind] = "added data"
            landkreisData[str(ort)][ind_section][ind] = data[ind]
        

    with open('data.json', 'w', encoding='utf-8') as f:
        json.dump(landkreisData, f, ensure_ascii=False, indent=4)


generate_json(paths,2021)
# Out:
# ../finaldata/mo_final_data_bundesland_mobility_mid.csv
# ['not defined at source']
# mobility_mid_
# ../finaldata/mo_final_data_landkreis_mobility_fueltype.csv
# ['not defined at source', 'cars for 1000 inhabitants']
# mobility_fueltype_cardensity_
# ../finaldata/la_final_data_landkreis_agriculture_animalcount.csv
# ['not defined at source', 'cars for 1000 inhabitants', 'Anzahl']
# agriculture_animalcount_Anzahl_
# ../finaldata/la_final_data_bundesland_agriculture_animalcount.csv
# ['not defined at source', 'cars for 1000 inhabitants', 'Anzahl', 'GV pro Ha']
# agriculture_animalcount_bydensity_
# ../finaldata/ge_final_data_landkreis_newbuildings_renewables.csv
# ['not defined at source', 'cars for 1000 inhabitants', 'Anzahl', 'GV pro Ha', 'kWh pro m²']
# buildings_newbuilding_energy_
# ../finaldata/ge_final_data_bundesland_heating.csv
# ['not defined at source', 'cars for 1000 inhabitants', 'Anzahl', 'GV pro Ha', 'kWh pro m²', 'kWh pro m²']
# buildings_heating_20
# ../finaldata/en_final_data_bundesland_energy_primaryconsumption.csv
# ['not defined at source', 'cars for 1000 inhabitants', 'Anzahl', 'GV pro Ha', 'kWh pro m²', 'kWh pro m²', 'TJoule']
# energy_primaryconsumption_
# ../finaldata/en_final_data_landkreis_energy_industryenergy.csv
# ['not defined at source', 'cars for 1000 inhabitants', 'Anzahl', 'GV pro Ha', 'kWh pro m²', 'kWh pro m²', 'TJoule', 'Tsd. MJ']
# energy_industry_consumption_
# ../finaldata/ab_final_data_landkreis_waste_organicwaste.csv
# ['not defined at source', 'cars for 1000 inhabitants', 'Anzahl', 'GV pro Ha', 'kWh pro m²', 'kWh pro m²', 'TJoule', 'Tsd. MJ', 'Kg per person']
# waste_organicwaste_weight_
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [{'key': 0, 'year': '2010', 'column': 'Rinder', 'value': 0.0}, {'key': 1, 'year': '2016', 'column': 'Rinder', 'value': 0.0}, {'key': 2, 'year': '2020', 'column': 'Rinder', 'value': 0.0}, {'key': 3, 'year': '2010', 'column': 'Schafe', 'value': 0.0}, {'key': 4, 'year': '2016', 'column': 'Schafe', 'value': 0.0}, {'key': 5, 'year': '2020', 'column': 'Schafe', 'value': 0.0}, {'key': 6, 'year': '2010', 'column': 'Schweine', 'value': 0.0}, {'key': 7, 'year': '2016', 'column': 'Schweine', 'value': 0.0}, {'key': 8, 'year': '2020', 'column': 'Schweine', 'value': 0.0}]
# [{'key': 0, 'year': '2016', 'column': 'renewables', 'value': 0}, {'key': 1, 'year': '2017', 'column': 'renewables', 'value': 0}, {'key': 2, 'year': '2018', 'column': 'renewables', 'value': 0}, {'key': 3, 'year': '2019', 'column': 'renewables', 'value': 0}, {'key': 4, 'year': '2020', 'column': 'renewables', 'value': 0}, {'key': 5, 'year': '2016', 'column': 'fossils', 'value': 0}, {'key': 6, 'year': '2017', 'column': 'fossils', 'value': 0}, {'key': 7, 'year': '2018', 'column': 'fossils', 'value': 0}, {'key': 8, 'year': '2019', 'column': 'fossils', 'value': 0}, {'key': 9, 'year': '2020', 'column': 'fossils', 'value': 0}, {'key': 10, 'year': '2016', 'column': 'Solarthermie', 'value': 0}, {'key': 11, 'year': '2017', 'column': 'Solarthermie', 'value': 0}, {'key': 12, 'year': '2018', 'column': 'Solarthermie', 'value': 0}, {'key': 13, 'year': '2019', 'column': 'Solarthermie', 'value': 0}, {'key': 14, 'year': '2020', 'column': 'Solarthermie', 'value': 0}, {'key': 15, 'year': '2016', 'column': 'Geothermie', 'value': 0}, {'key': 16, 'year': '2017', 'column': 'Geothermie', 'value': 0}, {'key': 17, 'year': '2018', 'column': 'Geothermie', 'value': 0}, {'key': 18, 'year': '2019', 'column': 'Geothermie', 'value': 0}, {'key': 19, 'year': '2020', 'column': 'Geothermie', 'value': 0}, {'key': 20, 'year': '2016', 'column': 'Umweltthermie (Luft/Wasser)', 'value': 0}, {'key': 21, 'year': '2017', 'column': 'Umweltthermie (Luft/Wasser)', 'value': 0}, {'key': 22, 'year': '2018', 'column': 'Umweltthermie (Luft/Wasser)', 'value': 0}, {'key': 23, 'year': '2019', 'column': 'Umweltthermie (Luft/Wasser)', 'value': 0}, {'key': 24, 'year': '2020', 'column': 'Umweltthermie (Luft/Wasser)', 'value': 0}, {'key': 25, 'year': '2016', 'column': 'Holz', 'value': 0}, {'key': 26, 'year': '2017', 'column': 'Holz', 'value': 0}, {'key': 27, 'year': '2018', 'column': 'Holz', 'value': 0}, {'key': 28, 'year': '2019', 'column': 'Holz', 'value': 0}, {'key': 29, 'year': '2020', 'column': 'Holz', 'value': 0}, {'key': 30, 'year': '2016', 'column': 'Biogas/Biomethan', 'value': 0}, {'key': 31, 'year': '2017', 'column': 'Biogas/Biomethan', 'value': 0}, {'key': 32, 'year': '2018', 'column': 'Biogas/Biomethan', 'value': 0}, {'key': 33, 'year': '2019', 'column': 'Biogas/Biomethan', 'value': 0}, {'key': 34, 'year': '2020', 'column': 'Biogas/Biomethan', 'value': 0}, {'key': 35, 'year': '2016', 'column': 'Sonstige Biomasse', 'value': 0}, {'key': 36, 'year': '2017', 'column': 'Sonstige Biomasse', 'value': 0}, {'key': 37, 'year': '2018', 'column': 'Sonstige Biomasse', 'value': 0}, {'key': 38, 'year': '2019', 'column': 'Sonstige Biomasse', 'value': 0}, {'key': 39, 'year': '2020', 'column': 'Sonstige Biomasse', 'value': 0}, {'key': 40, 'year': '2016', 'column': 'Keine Energie (einschl. Passivhaus)', 'value': 0}, {'key': 41, 'year': '2017', 'column': 'Keine Energie (einschl. Passivhaus)', 'value': 0}, {'key': 42, 'year': '2018', 'column': 'Keine Energie (einschl. Passivhaus)', 'value': 0}, {'key': 43, 'year': '2019', 'column': 'Keine Energie (einschl. Passivhaus)', 'value': 0}, {'key': 44, 'year': '2020', 'column': 'Keine Energie (einschl. Passivhaus)', 'value': 0}, {'key': 45, 'year': '2016', 'column': 'Gas', 'value': 0}, {'key': 46, 'year': '2017', 'column': 'Gas', 'value': 0}, {'key': 47, 'year': '2018', 'column': 'Gas', 'value': 0}, {'key': 48, 'year': '2019', 'column': 'Gas', 'value': 0}, {'key': 49, 'year': '2020', 'column': 'Gas', 'value': 0}, {'key': 50, 'year': '2016', 'column': 'Strom', 'value': 0}, {'key': 51, 'year': '2017', 'column': 'Strom', 'value': 0}, {'key': 52, 'year': '2018', 'column': 'Strom', 'value': 0}, {'key': 53, 'year': '2019', 'column': 'Strom', 'value': 0}, {'key': 54, 'year': '2020', 'column': 'Strom', 'value': 0}, {'key': 55, 'year': '2016', 'column': 'Öl', 'value': 0}, {'key': 56, 'year': '2017', 'column': 'Öl', 'value': 0}, {'key': 57, 'year': '2018', 'column': 'Öl', 'value': 0}, {'key': 58, 'year': '2019', 'column': 'Öl', 'value': 0}, {'key': 59, 'year': '2020' ...
# [{'key': 0, 'year': '2003', 'column': 'Erdgas', 'value': 4556694.0}, {'key': 1, 'year': '2004', 'column': 'Erdgas', 'value': 5167417.0}, {'key': 2, 'year': '2005', 'column': 'Erdgas', 'value': 5305696.0}, {'key': 3, 'year': '2006', 'column': 'Erdgas', 'value': 5620803.0}, {'key': 4, 'year': '2007', 'column': 'Erdgas', 'value': 5522891.0}, {'key': 5, 'year': '2008', 'column': 'Erdgas', 'value': 0.0}, {'key': 6, 'year': '2009', 'column': 'Erdgas', 'value': 0.0}, {'key': 7, 'year': '2010', 'column': 'Erdgas', 'value': 0.0}, {'key': 8, 'year': '2011', 'column': 'Erdgas', 'value': 0.0}, {'key': 9, 'year': '2012', 'column': 'Erdgas', 'value': 0.0}, {'key': 10, 'year': '2013', 'column': 'Erdgas', 'value': 0.0}, {'key': 11, 'year': '2014', 'column': 'Erdgas', 'value': 0.0}, {'key': 12, 'year': '2015', 'column': 'Erdgas', 'value': 0.0}, {'key': 13, 'year': '2016', 'column': 'Erdgas', 'value': 0.0}, {'key': 14, 'year': '2017', 'column': 'Erdgas', 'value': 0.0}, {'key': 15, 'year': '2018', 'column': 'Erdgas', 'value': 0.0}, {'key': 16, 'year': '2019', 'column': 'Erdgas', 'value': 0.0}, {'key': 17, 'year': '2020', 'column': 'Erdgas', 'value': 0.0}, {'key': 18, 'year': '2003', 'column': 'Erneuerbare Energien', 'value': None}, {'key': 19, 'year': '2004', 'column': 'Erneuerbare Energien', 'value': None}, {'key': 20, 'year': '2005', 'column': 'Erneuerbare Energien', 'value': None}, {'key': 21, 'year': '2006', 'column': 'Erneuerbare Energien', 'value': 1091706.0}, {'key': 22, 'year': '2007', 'column': 'Erneuerbare Energien', 'value': 1184267.0}, {'key': 23, 'year': '2008', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 24, 'year': '2009', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 25, 'year': '2010', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 26, 'year': '2011', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 27, 'year': '2012', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 28, 'year': '2013', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 29, 'year': '2014', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 30, 'year': '2015', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 31, 'year': '2016', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 32, 'year': '2017', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 33, 'year': '2018', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 34, 'year': '2019', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 35, 'year': '2020', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 36, 'year': '2003', 'column': 'Heizöl', 'value': 420082.0}, {'key': 37, 'year': '2004', 'column': 'Heizöl', 'value': 377526.0}, {'key': 38, 'year': '2005', 'column': 'Heizöl', 'value': 197393.0}, {'key': 39, 'year': '2006', 'column': 'Heizöl', 'value': 124521.0}, {'key': 40, 'year': '2007', 'column': 'Heizöl', 'value': 75816.0}, {'key': 41, 'year': '2008', 'column': 'Heizöl', 'value': 0.0}, {'key': 42, 'year': '2009', 'column': 'Heizöl', 'value': 0.0}, {'key': 43, 'year': '2010', 'column': 'Heizöl', 'value': 0.0}, {'key': 44, 'year': '2011', 'column': 'Heizöl', 'value': 0.0}, {'key': 45, 'year': '2012', 'column': 'Heizöl', 'value': 0.0}, {'key': 46, 'year': '2013', 'column': 'Heizöl', 'value': 0.0}, {'key': 47, 'year': '2014', 'column': 'Heizöl', 'value': 0.0}, {'key': 48, 'year': '2015', 'column': 'Heizöl', 'value': 0.0}, {'key': 49, 'year': '2016', 'column': 'Heizöl', 'value': 0.0}, {'key': 50, 'year': '2017', 'column': 'Heizöl', 'value': 0.0}, {'key': 51, 'year': '2018', 'column': 'Heizöl', 'value': 0.0}, {'key': 52, 'year': '2019', 'column': 'Heizöl', 'value': 0.0}, {'key': 53, 'year': '2020', 'column': 'Heizöl', 'value': 0.0}, {'key': 54, 'year': '2003', 'column': 'Kohle', 'value': 0.0}, {'key': 55, 'year': '2004', 'column': 'Kohle', 'value': 0.0}, {'key': 56, 'year': '2005', 'column': 'Kohle', 'value': 0.0}, {'key': 57, 'year': '2006', 'column': 'Kohle', 'value': None}, {'key': 58, 'year': '2007', 'column': ...
# [{'key': 0, 'year': '2004', 'column': 'biotonne', 'value': 0.0}, {'key': 1, 'year': '2005', 'column': 'biotonne', 'value': 0.0}, {'key': 2, 'year': '2006', 'column': 'biotonne', 'value': 0.0}, {'key': 3, 'year': '2007', 'column': 'biotonne', 'value': 0.0}, {'key': 4, 'year': '2008', 'column': 'biotonne', 'value': 0.0}, {'key': 5, 'year': '2009', 'column': 'biotonne', 'value': 0.0}, {'key': 6, 'year': '2010', 'column': 'biotonne', 'value': 0.0}, {'key': 7, 'year': '2011', 'column': 'biotonne', 'value': 0.0}, {'key': 8, 'year': '2012', 'column': 'biotonne', 'value': 0.0}, {'key': 9, 'year': '2013', 'column': 'biotonne', 'value': 0.0}, {'key': 10, 'year': '2014', 'column': 'biotonne', 'value': 0.0}, {'key': 11, 'year': '2015', 'column': 'biotonne', 'value': 0.0}, {'key': 12, 'year': '2016', 'column': 'biotonne', 'value': 0.0}, {'key': 13, 'year': '2017', 'column': 'biotonne', 'value
, {'key': 57, 'year': '2006', 'column': 'Kohle', 'value': None}, {'key': 58, 'year': '2007', 'column': 'Kohle', 'value ...
# [{'key': 0, 'year': '2004', 'column': 'biotonne', 'value': 0.0}, {'key': 1, 'year': '2005', 'column': 'biotonne', 'value': 0.0}, {'key': 2, 'year': '2006', 'column': 'biotonne', 'value': 0.0}, {'key': 3, 'year': '2007', 'column': 'biotonne', 'value': 0.0}, {'key': 4, 'year': '2008', 'column': 'biotonne', 'value': 0.0}, {'key': 5, 'year': '2009', 'column': 'biotonne', 'value': 0.0}, {'key': 6, 'year': '2010', 'column': 'biotonne', 'value': 0.0}, {'key': 7, 'year': '2011', 'column': 'biotonne', 'value': 0.0}, {'key': 8, 'year': '2012', 'column': 'biotonne', 'value': 0.0}, {'key': 9, 'year': '2013', 'column': 'biotonne', 'value': 0.0}, {'key': 10, 'year': '2014', 'column': 'biotonne', 'value': 0.0}, {'key': 11, 'year': '2015', 'column': 'biotonne', 'value': 0.0}, {'key': 12, 'year': '2016', 'column': 'biotonne', 'value': 0.0}, {'key': 13, 'year': '2017', 'column': 'biotonne', 'value': 0.0}, {'key': 14, 'year': '2018', 'column': 'biotonne', 'value': 0.0}, {'key': 15, 'year': '2019', 'column': 'biotonne', 'value': 0.0}, {'key': 16, 'year': '2020', 'column': 'biotonne', 'value': 0.0}, {'key': 17, 'year': '2004', 'column': 'gartenPark', 'value': 0.0}, {'key': 18, 'year': '2005', 'column': 'gartenPark', 'value': 0.0}, {'key': 19, 'year': '2006', 'column': 'gartenPark', 'value': 0.0}, {'key': 20, 'year': '2007', 'column': 'gartenPark', 'value': 0.0}, {'key': 21, 'year': '2008', 'column': 'gartenPark', 'value': 0.0}, {'key': 22, 'year': '2009', 'column': 'gartenPark', 'value': 0.0}, {'key': 23, 'year': '2010', 'column': 'gartenPark', 'value': 0.0}, {'key': 24, 'year': '2011', 'column': 'gartenPark', 'value': 0.0}, {'key': 25, 'year': '2012', 'column': 'gartenPark', 'value': 0.0}, {'key': 26, 'year': '2013', 'column': 'gartenPark', 'value': 0.0}, {'key': 27, 'year': '2014', 'column': 'gartenPark', 'value': 0.0}, {'key': 28, 'year': '2015', 'column': 'gartenPark', 'value': 0.0}, {'key': 29, 'year': '2016', 'column': 'gartenPark', 'value': 0.0}, {'key': 30, 'year': '2017', 'column': 'gartenPark', 'value': 0.0}, {'key': 31, 'year': '2018', 'column': 'gartenPark', 'value': 0.0}, {'key': 32, 'year': '2019', 'column': 'gartenPark', 'value': 0.0}, {'key': 33, 'year': '2020', 'column': 'gartenPark', 'value': 0.0}, {'key': 34, 'year': '2004', 'column': 'sum', 'value': 0.0}, {'key': 35, 'year': '2005', 'column': 'sum', 'value': 0.0}, {'key': 36, 'year': '2006', 'column': 'sum', 'value': 0.0}, {'key': 37, 'year': '2007', 'column': 'sum', 'value': 0.0}, {'key': 38, 'year': '2008', 'column': 'sum', 'value': 0.0}, {'key': 39, 'year': '2009', 'column': 'sum', 'value': 1266.0}, {'key': 40, 'year': '2010', 'column': 'sum', 'value': 0.0}, {'key': 41, 'year': '2011', 'column': 'sum', 'value': 0.0}, {'key': 42, 'year': '2012', 'column': 'sum', 'value': 0.0}, {'key': 43, 'year': '2013', 'column': 'sum', 'value': 0.0}, {'key': 44, 'year': '2014', 'column': 'sum', 'value': 0.0}, {'key': 45, 'year': '2015', 'column': 'sum', 'value': 0.0}, {'key': 46, 'year': '2016', 'column': 'sum', 'value': 0.0}, {'key': 47, 'year': '2017', 'column': 'sum', 'value': 0.0}, {'key': 48, 'year': '2018', 'column': 'sum', 'value': 0.0}, {'key': 49, 'year': '2019', 'column': 'sum', 'value': 0.0}, {'key': 50, 'year': '2020', 'column': 'sum', 'value': 0.0}]
# [{'key': 0, 'year': '2010', 'column': 'Rinder', 'value': 0.0}, {'key': 1, 'year': '2016', 'column': 'Rinder', 'value': 0.0}, {'key': 2, 'year': '2020', 'column': 'Rinder', 'value': 0.0}, {'key': 3, 'year': '2010', 'column': 'Schafe', 'value': 0.0}, {'key': 4, 'year': '2016', 'column': 'Schafe', 'value': 0.0}, {'key': 5, 'year': '2020', 'column': 'Schafe', 'value': 0.0}, {'key': 6, 'year': '2010', 'column': 'Schweine', 'value': 0.0}, {'key': 7, 'year': '2016', 'column': 'Schweine', 'value': 0.0}, {'key': 8, 'year': '2020', 'column': 'Schweine', 'value': 0.0}]
# [{'key': 0, 'year': '2016', 'column': 'renewables', 'value': 0}, {'key': 1, 'year': '2017', 'column': 'renewables', 'value': 0}, {'key': 2, 'year': '2018', 'column': 'renewables', 'value': 0}, {'key': 3, 'year': '2019', 'column': 'renewables', 'value': 0}, {'key': 4, 'year': '2020', 'column': 'renewables', 'value': 0}, {'key': 5, 'year': '2016', 'column': 'fossils', 'value': 0}, {'key': 6, 'year': '2017', 'column': 'fossils', 'value': 0}, {'key': 7, 'year': '2018', 'column': 'fossils', 'value': 0}, {'key': 8, 'year': '2019', 'column': 'fossils', 'value': 0}, {'key': 9, 'year': '2020', 'column': 'fossils', 'value': 0}, {'key': 10, 'year': '2016', 'column': 'Solarthermie', 'value': 0}, {'key': 11, 'year': '2017', 'column': 'Solarthermie', 'value': 0}, {'key': 12, 'year': '2018', 'column': 'Solarthermie', 'value': 0}, {'key': 13, 'year': '2019', 'column': 'Solarthermie', 'value': 0}, {'key': 14, 'year': '2020', 'column': 'Solarthermie', 'value': 0}, {'key': 15, 'year': '2016', 'column': 'Geothermie', 'value': 0}, {'key': 16, 'year': '2017', 'column': 'Geothermie', 'value': 0}, {'key': 17, 'year': '2018', 'column': 'Geothermie', 'value': 0}, {'key': 18, 'year': '2019', 'column': 'Geothermie', 'value': 0}, {'key': 19, 'year': '2020', 'column': 'Geothermie', 'value': 0}, {'key': 20, 'year': '2016', 'column': 'Umweltthermie (Luft/Wasser)', 'value': 0}, {'key': 21, 'year': '2017', 'column': 'Umweltthermie (Luft/Wasser)', 'value': 0}, {'key': 22, 'year': '2018', 'column': 'Umweltthermie (Luft/Wasser)', 'value': 0}, {'key': 23, 'year': '2019', 'column': 'Umweltthermie (Luft/Wasser)', 'value': 0}, {'key': 24, 'year': '2020', 'column': 'Umweltthermie (Luft/Wasser)', 'value': 0}, {'key': 25, 'year': '2016', 'column': 'Holz', 'value': 0}, {'key': 26, 'year': '2017', 'column': 'Holz', 'value': 0}, {'key': 27, 'year': '2018', 'column': 'Holz', 'value': 0}, {'key': 28, 'year': '2019', 'column': 'Holz', 'value': 0}, {'key': 29, 'year': '2020', 'column': 'Holz', 'value': 0}, {'key': 30, 'year': '2016', 'column': 'Biogas/Biomethan', 'value': 0}, {'key': 31, 'year': '2017', 'column': 'Biogas/Biomethan', 'value': 0}, {'key': 32, 'year': '2018', 'column': 'Biogas/Biomethan', 'value': 0}, {'key': 33, 'year': '2019', 'column': 'Biogas/Biomethan', 'value': 0}, {'key': 34, 'year': '2020', 'column': 'Biogas/Biomethan', 'value': 0}, {'key': 35, 'year': '2016', 'column': 'Sonstige Biomasse', 'value': 0}, {'key': 36, 'year': '2017', 'column': 'Sonstige Biomasse', 'value': 0}, {'key': 37, 'year': '2018', 'column': 'Sonstige Biomasse', 'value': 0}, {'key': 38, 'year': '2019', 'column': 'Sonstige Biomasse', 'value': 0}, {'key': 39, 'year': '2020', 'column': 'Sonstige Biomasse', 'value': 0}, {'key': 40, 'year': '2016', 'column': 'Keine Energie (einschl. Passivhaus)', 'value': 0}, {'key': 41, 'year': '2017', 'column': 'Keine Energie (einschl. Passivhaus)', 'value': 0}, {'key': 42, 'year': '2018', 'column': 'Keine Energie (einschl. Passivhaus)', 'value': 0}, {'key': 43, 'year': '2019', 'column': 'Keine Energie (einschl. Passivhaus)', 'value': 0}, {'key': 44, 'year': '2020', 'column': 'Keine Energie (einschl. Passivhaus)', 'value': 0}, {'key': 45, 'year': '2016', 'column': 'Gas', 'value': 0}, {'key': 46, 'year': '2017', 'column': 'Gas', 'value': 0}, {'key': 47, 'year': '2018', 'column': 'Gas', 'value': 0}, {'key': 48, 'year': '2019', 'column': 'Gas', 'value': 0}, {'key': 49, 'year': '2020', 'column': 'Gas', 'value': 0}, {'key': 50, 'year': '2016', 'column': 'Strom', 'value': 0}, {'key': 51, 'year': '2017', 'column': 'Strom', 'value': 0}, {'key': 52, 'year': '2018', 'column': 'Strom', 'value': 0}, {'key': 53, 'year': '2019', 'column': 'Strom', 'value': 0}, {'key': 54, 'year': '2020', 'column': 'Strom', 'value': 0}, {'key': 55, 'year': '2016', 'column': 'Öl', 'value': 0}, {'key': 56, 'year': '2017', 'column': 'Öl', 'value': 0}, {'key': 57, 'year': '2018', 'column': 'Öl', 'value': 0}, {'key': 58, 'year': '2019', 'column': 'Öl', 'value': 0}, {'key': 59, 'year': '2020' ...
# [{'key': 0, 'year': '2003', 'column': 'Erdgas', 'value': 1190056.0}, {'key': 1, 'year': '2004', 'column': 'Erdgas', 'value': 1317240.0}, {'key': 2, 'year': '2005', 'column': 'Erdgas', 'value': 1385707.0}, {'key': 3, 'year': '2006', 'column': 'Erdgas', 'value': 1319885.0}, {'key': 4, 'year': '2007', 'column': 'Erdgas', 'value': 1449110.0}, {'key': 5, 'year': '2008', 'column': 'Erdgas', 'value': 0.0}, {'key': 6, 'year': '2009', 'column': 'Erdgas', 'value': 0.0}, {'key': 7, 'year': '2010', 'column': 'Erdgas', 'value': 0.0}, {'key': 8, 'year': '2011', 'column': 'Erdgas', 'value': 0.0}, {'key': 9, 'year': '2012', 'column': 'Erdgas', 'value': 0.0}, {'key': 10, 'year': '2013', 'column': 'Erdgas', 'value': 0.0}, {'key': 11, 'year': '2014', 'column': 'Erdgas', 'value': 0.0}, {'key': 12, 'year': '2015', 'column': 'Erdgas', 'value': 0.0}, {'key': 13, 'year': '2016', 'column': 'Erdgas', 'value': 0.0}, {'key': 14, 'year': '2017', 'column': 'Erdgas', 'value': 0.0}, {'key': 15, 'year': '2018', 'column': 'Erdgas', 'value': 0.0}, {'key': 16, 'year': '2019', 'column': 'Erdgas', 'value': 0.0}, {'key': 17, 'year': '2020', 'column': 'Erdgas', 'value': 0.0}, {'key': 18, 'year': '2003', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 19, 'year': '2004', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 20, 'year': '2005', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 21, 'year': '2006', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 22, 'year': '2007', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 23, 'year': '2008', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 24, 'year': '2009', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 25, 'year': '2010', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 26, 'year': '2011', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 27, 'year': '2012', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 28, 'year': '2013', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 29, 'year': '2014', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 30, 'year': '2015', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 31, 'year': '2016', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 32, 'year': '2017', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 33, 'year': '2018', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 34, 'year': '2019', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 35, 'year': '2020', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 36, 'year': '2003', 'column': 'Heizöl', 'value': 59070.0}, {'key': 37, 'year': '2004', 'column': 'Heizöl', 'value': 45122.0}, {'key': 38, 'year': '2005', 'column': 'Heizöl', 'value': 43670.0}, {'key': 39, 'year': '2006', 'column': 'Heizöl', 'value': 40289.0}, {'key': 40, 'year': '2007', 'column': 'Heizöl', 'value': 43518.0}, {'key': 41, 'year': '2008', 'column': 'Heizöl', 'value': 0.0}, {'key': 42, 'year': '2009', 'column': 'Heizöl', 'value': 0.0}, {'key': 43, 'year': '2010', 'column': 'Heizöl', 'value': 0.0}, {'key': 44, 'year': '2011', 'column': 'Heizöl', 'value': 0.0}, {'key': 45, 'year': '2012', 'column': 'Heizöl', 'value': 0.0}, {'key': 46, 'year': '2013', 'column': 'Heizöl', 'value': 0.0}, {'key': 47, 'year': '2014', 'column': 'Heizöl', 'value': 0.0}, {'key': 48, 'year': '2015', 'column': 'Heizöl', 'value': 0.0}, {'key': 49, 'year': '2016', 'column': 'Heizöl', 'value': 0.0}, {'key': 50, 'year': '2017', 'column': 'Heizöl', 'value': 0.0}, {'key': 51, 'year': '2018', 'column': 'Heizöl', 'value': 0.0}, {'key': 52, 'year': '2019', 'column': 'Heizöl', 'value': 0.0}, {'key': 53, 'year': '2020', 'column': 'Heizöl', 'value': 0.0}, {'key': 54, 'year': '2003', 'column': 'Kohle', 'value': None}, {'key': 55, 'year': '2004', 'column': 'Kohle', 'value': None}, {'key': 56, 'year': '2005', 'column': 'Kohle', 'value': None}, {'key': 57, 'year': '2006', 'column': 'Kohle', 'value': None}, {'key': 58, 'year': '2007', 'column': 'Kohle', 'value ...
# ...
# [{'key': 0, 'year': '2020', 'column': 'Gesamt', 'value': 582.3373624881162}, {'key': 1, 'year': '2021', 'column': 'Gesamt', 'value': 587.4702472468026}, {'key': 2, 'year': '2020', 'column': 'Fossils', 'value': 577.8554936846394}, {'key': 3, 'year': '2021', 'column': 'Fossils', 'value': 577.1977177218217}, {'key': 4, 'year': '2020', 'column': 'Benzin', 'value': 429.1728914844493}, {'key': 5, 'year': '2021', 'column': 'Benzin', 'value': 426.3555297413646}, {'key': 6, 'year': '2020', 'column': 'Diesel', 'value': 144.2007333967133}, {'key': 7, 'year': '2021', 'column': 'Diesel', 'value': 146.73089844773196}, {'key': 8, 'year': '2020', 'column': 'Gas (einschl. bivalent)', 'value': 4.481868803476844}, {'key': 9, 'year': '2021', 'column': 'Gas (einschl. bivalent)', 'value': 4.1112895327251815}, {'key': 10, 'year': '2020', 'column': 'Elektro', 'value': 0.6337996287745031}, {'key': 11, 'year': '2021', 'column': 'Elektro', 'value': 1.252747503046454}, {'key': 12, 'year': '2020', 'column': 'Hybrid', 'value': 3.644347865453393}, {'key': 13, 'year': '2021', 'column': 'Hybrid', 'value': 8.871730044301707}, {'key': 14, 'year': '2020', 'column': 'sonstige Kraftstoffarten', 'value': 0.2037213092489474}, {'key': 15, 'year': '2021', 'column': 'sonstige Kraftstoffarten', 'value': 0.1480519776327627}]
# [{'key': 0, 'year': '2010', 'column': 'Rinder', 'value': 13797.0}, {'key': 1, 'year': '2016', 'column': 'Rinder', 'value': 36733.0}, {'key': 2, 'year': '2020', 'column': 'Rinder', 'value': 1502.0}, {'key': 3, 'year': '2010', 'column': 'Schafe', 'value': 12381.0}, {'key': 4, 'year': '2016', 'column': 'Schafe', 'value': 31199.0}, {'key': 5, 'year': '2020', 'column': 'Schafe', 'value': 825.0}, {'key': 6, 'year': '2010', 'column': 'Schweine', 'value': 12050.0}, {'key': 7, 'year': '2016', 'column': 'Schweine', 'value': 29186.0}, {'key': 8, 'year': '2020', 'column': 'Schweine', 'value': 1173.0}]
# [{'key': 0, 'year': '2016', 'column': 'renewables', 'value': 21}, {'key': 1, 'year': '2017', 'column': 'renewables', 'value': 34}, {'key': 2, 'year': '2018', 'column': 'renewables', 'value': 35}, {'key': 3, 'year': '2019', 'column': 'renewables', 'value': 22}, {'key': 4, 'year': '2020', 'column': 'renewables', 'value': 34}, {'key': 5, 'year': '2016', 'column': 'fossils', 'value': 80}, {'key': 6, 'year': '2017', 'column': 'fossils', 'value': 34}, {'key': 7, 'year': '2018', 'column': 'fossils', 'value': 37}, {'key': 8, 'year': '2019', 'column': 'fossils', 'value': 136}, {'key': 9, 'year': '2020', 'column': 'fossils', 'value': 103}, {'key': 10, 'year': '2016', 'column': 'Solarthermie', 'value': 1}, {'key': 11, 'year': '2017', 'column': 'Solarthermie', 'value': 2}, {'key': 12, 'year': '2018', 'column': 'Solarthermie', 'value': 0}, {'key': 13, 'year': '2019', 'column': 'Solarthermie', 'value': 1}, {'key': 14, 'year': '2020', 'column': 'Solarthermie', 'value': 0}, {'key': 15, 'year': '2016', 'column': 'Geothermie', 'value': 6}, {'key': 16, 'year': '2017', 'column': 'Geothermie', 'value': 6}, {'key': 17, 'year': '2018', 'column': 'Geothermie', 'value': 9}, {'key': 18, 'year': '2019', 'column': 'Geothermie', 'value': 3}, {'key': 19, 'year': '2020', 'column': 'Geothermie', 'value': 9}, {'key': 20, 'year': '2016', 'column': 'Umweltthermie (Luft/Wasser)', 'value': 13}, {'key': 21, 'year': '2017', 'column': 'Umweltthermie (Luft/Wasser)', 'value': 21}, {'key': 22, 'year': '2018', 'column': 'Umweltthermie (Luft/Wasser)', 'value': 24}, {'key': 23, 'year': '2019', 'column': 'Umweltthermie (Luft/Wasser)', 'value': 17}, {'key': 24, 'year': '2020', 'column': 'Umweltthermie (Luft/Wasser)', 'value': 24}, {'key': 25, 'year': '2016', 'column': 'Holz', 'value': 0}, {'key': 26, 'year': '2017', 'column': 'Holz', 'value': 4}, {'key': 27, 'year': '2018', 'column': 'Holz', 'value': 2}, {'key': 28, 'year': '2019', 'column': 'Holz', 'value': 1}, {'key': 29, 'year': '2020', 'column': 'Holz', 'value': 1}, {'key': 30, 'year': '2016', 'column': 'Biogas/Biomethan', 'value': 0}, {'key': 31, 'year': '2017', 'column': 'Biogas/Biomethan', 'value': 0}, {'key': 32, 'year': '2018', 'column': 'Biogas/Biomethan', 'value': 0}, {'key': 33, 'year': '2019', 'column': 'Biogas/Biomethan', 'value': 0}, {'key': 34, 'year': '2020', 'column': 'Biogas/Biomethan', 'value': 0}, {'key': 35, 'year': '2016', 'column': 'Sonstige Biomasse', 'value': 1}, {'key': 36, 'year': '2017', 'column': 'Sonstige Biomasse', 'value': 1}, {'key': 37, 'year': '2018', 'column': 'Sonstige Biomasse', 'value': 0}, {'key': 38, 'year': '2019', 'column': 'Sonstige Biomasse', 'value': 0}, {'key': 39, 'year': '2020', 'column': 'Sonstige Biomasse', 'value': 0}, {'key': 40, 'year': '2016', 'column': 'Keine Energie (einschl. Passivhaus)', 'value': 0}, {'key': 41, 'year': '2017', 'column': 'Keine Energie (einschl. Passivhaus)', 'value': 0}, {'key': 42, 'year': '2018', 'column': 'Keine Energie (einschl. Passivhaus)', 'value': 0}, {'key': 43, 'year': '2019', 'column': 'Keine Energie (einschl. Passivhaus)', 'value': 0}, {'key': 44, 'year': '2020', 'column': 'Keine Energie (einschl. Passivhaus)', 'value': 0}, {'key': 45, 'year': '2016', 'column': 'Gas', 'value': 77}, {'key': 46, 'year': '2017', 'column': 'Gas', 'value': 31}, {'key': 47, 'year': '2018', 'column': 'Gas', 'value': 26}, {'key': 48, 'year': '2019', 'column': 'Gas', 'value': 24}, {'key': 49, 'year': '2020', 'column': 'Gas', 'value': 101}, {'key': 50, 'year': '2016', 'column': 'Strom', 'value': 0}, {'key': 51, 'year': '2017', 'column': 'Strom', 'value': 0}, {'key': 52, 'year': '2018', 'column': 'Strom', 'value': 6}, {'key': 53, 'year': '2019', 'column': 'Strom', 'value': 1}, {'key': 54, 'year': '2020', 'column': 'Strom', 'value': 1}, {'key': 55, 'year': '2016', 'column': 'Öl', 'value': 0}, {'key': 56, 'year': '2017', 'column': 'Öl', 'value': 0}, {'key': 57, 'year': '2018', 'column': 'Öl', 'value': 0}, {'key': 58, 'year': '2019', 'column': 'Öl', 'value': 1}, {'k ...
# [{'key': 0, 'year': '2003', 'column': 'Erdgas', 'value': 240813.0}, {'key': 1, 'year': '2004', 'column': 'Erdgas', 'value': 255737.0}, {'key': 2, 'year': '2005', 'column': 'Erdgas', 'value': 257623.0}, {'key': 3, 'year': '2006', 'column': 'Erdgas', 'value': 624921.0}, {'key': 4, 'year': '2007', 'column': 'Erdgas', 'value': 688703.0}, {'key': 5, 'year': '2008', 'column': 'Erdgas', 'value': 348654.0}, {'key': 6, 'year': '2009', 'column': 'Erdgas', 'value': 366252.0}, {'key': 7, 'year': '2010', 'column': 'Erdgas', 'value': 439740.0}, {'key': 8, 'year': '2011', 'column': 'Erdgas', 'value': 394340.0}, {'key': 9, 'year': '2012', 'column': 'Erdgas', 'value': 368905.0}, {'key': 10, 'year': '2013', 'column': 'Erdgas', 'value': 349410.0}, {'key': 11, 'year': '2014', 'column': 'Erdgas', 'value': 306252.0}, {'key': 12, 'year': '2015', 'column': 'Erdgas', 'value': 342868.0}, {'key': 13, 'year': '2016', 'column': 'Erdgas', 'value': 366987.0}, {'key': 14, 'year': '2017', 'column': 'Erdgas', 'value': 362650.0}, {'key': 15, 'year': '2018', 'column': 'Erdgas', 'value': 347058.0}, {'key': 16, 'year': '2019', 'column': 'Erdgas', 'value': 365585.0}, {'key': 17, 'year': '2020', 'column': 'Erdgas', 'value': 349691.0}, {'key': 18, 'year': '2003', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 19, 'year': '2004', 'column': 'Erneuerbare Energien', 'value': None}, {'key': 20, 'year': '2005', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 21, 'year': '2006', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 22, 'year': '2007', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 23, 'year': '2008', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 24, 'year': '2009', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 25, 'year': '2010', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 26, 'year': '2011', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 27, 'year': '2012', 'column': 'Erneuerbare Energien', 'value': None}, {'key': 28, 'year': '2013', 'column': 'Erneuerbare Energien', 'value': None}, {'key': 29, 'year': '2014', 'column': 'Erneuerbare Energien', 'value': None}, {'key': 30, 'year': '2015', 'column': 'Erneuerbare Energien', 'value': None}, {'key': 31, 'year': '2016', 'column': 'Erneuerbare Energien', 'value': None}, {'key': 32, 'year': '2017', 'column': 'Erneuerbare Energien', 'value': None}, {'key': 33, 'year': '2018', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 34, 'year': '2019', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 35, 'year': '2020', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 36, 'year': '2003', 'column': 'Heizöl', 'value': 88692.0}, {'key': 37, 'year': '2004', 'column': 'Heizöl', 'value': 99830.0}, {'key': 38, 'year': '2005', 'column': 'Heizöl', 'value': 92802.0}, {'key': 39, 'year': '2006', 'column': 'Heizöl', 'value': 112969.0}, {'key': 40, 'year': '2007', 'column': 'Heizöl', 'value': 103685.0}, {'key': 41, 'year': '2008', 'column': 'Heizöl', 'value': 110084.0}, {'key': 42, 'year': '2009', 'column': 'Heizöl', 'value': 87039.0}, {'key': 43, 'year': '2010', 'column': 'Heizöl', 'value': 59859.0}, {'key': 44, 'year': '2011', 'column': 'Heizöl', 'value': 64328.0}, {'key': 45, 'year': '2012', 'column': 'Heizöl', 'value': 53217.0}, {'key': 46, 'year': '2013', 'column': 'Heizöl', 'value': 50047.0}, {'key': 47, 'year': '2014', 'column': 'Heizöl', 'value': 46935.0}, {'key': 48, 'year': '2015', 'column': 'Heizöl', 'value': 50451.0}, {'key': 49, 'year': '2016', 'column': 'Heizöl', 'value': 43101.0}, {'key': 50, 'year': '2017', 'column': 'Heizöl', 'value': 41589.0}, {'key': 51, 'year': '2018', 'column': 'Heizöl', 'value': 40064.0}, {'key': 52, 'year': '2019', 'column': 'Heizöl', 'value': 52241.0}, {'key': 53, 'year': '2020', 'column': 'Heizöl', 'value': 29746.0}, {'key': 54, 'year': '2003', 'column': 'Kohle', 'value': 0.0}, {'key': 55, 'year': '2004', 'column': 'Kohle', 'value': 0.0}, {'key': 56, 'year': '2005', 'column': 'Kohle', 'value': 0.0 ...
# [{'key': 0, 'year': '2004', 'column': 'biotonne', 'value': 13470.0}, {'key': 1, 'year': '2005', 'column': 'biotonne', 'value': 5606.0}, {'key': 2, 'year': '2006', 'column': 'biotonne', 'value': 7863.0}, {'key': 3, 'year': '2007', 'column': 'biotonne', 'value': 14205.0}, {'key': 4, 'year': '2008', 'column': 'biotonne', 'value': 5434.0}, {'key': 5, 'year': '2009', 'column': 'biotonne', 'value': 8771.0}, {'key': 6, 'year': '2010', 'column': 'biotonne', 'value': 12971.0}, {'key': 7, 'year': '2011', 'column': 'biotonne', 'value': 5255.0}, {'key': 8, 'year': '2012', 'column': 'biotonne', 'value': 7716.0}, {'key': 9, 'year': '2013', 'column': 'biotonne', 'value': 14383.0}, {'key': 10, 'year': '2014', 'column': 'biotonne', 'value': 5015.0}, {'key': 11, 'year': '2015', 'column': 'biotonne', 'value': 9368.0}, {'key': 12, 'year': '2016', 'column': 'biotonne', 'value': 12719.0}, {'key': 13, 'year': '2017', 'column': 'biotonne', 'value': 4309.0}, {'key': 14, 'year': '2018', 'column': 'biotonne', 'value': 8409.0}, {'key': 15, 'year': '2019', 'column': 'biotonne', 'value': 12873.0}, {'key': 16, 'year': '2020', 'column': 'biotonne', 'value': 4434.0}, {'key': 17, 'year': '2004', 'column': 'gartenPark', 'value': 8439.0}, {'key': 18, 'year': '2005', 'column': 'gartenPark', 'value': 12804.0}, {'key': 19, 'year': '2006', 'column': 'gartenPark', 'value': 4483.0}, {'key': 20, 'year': '2007', 'column': 'gartenPark', 'value': 8321.0}, {'key': 21, 'year': '2008', 'column': 'gartenPark', 'value': 14953.0}, {'key': 22, 'year': '2009', 'column': 'gartenPark', 'value': 3993.0}, {'key': 23, 'year': '2010', 'column': 'gartenPark', 'value': 10960.0}, {'key': 24, 'year': '2011', 'column': 'gartenPark', 'value': 15611.0}, {'key': 25, 'year': '2012', 'column': 'gartenPark', 'value': 4345.0}, {'key': 26, 'year': '2013', 'column': 'gartenPark', 'value': 11266.0}, {'key': 27, 'year': '2014', 'column': 'gartenPark', 'value': 16215.0}, {'key': 28, 'year': '2015', 'column': 'gartenPark', 'value': 4638.0}, {'key': 29, 'year': '2016', 'column': 'gartenPark', 'value': 11577.0}, {'key': 30, 'year': '2017', 'column': 'gartenPark', 'value': 14725.0}, {'key': 31, 'year': '2018', 'column': 'gartenPark', 'value': 4457.0}, {'key': 32, 'year': '2019', 'column': 'gartenPark', 'value': 10268.0}, {'key': 33, 'year': '2020', 'column': 'gartenPark', 'value': 15982.0}, {'key': 34, 'year': '2004', 'column': 'sum', 'value': 4873.0}, {'key': 35, 'year': '2005', 'column': 'sum', 'value': 11109.0}, {'key': 36, 'year': '2006', 'column': 'sum', 'value': 13393.0}, {'key': 37, 'year': '2007', 'column': 'sum', 'value': 4760.0}, {'key': 38, 'year': '2008', 'column': 'sum', 'value': 8633.0}, {'key': 39, 'year': '2009', 'column': 'sum', 'value': 12946.0}, {'key': 40, 'year': '2010', 'column': 'sum', 'value': 5103.0}, {'key': 41, 'year': '2011', 'column': 'sum', 'value': 7843.0}, {'key': 42, 'year': '2012', 'column': 'sum', 'value': 11473.0}, {'key': 43, 'year': '2013', 'column': 'sum', 'value': 5013.0}, {'key': 44, 'year': '2014', 'column': 'sum', 'value': 6460.0}, {'key': 45, 'year': '2015', 'column': 'sum', 'value': 12038.0}, {'key': 46, 'year': '2016', 'column': 'sum', 'value': 5219.0}, {'key': 47, 'year': '2017', 'column': 'sum', 'value': 6819.0}, {'key': 48, 'year': '2018', 'column': 'sum', 'value': 11950.0}, {'key': 49, 'year': '2019', 'column': 'sum', 'value': 5435.0}, {'key': 50, 'year': '2020', 'column': 'sum', 'value': 6515.0}]

# %%
paths = [mobi2]
for path in paths:
    #read dataset
    df = pd.read_csv(path)

    #check if ags is in list of current ags
    check = df[~df['AGS'].isin(currentAGS)]

#TODO: agri1 & bui1 & en2 have regierunsgbezirke included
    #is brunaschweig included??

check
# Out:
# Empty DataFrame
# Columns: [AGS, Name, mobility_mid_tripcount_percentage_value_MIV_(Fahrer)_2002, mobility_mid_tripcount_percentage_value_ÖPV_2002, mobility_mid_tripcount_percentage_value_Fuß_2002, mobility_mid_tripcount_percentage_value_MIV_(Mitfahrer)_2002, mobility_mid_tripcount_percentage_value_Fahrrad_2002, mobility_mid_tripcount_percentage_sum_2002, mobility_mid_tripcount_percentage_value_MIV_(Fahrer)_2008, mobility_mid_tripcount_percentage_value_ÖPV_2008, mobility_mid_tripcount_percentage_value_Fuß_2008, mobility_mid_tripcount_percentage_value_MIV_(Mitfahrer)_2008, mobility_mid_tripcount_percentage_value_Fahrrad_2008, mobility_mid_tripcount_percentage_sum_2008, mobility_mid_tripcount_percentage_value_MIV_(Fahrer)_2017, mobility_mid_tripcount_percentage_value_ÖPV_2017, mobility_mid_tripcount_percentage_value_Fuß_2017, mobility_mid_tripcount_percentage_value_MIV_(Mitfahrer)_2017, mobility_mid_tripcount_percentage_value_Fahrrad_2017, mobility_mid_tripcount_percentage_sum_2017, mobility_mid_tripcount_value_MIV_(Fahrer)_2002, mobility_mid_tripcount_value_MIV_(Fahrer)_2008, mobility_mid_tripcount_value_MIV_(Fahrer)_2017, mobility_mid_tripcount_value_ÖPV_2002, mobility_mid_tripcount_value_ÖPV_2008, mobility_mid_tripcount_value_ÖPV_2017, mobility_mid_tripcount_value_Fuß_2002, mobility_mid_tripcount_value_Fuß_2008, mobility_mid_tripcount_value_Fuß_2017, mobility_mid_tripcount_value_MIV_(Mitfahrer)_2002, mobility_mid_tripcount_value_MIV_(