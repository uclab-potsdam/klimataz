# %%
import pandas as pd;
# PATHS
# Changed structure for more legibility of sources
#agriculture (3)
agri1 = '../finaldata/la_final_data_bundesland_agriculture_animalcount.csv'
agri2 = '../finaldata/la_final_data_landkreis_agriculture_animalcount.csv'

#buildings (2)
bui1 = '../finaldata/ge_final_data_aggregated_landkreis_newbuildings_renewables.csv'
bui2 = '../finaldata/ge_final_data_bundesland_heating.csv'

#mobility (3)
# mobi1 = '../finaldata/mo_final_data_landkreis_mobility_cartype.csv'
mobi2 = '../finaldata/mo_final_data_bundesland_mobility_mid.csv'
mobi3 = '../finaldata/mo_final_data_landkreis_mobility_fueltype.csv'

#waste (3)
was1 = '../finaldata/ab_final_data_landkreis_waste_organicwaste.csv'

#energy (3)
en1 = '../finaldata/en_final_data_bundesland_energy_primaryconsumption.csv'
en2 = '../finaldata/en_final_data_landkreis_energy_industryenergy.csv'

#combine all paths
paths = [mobi2,mobi3,agri2,agri1,bui1,bui2,en1,en2,was1]
paths
# Out:
# ['../finaldata/mo_final_data_bundesland_mobility_mid.csv',
#  '../finaldata/mo_final_data_landkreis_mobility_fueltype.csv',
#  '../finaldata/la_final_data_landkreis_agriculture_animalcount.csv',
#  '../finaldata/la_final_data_bundesland_agriculture_animalcount.csv',
#  '../finaldata/ge_final_data_aggregated_landkreis_newbuildings_renewables.csv',
#  '../finaldata/ge_final_data_bundesland_heating.csv',
#  '../finaldata/en_final_data_bundesland_energy_primaryconsumption.csv',
#  '../finaldata/en_final_data_landkreis_energy_industryenergy.csv',
#  '../finaldata/ab_final_data_landkreis_waste_organicwaste.csv']

# %%
import json
import numpy as np
import os

#decision to split by lk, not by section, to have smaller slices of data 
#max slice of 5 section / 5 landkreise, min slice of 5 sections / 1 landkreis 
#not max slice of 5 sections / 400 landkreise, min slice of 1 section / 400 landkreise
            
#1001
    #ags
    #bundesland
    #score
    #En
        #score
        #primary_energy 
            #regional
            #data
            #benchmark
            #unit
        #industry
            #regional
            #data
            #benchmark
            #unit

#1. Create pipeline to fetch snippets of data for each location and indicator
#2. TODO: Define a hierarchy for indicators
#3. Create dynamic labels to differentiate datasets
#4. Check if regional data are available for each landkreis to store it as a parameter

sections={"mobility":"Mo","agriculture":"La","energy":"En","waste":"Ab","buildings":"Ge"}

def getDictionaryWithPrefix(df):
    #set index, condition to catch error in case AGS column is not defined
    if 'AGS' in df.columns:
        df.set_index('AGS',inplace=True)
    
    #fill nan with jsonable format
    df = df.fillna(np.nan).replace([np.nan], [None])
    
    #drop name column
    df.drop(columns=["Name"],axis=1,inplace=True)
    
    #get dynamic labels to differentiate datasets
    #get prefix
    columns = df.columns.tolist()
    #remove column Unit to avoid data mash-up (dirtydirty)
    if "Unit" in columns:
        columns.remove("Unit")
    prefix = os.path.commonprefix(columns)  
    print(prefix)
    #TODO: create hiearchy from prefixes
    section_eng = prefix.split('_')[0]
    section = sections[section_eng]

    #remove prefix from column names
    df.columns = df.columns.str.removeprefix(prefix)
    
    #remove section from prefix
    prefix = prefix.removeprefix(section_eng)

    #create dict from dataframe
    data_dict = df.T.to_dict('dict')
    
    return section,prefix,data_dict 


def generate_json(paths,last_year):

    landkreisData = {}

    indicators = []
    dicts = []
    indicator_sections = []
    
    #get current ags list from population data from regionalstatisik
    population = pd.read_csv("../general_data/population.csv",delimiter=";",encoding="latin1")
    population.rename({"1_Auspraegung_Code":"AGS"},axis=1,inplace=True)
    population["AGS"].replace({"DG":0},inplace=True)
    population["AGS"] = pd.to_numeric(population["AGS"])
    population["Zeit"] = population["Zeit"].str.replace(".","/",regex=True)
    population['Zeit'] =  pd.to_datetime(population['Zeit'],dayfirst=True)
    population['Jahr'] = population['Zeit'].dt.year

    #rows with no population data in some year before is changed ags
    changedAGS = population[(population.BEVSTD__Bevoelkerungsstand__Anzahl == "-") & (population.Jahr != last_year)].AGS.unique()
    currentAGS = population.AGS.unique() #only current AGS are counted in this dataset

    population["BEVSTD__Bevoelkerungsstand__Anzahl"] = population["BEVSTD__Bevoelkerungsstand__Anzahl"].replace("-",np.NaN,regex=True)
    units = []
    #pipeline to fetch snippets of data for each location and indicator
    for path in paths:
        #read dataset
        print(path)
        df = pd.read_csv(path)
        #check if ags is in list of current ags    
        #df = df[~df['AGS'].isin(currentAGS)]
        #append footnotes for lk if only new data exists
        
        #Check if unit is defined in the dataset 
        if "Unit" in df.columns.tolist():
            # If yes appends itself to array
            unitValue = df["Unit"][1]
            units.append(unitValue)
            df.drop('Unit', axis=1, inplace=True)
        else:
            # If no appends dummy to array
            units.append("not defined at source")
        
        
        section,prefix,data_dict = getDictionaryWithPrefix(df)
        indicators.append(prefix)
        indicator_sections.append(section)
        dicts.append(data_dict)

    print("indicator: ",indicators)

    for ort in currentAGS:
        ort = int(ort)
        footnote = ""
        
        #handle new landkreise
        if(ort in changedAGS):
            s = population[population.AGS == ort]
            #get first datapoint for each
            first = s.BEVSTD__Bevoelkerungsstand__Anzahl.first_valid_index()
            footnote = "Diesen Landkreis gibt es erst seit " + str(population.iloc[first].Jahr)
        
        if(ort == 15003):
            print(footnote)
        
        #store bundesland of each landkreis
        if(ort < 17):
            bundesland = ort
        elif ort > 1000:
            bundesland = int(str(ort)[:-3])  #store bundesland from ags
        else:
            print("not included: ",ort)
            pass

        #create top level data for each location
        landkreisData[str(ort)] = {
            'ags':ort,
            'bundesland':bundesland,
            'score':2,
            'footnote':footnote,
            'Mo':{},
            'La':{},
            'Ge':{},
            'En':{},
            'Ab':{},
            }

        data = {}
        
        #iterate over indicators
        for i,ind in enumerate(indicators):
            ind_section = indicator_sections[i]
            #print(ind,ind_section)
#             print(ort)
            if(ort in dicts[i]):
                local_data = [{"key":index ,"year":item[0][-4:],"column":item[0][:-5],"value":item[1]} for index,item in enumerate(dicts[i][ort].items())]
                print(local_data)
                #create one entry per indicator
                #Check if regional data are available for each landkreis to store it as a parameter
                #Gets unit of measure from array of units based on i
                data[ind] = {
                    'benchmark':200,
                    'regional': True if ort > 17 else False,
                    'unit': units[i],
                    'data':local_data
                }
            
            else:
                #TODO: add bundesland level to all indicators, so this is only false for landkreise
                data[ind] = {
                    'regional':False,
                }

            #add data entry to location level
            #landkreisData[str(ort)][ind] = "added data"
            landkreisData[str(ort)][ind_section][ind] = data[ind]
        

    with open('data.json', 'w', encoding='utf-8') as f:
        json.dump(landkreisData, f, ensure_ascii=False, indent=4)


generate_json(paths,2021)
# Out:
# ../finaldata/mo_final_data_bundesland_mobility_mid.csv
# mobility_mid_
# ../finaldata/mo_final_data_landkreis_mobility_fueltype.csv
# mobility_fueltype_cardensity_
# ../finaldata/la_final_data_landkreis_agriculture_animalcount.csv
# agriculture_animalcount_Anzahl_
# ../finaldata/la_final_data_bundesland_agriculture_animalcount.csv
# agriculture_animalcount_bydensity_
# ../finaldata/ge_final_data_aggregated_landkreis_newbuildings_renewables.csv
# buildings_newbuilding_energy_
# ../finaldata/ge_final_data_bundesland_heating.csv
# buildings_heating_20
# ../finaldata/en_final_data_bundesland_energy_primaryconsumption.csv
# energy_primaryconsumption_
# ../finaldata/en_final_data_landkreis_energy_industryenergy.csv
# energy_industry_consumption_
# ../finaldata/ab_final_data_landkreis_waste_organicwaste.csv
# waste_organicwaste_kg_per_person_
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [{'key': 0, 'year': '2010', 'column': 'Rinder', 'value': 0.0}, {'key': 1, 'year': '2016', 'column': 'Rinder', 'value': 0.0}, {'key': 2, 'year': '2020', 'column': 'Rinder', 'value': 0.0}, {'key': 3, 'year': '2010', 'column': 'Schafe', 'value': 0.0}, {'key': 4, 'year': '2016', 'column': 'Schafe', 'value': 0.0}, {'key': 5, 'year': '2020', 'column': 'Schafe', 'value': 0.0}, {'key': 6, 'year': '2010', 'column': 'Schweine', 'value': 0.0}, {'key': 7, 'year': '2016', 'column': 'Schweine', 'value': 0.0}, {'key': 8, 'year': '2020', 'column': 'Schweine', 'value': 0.0}]
# [{'key': 0, 'year': '2016', 'column': 'Umweltthermie', 'value': 0}, {'key': 1, 'year': '2017', 'column': 'Umweltthermie', 'value': 0}, {'key': 2, 'year': '2018', 'column': 'Umweltthermie', 'value': 0}, {'key': 3, 'year': '2019', 'column': 'Umweltthermie', 'value': 0}, {'key': 4, 'year': '2020', 'column': 'Umweltthermie', 'value': 0}, {'key': 5, 'year': '2016', 'column': 'andere erneuerbare Energien', 'value': 0}, {'key': 6, 'year': '2017', 'column': 'andere erneuerbare Energien', 'value': 0}, {'key': 7, 'year': '2018', 'column': 'andere erneuerbare Energien', 'value': 0}, {'key': 8, 'year': '2019', 'column': 'andere erneuerbare Energien', 'value': 0}, {'key': 9, 'year': '2020', 'column': 'andere erneuerbare Energien', 'value': 0}, {'key': 10, 'year': '2016', 'column': 'Gas', 'value': 0}, {'key': 11, 'year': '2017', 'column': 'Gas', 'value': 0}, {'key': 12, 'year': '2018', 'column': 'Gas', 'value': 0}, {'key': 13, 'year': '2019', 'column': 'Gas', 'value': 0}, {'key': 14, 'year': '2020', 'column': 'Gas', 'value': 0}, {'key': 15, 'year': '2016', 'column': 'andere fossile Energie', 'value': 0}, {'key': 16, 'year': '2017', 'column': 'andere fossile Energie', 'value': 0}, {'key': 17, 'year': '2018', 'column': 'andere fossile Energie', 'value': 0}, {'key': 18, 'year': '2019', 'column': 'andere fossile Energie', 'value': 0}, {'key': 19, 'year': '2020', 'column': 'andere fossile Energie', 'value': 0}, {'key': 20, 'year': '2016', 'column': 'Strom', 'value': 0}, {'key': 21, 'year': '2017', 'column': 'Strom', 'value': 0}, {'key': 22, 'year': '2018', 'column': 'Strom', 'value': 0}, {'key': 23, 'year': '2019', 'column': 'Strom', 'value': 0}, {'key': 24, 'year': '2020', 'column': 'Strom', 'value': 0}, {'key': 25, 'year': '2016', 'column': 'renewables', 'value': 0}, {'key': 26, 'year': '2017', 'column': 'renewables', 'value': 0}, {'key': 27, 'year': '2018', 'column': 'renewables', 'value': 0}, {'key': 28, 'year': '2019', 'column': 'renewables', 'value': 0}, {'key': 29, 'year': '2020', 'column': 'renewables', 'value': 0}, {'key': 30, 'year': '2016', 'column': 'fossils', 'value': 0}, {'key': 31, 'year': '2017', 'column': 'fossils', 'value': 0}, {'key': 32, 'year': '2018', 'column': 'fossils', 'value': 0}, {'key': 33, 'year': '2019', 'column': 'fossils', 'value': 0}, {'key': 34, 'year': '2020', 'column': 'fossils', 'value': 0}]
# [{'key': 0, 'year': '2003', 'column': 'Erdgas', 'value': 225881.0}, {'key': 1, 'year': '2004', 'column': 'Erdgas', 'value': 221764.0}, {'key': 2, 'year': '2005', 'column': 'Erdgas', 'value': 229096.0}, {'key': 3, 'year': '2006', 'column': 'Erdgas', 'value': 210664.0}, {'key': 4, 'year': '2007', 'column': 'Erdgas', 'value': 181438.0}, {'key': 5, 'year': '2008', 'column': 'Erdgas', 'value': 0.0}, {'key': 6, 'year': '2009', 'column': 'Erdgas', 'value': 0.0}, {'key': 7, 'year': '2010', 'column': 'Erdgas', 'value': 0.0}, {'key': 8, 'year': '2011', 'column': 'Erdgas', 'value': 0.0}, {'key': 9, 'year': '2012', 'column': 'Erdgas', 'value': 0.0}, {'key': 10, 'year': '2013', 'column': 'Erdgas', 'value': 0.0}, {'key': 11, 'year': '2014', 'column': 'Erdgas', 'value': 0.0}, {'key': 12, 'year': '2015', 'column': 'Erdgas', 'value': 0.0}, {'key': 13, 'year': '2016', 'column': 'Erdgas', 'value': 0.0}, {'key': 14, 'year': '2017', 'column': 'Erdgas', 'value': 0.0}, {'key': 15, 'year': '2018', 'column': 'Erdgas', 'value': 0.0}, {'key': 16, 'year': '2019', 'column': 'Erdgas', 'value': 0.0}, {'key': 17, 'year': '2020', 'column': 'Erdgas', 'value': 0.0}, {'key': 18, 'year': '2003', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 19, 'year': '2004', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 20, 'year': '2005', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 21, 'year': '2006', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 22, 'year': '2007', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 23, 'year': '2008', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 24, 'year': '2009', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 25, 'year': '2010', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 26, 'year': '2011', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 27, 'year': '2012', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 28, 'year': '2013', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 29, 'year': '2014', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 30, 'year': '2015', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 31, 'year': '2016', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 32, 'year': '2017', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 33, 'year': '2018', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 34, 'year': '2019', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 35, 'year': '2020', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 36, 'year': '2003', 'column': 'Heizöl', 'value': 105924.0}, {'key': 37, 'year': '2004', 'column': 'Heizöl', 'value': 99442.0}, {'key': 38, 'year': '2005', 'column': 'Heizöl', 'value': 105750.0}, {'key': 39, 'year': '2006', 'column': 'Heizöl', 'value': 105893.0}, {'key': 40, 'year': '2007', 'column': 'Heizöl', 'value': 107746.0}, {'key': 41, 'year': '2008', 'column': 'Heizöl', 'value': 0.0}, {'key': 42, 'year': '2009', 'column': 'Heizöl', 'value': 0.0}, {'key': 43, 'year': '2010', 'column': 'Heizöl', 'value': 0.0}, {'key': 44, 'year': '2011', 'column': 'Heizöl', 'value': 0.0}, {'key': 45, 'year': '2012', 'column': 'Heizöl', 'value': 0.0}, {'key': 46, 'year': '2013', 'column': 'Heizöl', 'value': 0.0}, {'key': 47, 'year': '2014', 'column': 'Heizöl', 'value': 0.0}, {'key': 48, 'year': '2015', 'column': 'Heizöl', 'value': 0.0}, {'key': 49, 'year': '2016', 'column': 'Heizöl', 'value': 0.0}, {'key': 50, 'year': '2017', 'column': 'Heizöl', 'value': 0.0}, {'key': 51, 'year': '2018', 'column': 'Heizöl', 'value': 0.0}, {'key': 52, 'year': '2019', 'column': 'Heizöl', 'value': 0.0}, {'key': 53, 'year': '2020', 'column': 'Heizöl', 'value': 0.0}, {'key': 54, 'year': '2003', 'column': 'Kohle', 'value': 0.0}, {'key': 55, 'year': '2004', 'column': 'Kohle', 'value': 0.0}, {'key': 56, 'year': '2005', 'column': 'Kohle', 'value': 0.0}, {'key': 57, 'year': '2006', 'column': 'Kohle', 'value': 0.0}, {'key': 58, 'year': '2007', 'column': 'Kohle', 'value': No ...
# [{'key': 0, 'year': '2004', 'column': 'biotonne', 'value': 0.0}, {'key': 1, 'year': '2005', 'column': 'biotonne', 'value': 0.0}, {'key': 2, 'year': '2006', 'column': 'biotonne', 'value': 0.0}, {'key': 3, 'year': '2007', 'column': 'biotonne', 'value': 0.0}, {'key': 4, 'year': '2008', 'column': 'biotonne', 'value': None}, {'key': 5, 'year': '2009', 'column': 'biotonne', 'value': None}, {'key': 6, 'year': '2010', 'column': 'biotonne', 'value': None}, {'key': 7, 'year': '2011', 'column': 'biotonne', 'value': None}, {'key': 8, 'year': '2012', 'column': 'biotonne', 'value': None}, {'key': 9, 'year': '2013', 'column': 'biotonne', 'value': None}, {'key': 10, 'year': '2014', 'column': 'biotonne', 'value': None}, {'key': 11, 'year': '2015', 'column': 'biotonne', 'value': None}, {'key': 12, 'year': '2016', 'column': 'biotonne', 'value': None}, {'key': 13, 'year': '2017', 'column': 'biotonne', 'value': None}, {'key': 14, 'year': '2018', 'column': 'biotonne', 'value': None}, {'key': 15, 'year': '2019', 'column': 'biotonne', 'value': None}, {'key': 16, 'year': '2020', 'column': 'biotonne', 'value': None}, {'key': 17, 'year': '2004', 'column': 'gartenPark', 'value': 0.0}, {'key': 18, 'year': '2005', 'column': 'gartenPark', 'value': 0.0}, {'key': 19, 'year': '2006', 'column': 'gartenPark', 'value': 0.0}, {'key': 20, 'year': '2007', 'column': 'gartenPark', 'value': 0.0}, {'key': 21, 'year': '2008', 'column': 'gartenPark', 'value': None}, {'key': 22, 'year': '2009', 'column': 'gartenPark', 'value': None}, {'key': 23, 'year': '2010', 'column': 'gartenPark', 'value': None}, {'key': 24, 'year': '2011', 'column': 'gartenPark', 'value': None}, {'key': 25, 'year': '2012', 'column': 'gartenPark', 'value': None}, {'key': 26, 'year': '2013', 'column': 'gartenPark', 'value': None}, {'key': 27, 'year': '2014', 'column': 'gartenPark', 'value': None}, {'key': 28, 'year': '2015', 'column': 'gartenPark', 'value': None}, {'key': 29, 'year': '2016', 'column': 'gartenPark', 'value': None}, {'key': 30, 'year': '2017', 'column': 'gartenPark', 'value': None}, {'key': 31, 'year': '2018', 'column': 'gartenPark', 'value': None}, {'key': 32, 'year': '2019', 'column': 'gartenPark', 'value': None}, {'key': 33, 'year': '2020', 'column': 'gartenPark', 'value': None}, {'key': 34, 'year': '2004', 'column': 'sum', 'value': 0.0}, {'key': 35, 'year': '2005', 'column': 'sum', 'value': 0.0}, {'key': 36, 'year': '2006', 'column': 'sum', 'value': 0.0}, {'key': 37, 'year': '2007', 'column': 'sum', 'value': 62.32529247334092}, {'key': 38, 'year': '2008', 'column': 'sum', 'value': None}, {'key': 39, 'year': '2009', 'column': 'sum', 'value': None}, {'key': 40, 'year': '2010', 'column': 'sum', 'value': None}, {'key': 41, 'year': '2011', 'column': 'sum', 'value': None}, {'key': 42, 'year': '2012', 'column': 'sum', 'value': None}, {'key': 43, 'year': '2013', 'column': 'sum', 'value': None}, {'key': 44, 'year': '2014', 'column': 'sum', 'value': None}, {'key': 45, 'year': '2015', 'column': 'sum', 'value': None}, {'key': 46, 'year': '2016', 'column': 'sum', 'value': None}, {'key': 47, 'year': '2017', 'column': 'sum', 'value': None}, {'key': 48, 'year': '2018', 'column': 'sum', 'value': None}, {'key': 49, 'year': '2019', 'column': 'sum', 'value': None}, {'key': 50, 'year': '2020', 'column': 'sum', 'value': None}]
# [{'key': 0, 'year': '2010', 'column': 'Rinder', 'value': 0.0}, {'key': 1, 'year': '2016', 'column': 'Rinder', 'value': 0.0}, {'key': 2, 'year': '2020', 'column': 'Rinder', 'value': 0.0}, {'key': 3, 'year': '2010', 'column': 'Schafe', 'value': 0.0}, {'key': 4, 'year': '2016', 'column': 'Schafe', 'value': 0.0}, {'key': 5, 'year': '2020', 'column': 'Schafe', 'value': 0.0}, {'key': 6, 'year': '2010', 'column': 'Schweine', 'value': 0.0}, {'key': 7, 'year': '2016', 'column': 'Schweine', 'value': 0.0}, {'key': 8, 'year': '2020', 'column': 'Schweine', 'value': 0.0}]
# [{'key': 0, 'year': '2016', 'column': 'Umweltthermie', 'value': 0}, {'key': 1, 'year': '2017', 'column': 'Umweltthermie', 'value': 0}, {'key': 2, 'year': '2018', 'column': 'Umweltthermie', 'value': 0}, {'key': 3, 'year': '2019', 'column': 'Umweltthermie', 'value': 0}, {'key': 4, 'year': '2020', 'column': 'Umweltthermie', 'value': 0}, {'key': 5, 'year': '2016', 'column': 'andere erneuerbare Energien', 'value': 0}, {'key': 6, 'year': '2017', 'column': 'andere erneuerbare Energien', 'value': 0}, {'key': 7, 'year': '2018', 'column': 'andere erneuerbare Energien', 'value': 0}, {'key': 8, 'year': '2019', 'column': 'andere erneuerbare Energien', 'value': 0}, {'key': 9, 'year': '2020', 'column': 'andere erneuerbare Energien', 'value': 0}, {'key': 10, 'year': '2016', 'column': 'Gas', 'value': 0}, {'key': 11, 'year': '2017', 'column': 'Gas', 'value': 0}, {'key': 12, 'year': '2018', 'column': 'Gas', 'value': 0}, {'key': 13, 'year': '2019', 'column': 'Gas', 'value': 0}, {'key': 14, 'year': '2020', 'column': 'Gas', 'value': 0}, {'key': 15, 'year': '2016', 'column': 'andere fossile Energie', 'value': 0}, {'key': 16, 'year': '2017', 'column': 'andere fossile Energie', 'value': 0}, {'key': 17, 'year': '2018', 'column': 'andere fossile Energie', 'value': 0}, {'key': 18, 'year': '2019', 'column': 'andere fossile Energie', 'value': 0}, {'key': 19, 'year': '2020', 'column': 'andere fossile Energie', 'value': 0}, {'key': 20, 'year': '2016', 'column': 'Strom', 'value': 0}, {'key': 21, 'year': '2017', 'column': 'Strom', 'value': 0}, {'key': 22, 'year': '2018', 'column': 'Strom', 'value': 0}, {'key': 23, 'year': '2019', 'column': 'Strom', 'value': 0}, {'key': 24, 'year': '2020', 'column': 'Strom', 'value': 0}, {'key': 25, 'year': '2016', 'column': 'renewables', 'value': 0}, {'key': 26, 'year': '2017', 'column': 'renewables', 'value': 0}, {'key': 27, 'year': '2018', 'column': 'renewables', 'value': 0}, {'key': 28, 'year': '2019', 'column': 'renewables', 'value': 0}, {'key': 29, 'year': '2020', 'column': 'renewables', 'value': 0}, {'key': 30, 'year': '2016', 'column': 'fossils', 'value': 0}, {'key': 31, 'year': '2017', 'column': 'fossils', 'value': 0}, {'key': 32, 'year': '2018', 'column': 'fossils', 'value': 0}, {'key': 33, 'year': '2019', 'column': 'fossils', 'value': 0}, {'key': 34, 'year': '2020', 'column': 'fossils', 'value': 0}]
# [{'key': 0, 'year': '2003', 'column': 'Erdgas', 'value': 1719307.0}, {'key': 1, 'year': '2004', 'column': 'Erdgas', 'value': 1670448.0}, {'key': 2, 'year': '2005', 'column': 'Erdgas', 'value': 1511458.0}, {'key': 3, 'year': '2006', 'column': 'Erdgas', 'value': 1450115.0}, {'key': 4, 'year': '2007', 'column': 'Erdgas', 'value': 1382735.0}, {'key': 5, 'year': '2008', 'column': 'Erdgas', 'value': 0.0}, {'key': 6, 'year': '2009', 'column': 'Erdgas', 'value': 0.0}, {'key': 7, 'year': '2010', 'column': 'Erdgas', 'value': 0.0}, {'key': 8, 'year': '2011', 'column': 'Erdgas', 'value': 0.0}, {'key': 9, 'year': '2012', 'column': 'Erdgas', 'value': 0.0}, {'key': 10, 'year': '2013', 'column': 'Erdgas', 'value': 0.0}, {'key': 11, 'year': '2014', 'column': 'Erdgas', 'value': 0.0}, {'key': 12, 'year': '2015', 'column': 'Erdgas', 'value': 0.0}, {'key': 13, 'year': '2016', 'column': 'Erdgas', 'value': 0.0}, {'key': 14, 'year': '2017', 'column': 'Erdgas', 'value': 0.0}, {'key': 15, 'year': '2018', 'column': 'Erdgas', 'value': 0.0}, {'key': 16, 'year': '2019', 'column': 'Erdgas', 'value': 0.0}, {'key': 17, 'year': '2020', 'column': 'Erdgas', 'value': 0.0}, {'key': 18, 'year': '2003', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 19, 'year': '2004', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 20, 'year': '2005', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 21, 'year': '2006', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 22, 'year': '2007', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 23, 'year': '2008', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 24, 'year': '2009', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 25, 'year': '2010', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 26, 'year': '2011', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 27, 'year': '2012', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 28, 'year': '2013', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 29, 'year': '2014', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 30, 'year': '2015', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 31, 'year': '2016', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 32, 'year': '2017', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 33, 'year': '2018', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 34, 'year': '2019', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 35, 'year': '2020', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 36, 'year': '2003', 'column': 'Heizöl', 'value': 62524.0}, {'key': 37, 'year': '2004', 'column': 'Heizöl', 'value': 47186.0}, {'key': 38, 'year': '2005', 'column': 'Heizöl', 'value': 58573.0}, {'key': 39, 'year': '2006', 'column': 'Heizöl', 'value': 41467.0}, {'key': 40, 'year': '2007', 'column': 'Heizöl', 'value': 21182.0}, {'key': 41, 'year': '2008', 'column': 'Heizöl', 'value': 0.0}, {'key': 42, 'year': '2009', 'column': 'Heizöl', 'value': 0.0}, {'key': 43, 'year': '2010', 'column': 'Heizöl', 'value': 0.0}, {'key': 44, 'year': '2011', 'column': 'Heizöl', 'value': 0.0}, {'key': 45, 'year': '2012', 'column': 'Heizöl', 'value': 0.0}, {'key': 46, 'year': '2013', 'column': 'Heizöl', 'value': 0.0}, {'key': 47, 'year': '2014', 'column': 'Heizöl', 'value': 0.0}, {'key': 48, 'year': '2015', 'column': 'Heizöl', 'value': 0.0}, {'key': 49, 'year': '2016', 'column': 'Heizöl', 'value': 0.0}, {'key': 50, 'year': '2017', 'column': 'Heizöl', 'value': 0.0}, {'key': 51, 'year': '2018', 'column': 'Heizöl', 'value': 0.0}, {'key': 52, 'year': '2019', 'column': 'Heizöl', 'value': 0.0}, {'key': 53, 'year': '2020', 'column': 'Heizöl', 'value': 0.0}, {'key': 54, 'year': '2003', 'column': 'Kohle', 'value': None}, {'key': 55, 'year': '2004', 'column': 'Kohle', 'value': None}, {'key': 56, 'year': '2005', 'column': 'Kohle', 'value': 0.0}, {'key': 57, 'year': '2006', 'column': 'Kohle', 'value': 0.0}, {'key': 58, 'year': '2007', 'column': 'Kohle', 'value': ...
# [{'key': 0, 'year': '2004', 'column': 'biotonne', 'value': 0.0}, {'key': 1, 'year': '2005', 'column': 'biotonne', 'value': 0.0}, {'key': 2, 'year': '2006', 'column': 'biotonne', 'value': 0.0}, {'key': 3, 'year': '2007', 'column': 'biotonne', 'value': 0.0}, {'key': 4, 'year': '2008', 'column': 'biotonne', 'value': None}, {'key': 5, 'year': '2009', 'column': 'biotonne', 'value': None}, {'key': 6, 'year': '2010', 'column': 'biotonne', 'value': None}, {'key': 7, 'year': '2011', 'column': 'biotonne', 'value': None}, {'key': 8, 'year': '2012', 'column': 'biotonne', 'value': None}, {'key': 9, 'year': '2013', 'column': 'biotonne', 'value': None}, {'key': 10, 'year': '2014', 'column': 'biotonne', 'value': None}, {'key': 11, 'year': '2015', 'column': 'biotonne', 'value': None}, {'key': 12, 'year': '2016', 'column': 'biotonne', 'value': None}, {'key': 13, 'year': '2017', 'column': 'biotonne', 'value': None}, {'key': 14, 'year': '2018', 'column': 'biotonne', 'value': None}, {'key': 15, 'year': '2019', 'column': 'biotonne', 'value': None}, {'key': 16, 'year': '2020', 'column': 'biotonne', 'value': None}, {'key': 17, 'year': '2004', 'column': 'gartenPark', 'value': 0.0}, {'key': 18, 'year': '2005', 'column': 'gartenPark', 'value': 0.0}, {'key': 19, 'year': '2006', 'column': 'gartenPark', 'value': 0.0}, {'key': 20, 'year': '2007', 'column': 'gartenPark', 'value': 0.0}, {'key': 21, 'year': '2008', 'column': 'gartenPark', 'value': None}, {'key': 22, 'year': '2009', 'column': 'gartenPark', 'value': None}, {'key': 23, 'year': '2010', 'column': 'gartenPark', 'value': None}, {'key': 24, 'year': '2011', 'column': 'gartenPark', 'value': None}, {'key': 25, 'year': '2012', 'column': 'gartenPark', 'value': None}, {'key': 26, 'year': '2013', 'column': 'gartenPark', 'value': None}, {'key': 27, 'year': '2014', 'column': 'gartenPark', 'value': None}, {'key': 28, 'year': '2015', 'column': 'gartenPark', 'value': None}, {'key': 29, 'year': '2016', 'column': 'gartenPark', 'value': None}, {'key': 30, 'year': '2017', 'column': 'gartenPark', 'value': None}, {'key': 31, 'year': '2018', 'column': 'gartenPark', 'value': None}, {'key': 32, 'year': '2019', 'column': 'gartenPark', 'value': None}, {'key': 33, 'year': '2020', 'column': 'gartenPark', 'value': None}, {'key': 34, 'year': '2004', 'column': 'sum', 'value': 0.0}, {'key': 35, 'year': '2005', 'column': 'sum', 'value': 0.0}, {'key': 36, 'year': '2006', 'column': 'sum', 'value': 0.0}, {'key': 37, 'year': '2007', 'column': 'sum', 'value': 7.022046931897622}, {'key': 38, 'year': '2008', 'column': 'sum', 'value': None}, {'key': 39, 'year': '2009', 'column': 'sum', 'value': None}, {'key': 40, 'year': '2010', 'column': 'sum', 'value': None}, {'key': 41, 'year': '2011', 'column': 'sum', 'value': None}, {'key': 42, 'year': '2012', 'column': 'sum', 'value': None}, {'key': 43, 'year': '2013', 'column': 'sum', 'value': None}, {'key': 44, 'year': '2014', 'column': 'sum', 'value': None}, {'key': 45, 'year': '2015', 'column': 'sum', 'value': None}, {'key': 46, 'year': '2016', 'column': 'sum', 'value': None}, {'key': 47, 'year': '2017', 'column': 'sum', 'value': None}, {'key': 48, 'year': '2018', 'column': 'sum', 'value': None}, {'key': 49, 'year': '2019', 'column': 'sum', 'value': None}, {'key': 50, 'year': '2020', 'column': 'sum', 'value': None}]
# [{'key': 0, 'year': '2010', 'column': 'Rinder', 'value': 0.0}, {'key': 1, 'year': '2016', 'column': 'Rinder', 'value': 0.0}, {'key': 2, 'year': '2020', 'column': 'Rinder', 'value': 0.0}, {'key': 3, 'year': '2010', 'column': 'Schafe', 'value': 0.0}, {'key': 4, 'year': '2016', 'column': 'Schafe', 'value': 0.0}, {'key': 5, 'year': '2020', 'column': 'Schafe', 'value': 0.0}, {'key': 6, 'year': '2010', 'column': 'Schweine', 'value': 0.0}, {'key': 7, 'year': '2016', 'column': 'Schweine', 'value': 0.0}, {'key': 8, 'year': '2020', 'column': 'Schweine', 'value': 0.0}]
# [{'key': 0, 'year': '2016', 'column': 'Umweltthermie', 'value': 0}, {'key': 1, 'year': '2017', 'column': 'Umweltthermie', 'value': 0}, {'key': 2, 'year': '2018', 'column': 'Umweltthermie', 'value': 0}, {'key': 3, 'year': '2019', 'column': 'Umweltthermie', 'value': 0}, {'key': 4, 'year': '2020', 'column': 'Umweltthermie', 'value': 0}, {'key': 5, 'year': '2016', 'column': 'andere erneuerbare Energien', 'value': 0}, {'key': 6, 'year': '2017', 'column': 'andere erneuerbare Energien', 'value': 0}, {'key': 7, 'year': '2018', 'column': 'andere erneuerbare Energien', 'value': 0}, {'key': 8, 'year': '2019', 'column': 'andere erneuerbare Energien', 'value': 0}, {'key': 9, 'year': '2020', 'column': 'andere erneuerbare Energien', 'value': 0}, {'key': 10, 'year': '2016', 'column': 'Gas', 'value': 0}, {'key': 11, 'year': '2017', 'column': 'Gas', 'value': 0}, {'key': 12, 'year': '2018', 'column': 'Gas', 'value': 0}, {'key': 13, 'year': '2019', 'column': 'Gas', 'value': 0}, {'key': 14, 'year': '2020', 'column': 'Gas', 'value': 0}, {'key': 15, 'year': '2016', 'column': 'andere fossile Energie', 'value': 0}, {'key': 16, 'year': '2017', 'column': 'andere fossile Energie', 'value': 0}, {'key': 17, 'year': '2018', 'column': 'andere fossile Energie', 'value': 0}, {'key': 18, 'year': '2019', 'column': 'andere fossile Energie', 'value': 0}, {'key': 19, 'year': '2020', 'column': 'andere fossile Energie', 'value': 0}, {'key': 20, 'year': '2016', 'column': 'Strom', 'value': 0}, {'key': 21, 'year': '2017', 'column': 'Strom', 'value': 0}, {'key': 22, 'year': '2018', 'column': 'Strom', 'value': 0}, {'key': 23, 'year': '2019', 'column': 'Strom', 'value': 0}, {'key': 24, 'year': '2020', 'column': 'Strom', 'value': 0}, {'key': 25, 'year': '2016', 'column': 'renewables', 'value': 0}, {'key': 26, 'year': '2017', 'column': 'renewables', 'value': 0}, {'key': 27, 'year': '2018', 'column': 'renewables', 'value': 0}, {'key': 28, 'year': '2019', 'column': 'renewables', 'value': 0}, {'key': 29, 'year': '2020', 'column': 'renewables', 'value': 0}, {'key': 30, 'year': '2016', 'column': 'fossils', 'value': 0}, {'key': 31, 'year': '2017', 'column': 'fossils', 'value': 0}, {'key': 32, 'year': '2018', 'column': 'fossils', 'value': 0}, {'key': 33, 'year': '2019', 'column': 'fossils', 'value': 0}, {'key': 34, 'year': '2020', 'column': 'fossils', 'value': 0}]
# [{'key': 0, 'year': '2003', 'column': 'Erdgas', 'value': 686488.0}, {'key': 1, 'year': '2004', 'column': 'Erdgas', 'value': 740807.0}, {'key': 2, 'year': '2005', 'column': 'Erdgas', 'value': 739817.0}, {'key': 3, 'year': '2006', 'column': 'Erdgas', 'value': 774486.0}, {'key': 4, 'year': '2007', 'column': 'Erdgas', 'value': 702293.0}, {'key': 5, 'year': '2008', 'column': 'Erdgas', 'value': 0.0}, {'key': 6, 'year': '2009', 'column': 'Erdgas', 'value': 0.0}, {'key': 7, 'year': '2010', 'column': 'Erdgas', 'value': 0.0}, {'key': 8, 'year': '2011', 'column': 'Erdgas', 'value': 0.0}, {'key': 9, 'year': '2012', 'column': 'Erdgas', 'value': 0.0}, {'key': 10, 'year': '2013', 'column': 'Erdgas', 'value': 0.0}, {'key': 11, 'year': '2014', 'column': 'Erdgas', 'value': 0.0}, {'key': 12, 'year': '2015', 'column': 'Erdgas', 'value': 0.0}, {'key': 13, 'year': '2016', 'column': 'Erdgas', 'value': 0.0}, {'key': 14, 'year': '2017', 'column': 'Erdgas', 'value': 0.0}, {'key': 15, 'year': '2018', 'column': 'Erdgas', 'value': 0.0}, {'key': 16, 'year': '2019', 'column': 'Erdgas', 'value': 0.0}, {'key': 17, 'year': '2020', 'column': 'Erdgas', 'value': 0.0}, {'key': 18, 'year': '2003', 'column': 'Erneuerbare Energien', 'value': None}, {'key': 19, 'year': '2004', 'column': 'Erneuerbare Energien', 'value': None}, {'key': 20, 'year': '2005', 'column': 'Erneuerbare Energien', 'value': None}, {'key': 21, 'year': '2006', 'column': 'Erneuerbare Energien', 'value': 29411.0}, {'key': 22, 'year': '2007', 'column': 'Erneuerbare Energien', 'value': 27427.0}, {'key': 23, 'year': '2008', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 24, 'year': '2009', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 25, 'year': '2010', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 26, 'year': '2011', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 27, 'year': '2012', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 28, 'year': '2013', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 29, 'year': '2014', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 30, 'year': '2015', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 31, 'year': '2016', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 32, 'year': '2017', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 33, 'year': '2018', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 34, 'year': '2019', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 35, 'year': '2020', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 36, 'year': '2003', 'column': 'Heizöl', 'value': 65346.0}, {'key': 37, 'year': '2004', 'column': 'Heizöl', 'value': 53675.0}, {'key': 38, 'year': '2005', 'column': 'Heizöl', 'value': 57244.0}, {'key': 39, 'year': '2006', 'column': 'Heizöl', 'value': 45305.0}, {'key': 40, 'year': '2007', 'column': 'Heizöl', 'value': 41951.0}, {'key': 41, 'year': '2008', 'column': 'Heizöl', 'value': 0.0}, {'key': 42, 'year': '2009', 'column': 'Heizöl', 'value': 0.0}, {'key': 43, 'year': '2010', 'column': 'Heizöl', 'value': 0.0}, {'key': 44, 'year': '2011', 'column': 'Heizöl', 'value': 0.0}, {'key': 45, 'year': '2012', 'column': 'Heizöl', 'value': 0.0}, {'key': 46, 'year': '2013', 'column': 'Heizöl', 'value': 0.0}, {'key': 47, 'year': '2014', 'column': 'Heizöl', 'value': 0.0}, {'key': 48, 'year': '2015', 'column': 'Heizöl', 'value': 0.0}, {'key': 49, 'year': '2016', 'column': 'Heizöl', 'value': 0.0}, {'key': 50, 'year': '2017', 'column': 'Heizöl', 'value': 0.0}, {'key': 51, 'year': '2018', 'column': 'Heizöl', 'value': 0.0}, {'key': 52, 'year': '2019', 'column': 'Heizöl', 'value': 0.0}, {'key': 53, 'year': '2020', 'column': 'Heizöl', 'value': 0.0}, {'key': 54, 'year': '2003', 'column': 'Kohle', 'value': 0.0}, {'key': 55, 'year': '2004', 'column': 'Kohle', 'value': 0.0}, {'key': 56, 'year': '2005', 'column': 'Kohle', 'value': 0.0}, {'key': 57, 'year': '2006', 'column': 'Kohle', 'value': 0.0}, {'key': 58, 'year': '2007', 'column': 'Kohle', 'val ...
# [{'key': 0, 'year': '2004', 'column': 'biotonne', 'value': 0.0}, {'key': 1, 'year': '2005', 'column': 'biotonne', 'value': 0.0}, {'key': 2, 'year': '2006', 'column': 'biotonne', 'value': 0.0}, {'key': 3, 'year': '2007', 'column': 'biotonne', 'value': 0.0}, {'key': 4, 'year': '2008', 'column': 'biotonne', 'value': None}, {'key': 5, 'year': '2009', 'column': 'biotonne', 'value': None}, {'key': 6, 'year': '2010', 'column': 'biotonne', 'value': None}, {'key': 7, 'year': '2011', 'column': 'biotonne', 'value': None}, {'key': 8, 'year': '2012', 'column': 'biotonne', 'value': None}, {'key': 9, 'year': '2013', 'column': 'biotonne', 'value': None}, {'key': 10, 'year': '2014', 'column': 'biotonne', 'value': None}, {'key': 11, 'year': '2015', 'column': 'biotonne', 'value': None}, {'key': 12, 'year': '2016', 'column': 'biotonne', 'value': None}, {'key': 13, 'year': '2017', 'column': 'biotonne', 'value': None}, {'key': 14, 'year': '2018', 'column': 'biotonne', 'value': None}, {'key': 15, 'year': '2019', 'column': 'biotonne', 'value': None}, {'key': 16, 'year': '2020', 'column': 'biotonne', 'value': None}, {'key': 17, 'year': '2004', 'column': 'gartenPark', 'value': 0.0}, {'key': 18, 'year': '2005', 'column': 'gartenPark', 'value': 0.0}, {'key': 19, 'year': '2006', 'column': 'gartenPark', 'value': 0.0}, {'key': 20, 'year': '2007', 'column': 'gartenPark', 'value': 0.0}, {'key': 21, 'year': '2008', 'column': 'gartenPark', 'value': None}, {'key': 22, 'year': '2009', 'column': 'gartenPark', 'value': None}, {'key': 23, 'year': '2010', 'column': 'gartenPark', 'value': None}, {'key': 24, 'year': '2011', 'column': 'gartenPark', 'value': None}, {'key': 25, 'year': '2012', 'column': 'gartenPark', 'value': None}, {'key': 26, 'year': '2013', 'column': 'gartenPark', 'value': None}, {'key': 27, 'year': '2014', 'column': 'gartenPark', 'value': None}, {'key': 28, 'year': '2015', 'column': 'gartenPark', 'value': None}, {'key': 29, 'year': '2016', 'column': 'gartenPark', 'value': None}, {'key': 30, 'year': '2017', 'column': 'gartenPark', 'value': None}, {'key': 31, 'year': '2018', 'column': 'gartenPark', 'value': None}, {'key': 32, 'year': '2019', 'column': 'gartenPark', 'value': None}, {'key': 33, 'year': '2020', 'column': 'gartenPark', 'value': None}, {'key': 34, 'year': '2004', 'column': 'sum', 'value': 0.0}, {'key': 35, 'year': '2005', 'column': 'sum', 'value': 0.0}, {'key': 36, 'year': '2006', 'column': 'sum', 'value': 0.0}, {'key': 37, 'year': '2007', 'column': 'sum', 'value': 19.315307350376973}, {'key': 38, 'year': '2008', 'column': 'sum', 'value': None}, {'key': 39, 'year': '2009', 'column': 'sum', 'value': None}, {'key': 40, 'year': '2010', 'column': 'sum', 'value': None}, {'key': 41, 'year': '2011', 'column': 'sum', 'value': None}, {'key': 42, 'year': '2012', 'column': 'sum', 'value': None}, {'key': 43, 'year': '2013', 'column': 'sum', 'value': None}, {'key': 44, 'year': '2014', 'column': 'sum', 'value': None}, {'key': 45, 'year': '2015', 'column': 'sum', 'value': None}, {'key': 46, 'year': '2016', 'column': 'sum', 'value': None}, {'key': 47, 'year': '2017', 'column': 'sum', 'value': None}, {'key': 48, 'year': '2018', 'column': 'sum', 'value': None}, {'key': 49, 'year': '2019', 'column': 'sum', 'value': None}, {'key': 50, 'year': '2020', 'column': 'sum', 'value': None}]
# [{'key': 0, 'year': '2010', 'column': 'Rinder', 'value': 0.0}, {'key': 1, 'year': '2016', 'column': 'Rinder', 'value': 0.0}, {'key': 2, 'year': '2020', 'column': 'Rinder', 'value': 0.0}, {'key': 3, 'year': '2010', 'column': 'Schafe', 'value': 0.0}, {'key': 4, 'year': '2016', 'column': 'Schafe', 'value': 0.0}, {'key': 5, 'year': '2020', 'column': 'Schafe', 'value': 0.0}, {'key': 6, 'year': '2010', 'column': 'Schweine', 'value': 0.0}, {'key': 7, 'year': '2016', 'column': 'Schweine', 'value': 0.0}, {'key': 8, 'year': '2020', 'column': 'Schweine', 'value': 0.0}]
# [{'key': 0, 'year': '2016', 'column': 'Umweltthermie', 'value': 0}, {'key': 1, 'year': '2017', 'column': 'Umweltthermie', 'value': 0}, {'key': 2, 'year': '2018', 'column': 'Umweltthermie', 'value': 0}, {'key': 3, 'year': '2019', 'column': 'Umweltthermie', 'value': 0}, {'key': 4, 'year': '2020', 'column': 'Umweltthermie', 'value': 0}, {'key': 5, 'year': '2016', 'column': 'andere erneuerbare Energien', 'value': 0}, {'key': 6, 'year': '2017', 'column': 'andere erneuerbare Energien', 'value': 0}, {'key': 7, 'year': '2018', 'column': 'andere erneuerbare Energien', 'value': 0}, {'key': 8, 'year': '2019', 'column': 'andere erneuerbare Energien', 'value': 0}, {'key': 9, 'year': '2020', 'column': 'andere erneuerbare Energien', 'value': 0}, {'key': 10, 'year': '2016', 'column': 'Gas', 'value': 0}, {'key': 11, 'year': '2017', 'column': 'Gas', 'value': 0}, {'key': 12, 'year': '2018', 'column': 'Gas', 'value': 0}, {'key': 13, 'year': '2019', 'column': 'Gas', 'value': 0}, {'key': 14, 'year': '2020', 'column': 'Gas', 'value': 0}, {'key': 15, 'year': '2016', 'column': 'andere fossile Energie', 'value': 0}, {'key': 16, 'year': '2017', 'column': 'andere fossile Energie', 'value': 0}, {'key': 17, 'year': '2018', 'column': 'andere fossile Energie', 'value': 0}, {'key': 18, 'year': '2019', 'column': 'andere fossile Energie', 'value': 0}, {'key': 19, 'year': '2020', 'column': 'andere fossile Energie', 'value': 0}, {'key': 20, 'year': '2016', 'column': 'Strom', 'value': 0}, {'key': 21, 'year': '2017', 'column': 'Strom', 'value': 0}, {'key': 22, 'year': '2018', 'column': 'Strom', 'value': 0}, {'key': 23, 'year': '2019', 'column': 'Strom', 'value': 0}, {'key': 24, 'year': '2020', 'column': 'Strom', 'value': 0}, {'key': 25, 'year': '2016', 'column': 'renewables', 'value': 0}, {'key': 26, 'year': '2017', 'column': 'renewables', 'value': 0}, {'key': 27, 'year': '2018', 'column': 'renewables', 'value': 0}, {'key': 28, 'year': '2019', 'column': 'renewables', 'value': 0}, {'key': 29, 'year': '2020', 'column': 'renewables', 'value': 0}, {'key': 30, 'year': '2016', 'column': 'fossils', 'value': 0}, {'key': 31, 'year': '2017', 'column': 'fossils', 'value': 0}, {'key': 32, 'year': '2018', 'column': 'fossils', 'value': 0}, {'key': 33, 'year': '2019', 'column': 'fossils', 'value': 0}, {'key': 34, 'year': '2020', 'column': 'fossils', 'value': 0}]
# [{'key': 0, 'year': '2003', 'column': 'Erdgas', 'value': 789867.0}, {'key': 1, 'year': '2004', 'column': 'Erdgas', 'value': 809318.0}, {'key': 2, 'year': '2005', 'column': 'Erdgas', 'value': 748539.0}, {'key': 3, 'year': '2006', 'column': 'Erdgas', 'value': 657110.0}, {'key': 4, 'year': '2007', 'column': 'Erdgas', 'value': 583683.0}, {'key': 5, 'year': '2008', 'column': 'Erdgas', 'value': 0.0}, {'key': 6, 'year': '2009', 'column': 'Erdgas', 'value': 0.0}, {'key': 7, 'year': '2010', 'column': 'Erdgas', 'value': 0.0}, {'key': 8, 'year': '2011', 'column': 'Erdgas', 'value': 0.0}, {'key': 9, 'year': '2012', 'column': 'Erdgas', 'value': 0.0}, {'key': 10, 'year': '2013', 'column': 'Erdgas', 'value': 0.0}, {'key': 11, 'year': '2014', 'column': 'Erdgas', 'value': 0.0}, {'key': 12, 'year': '2015', 'column': 'Erdgas', 'value': 0.0}, {'key': 13, 'year': '2016', 'column': 'Erdgas', 'value': 0.0}, {'key': 14, 'year': '2017', 'column': 'Erdgas', 'value': 0.0}, {'key': 15, 'year': '2018', 'column': 'Erdgas', 'value': 0.0}, {'key': 16, 'year': '2019', 'column': 'Erdgas', 'value': 0.0}, {'key': 17, 'year': '2020', 'column': 'Erdgas', 'value': 0.0}, {'key': 18, 'year': '2003', 'column': 'Erneuerbare Energien', 'value': None}, {'key': 19, 'year': '2004', 'column': 'Erneuerbare Energien', 'value': None}, {'key': 20, 'year': '2005', 'column': 'Erneuerbare Energien', 'value': None}, {'key': 21, 'year': '2006', 'column': 'Erneuerbare Energien', 'value': None}, {'key': 22, 'year': '2007', 'column': 'Erneuerbare Energien', 'value': None}, {'key': 23, 'year': '2008', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 24, 'year': '2009', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 25, 'year': '2010', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 26, 'year': '2011', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 27, 'year': '2012', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 28, 'year': '2013', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 29, 'year': '2014', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 30, 'year': '2015', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 31, 'year': '2016', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 32, 'year': '2017', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 33, 'year': '2018', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 34, 'year': '2019', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 35, 'year': '2020', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 36, 'year': '2003', 'column': 'Heizöl', 'value': 171674.0}, {'key': 37, 'year': '2004', 'column': 'Heizöl', 'value': 149597.0}, {'key': 38, 'year': '2005', 'column': 'Heizöl', 'value': 151729.0}, {'key': 39, 'year': '2006', 'column': 'Heizöl', 'value': 152248.0}, {'key': 40, 'year': '2007', 'column': 'Heizöl', 'value': 167666.0}, {'key': 41, 'year': '2008', 'column': 'Heizöl', 'value': 0.0}, {'key': 42, 'year': '2009', 'column': 'Heizöl', 'value': 0.0}, {'key': 43, 'year': '2010', 'column': 'Heizöl', 'value': 0.0}, {'key': 44, 'year': '2011', 'column': 'Heizöl', 'value': 0.0}, {'key': 45, 'year': '2012', 'column': 'Heizöl', 'value': 0.0}, {'key': 46, 'year': '2013', 'column': 'Heizöl', 'value': 0.0}, {'key': 47, 'year': '2014', 'column': 'Heizöl', 'value': 0.0}, {'key': 48, 'year': '2015', 'column': 'Heizöl', 'value': 0.0}, {'key': 49, 'year': '2016', 'column': 'Heizöl', 'value': 0.0}, {'key': 50, 'year': '2017', 'column': 'Heizöl', 'value': 0.0}, {'key': 51, 'year': '2018', 'column': 'Heizöl', 'value': 0.0}, {'key': 52, 'year': '2019', 'column': 'Heizöl', 'value': 0.0}, {'key': 53, 'year': '2020', 'column': 'Heizöl', 'value': 0.0}, {'key': 54, 'year': '2003', 'column': 'Kohle', 'value': None}, {'key': 55, 'year': '2004', 'column': 'Kohle', 'value': None}, {'key': 56, 'year': '2005', 'column': 'Kohle', 'value': None}, {'key': 57, 'year': '2006', 'column': 'Kohle', 'value': None}, {'key': 58, 'year': '2007', 'column': 'Kohle', ' ...
# [{'key': 0, 'year': '2004', 'column': 'biotonne', 'value': 0.0}, {'key': 1, 'year': '2005', 'column': 'biotonne', 'value': 0.0}, {'key': 2, 'year': '2006', 'column': 'biotonne', 'value': 0.0}, {'key': 3, 'year': '2007', 'column': 'biotonne', 'value': 0.0}, {'key': 4, 'year': '2008', 'column': 'biotonne', 'value': None}, {'key': 5, 'year': '2009', 'column': 'biotonne', 'value': None}, {'key': 6, 'year': '2010', 'column': 'biotonne', 'value': None}, {'key': 7, 'year': '2011', 'column': 'biotonne', 'value': None}, {'key': 8, 'year': '2012', 'column': 'biotonne', 'value': None}, {'key': 9, 'year': '2013', 'column': 'biotonne', 'value': None}, {'key': 10, 'year': '2014', 'column': 'biotonne', 'value': None}, {'key': 11, 'year': '2015', 'column': 'biotonne', 'value': None}, {'key': 12, 'year': '2016', 'column': 'biotonne', 'value': None}, {'key': 13, 'year': '2017', 'column': 'biotonne', 'value': None}, {'key': 14, 'year': '2018', 'column': 'biotonne', 'value': None}, {'key': 15, 'year': '2019', 'column': 'biotonne', 'value': None}, {'key': 16, 'year': '2020', 'column': 'biotonne', 'value': None}, {'key': 17, 'year': '2004', 'column': 'gartenPark', 'value': 0.0}, {'key': 18, 'year': '2005', 'column': 'gartenPark', 'value': 0.0}, {'key': 19, 'year': '2006', 'column': 'gartenPark', 'value': 0.0}, {'key': 20, 'year': '2007', 'column': 'gartenPark', 'value': 0.0}, {'key': 21, 'year': '2008', 'column': 'gartenPark', 'value': None}, {'key': 22, 'year': '2009', 'column': 'gartenPark', 'value': None}, {'key': 23, 'year': '2010', 'column': 'gartenPark', 'value': None}, {'key': 24, 'year': '2011', 'column': 'gartenPark', 'value': None}, {'key': 25, 'year': '2012', 'column': 'gartenPark', 'value': None}, {'key': 26, 'year': '2013', 'column': 'gartenPark', 'value': None}, {'key': 27, 'year': '2014', 'column': 'gartenPark', 'value': None}, {'key': 28, 'year': '2015', 'column': 'gartenPark', 'value': None}, {'key': 29, 'year': '2016', 'column': 'gartenPark', 'value': None}, {'key': 30, 'year': '2017', 'column': 'gartenPark', 'value': None}, {'key': 31, 'year': '2018', 'column': 'gartenPark', 'value': None}, {'key': 32, 'year': '2019', 'column': 'gartenPark', 'value': None}, {'key': 33, 'year': '2020', 'column': 'gartenPark', 'value': None}, {'key': 34, 'year': '2004', 'column': 'sum', 'value': 0.0}, {'key': 35, 'year': '2005', 'column': 'sum', 'value': 0.0}, {'key': 36, 'year': '2006', 'column': 'sum', 'value': 0.0}, {'key': 37, 'year': '2007', 'column': 'sum', 'value': 5.889021615904924}, {'key': 38, 'year': '2008', 'column': 'sum', 'value': None}, {'key': 39, 'year': '2009', 'column': 'sum', 'value': None}, {'key': 40, 'year': '2010', 'column': 'sum', 'value': None}, {'key': 41, 'year': '2011', 'column': 'sum', 'value': None}, {'key': 42, 'year': '2012', 'column': 'sum', 'value': None}, {'key': 43, 'year': '2013', 'column': 'sum', 'value': None}, {'key': 44, 'year': '2014', 'column': 'sum', 'value': None}, {'key': 45, 'year': '2015', 'column': 'sum', 'value': None}, {'key': 46, 'year': '2016', 'column': 'sum', 'value': None}, {'key': 47, 'year': '2017', 'column': 'sum', 'value': None}, {'key': 48, 'year': '2018', 'column': 'sum', 'value': None}, {'key': 49, 'year': '2019', 'column': 'sum', 'value': None}, {'key': 50, 'year': '2020', 'column': 'sum', 'value': None}]
# [{'key': 0, 'year': '2010', 'column': 'Rinder', 'value': 0.0}, {'key': 1, 'year': '2016', 'column': 'Rinder', 'value': 0.0}, {'key': 2, 'year': '2020', 'column': 'Rinder', 'value': 0.0}, {'key': 3, 'year': '2010', 'column': 'Schafe', 'value': 0.0}, {'key': 4, 'year': '2016', 'column': 'Schafe', 'value': 0.0}, {'key': 5, 'year': '2020', 'column': 'Schafe', 'value': 0.0}, {'key': 6, 'year': '2010', 'column': 'Schweine', 'value': 0.0}, {'key': 7, 'year': '2016', 'column': 'Schweine', 'value': 0.0}, {'key': 8, 'year': '2020', 'column': 'Schweine', 'value': 0.0}]
# [{'key': 0, 'year': '2016', 'column': 'Umweltthermie', 'value': 0}, {'key': 1, 'year': '2017', 'column': 'Umweltthermie', 'value': 0}, {'key': 2, 'year': '2018', 'column': 'Umweltthermie', 'value': 0}, {'key': 3, 'year': '2019', 'column': 'Umweltthermie', 'value': 0}, {'key': 4, 'year': '2020', 'column': 'Umweltthermie', 'value': 0}, {'key': 5, 'year': '2016', 'column': 'andere erneuerbare Energien', 'value': 0}, {'key': 6, 'year': '2017', 'column': 'andere erneuerbare Energien', 'value': 0}, {'key': 7, 'year': '2018', 'column': 'andere erneuerbare Energien', 'value': 0}, {'key': 8, 'year': '2019', 'column': 'andere erneuerbare Energien', 'value': 0}, {'key': 9, 'year': '2020', 'column': 'andere erneuerbare Energien', 'value': 0}, {'key': 10, 'year': '2016', 'column': 'Gas', 'value': 0}, {'key': 11, 'year': '2017', 'column': 'Gas', 'value': 0}, {'key': 12, 'year': '2018', 'column': 'Gas', 'value': 0}, {'key': 13, 'year': '2019', 'column': 'Gas', 'value': 0}, {'key': 14, 'year': '2020', 'column': 'Gas', 'value': 0}, {'key': 15, 'year': '2016', 'column': 'andere fossile Energie', 'value': 0}, {'key': 16, 'year': '2017', 'column': 'andere fossile Energie', 'value': 0}, {'key': 17, 'year': '2018', 'column': 'andere fossile Energie', 'value': 0}, {'key': 18, 'year': '2019', 'column': 'andere fossile Energie', 'value': 0}, {'key': 19, 'year': '2020', 'column': 'andere fossile Energie', 'value': 0}, {'key': 20, 'year': '2016', 'column': 'Strom', 'value': 0}, {'key': 21, 'year': '2017', 'column': 'Strom', 'value': 0}, {'key': 22, 'year': '2018', 'column': 'Strom', 'value': 0}, {'key': 23, 'year': '2019', 'column': 'Strom', 'value': 0}, {'key': 24, 'year': '2020', 'column': 'Strom', 'value': 0}, {'key': 25, 'year': '2016', 'column': 'renewables', 'value': 0}, {'key': 26, 'year': '2017', 'column': 'renewables', 'value': 0}, {'key': 27, 'year': '2018', 'column': 'renewables', 'value': 0}, {'key': 28, 'year': '2019', 'column': 'renewables', 'value': 0}, {'key': 29, 'year': '2020', 'column': 'renewables', 'value': 0}, {'key': 30, 'year': '2016', 'column': 'fossils', 'value': 0}, {'key': 31, 'year': '2017', 'column': 'fossils', 'value': 0}, {'key': 32, 'year': '2018', 'column': 'fossils', 'value': 0}, {'key': 33, 'year': '2019', 'column': 'fossils', 'value': 0}, {'key': 34, 'year': '2020', 'column': 'fossils', 'value': 0}]
# ...
# [{'key': 0, 'year': '2020', 'column': 'Gesamt', 'value': 582.3373624881162}, {'key': 1, 'year': '2021', 'column': 'Gesamt', 'value': 587.4702472468026}, {'key': 2, 'year': '2020', 'column': 'Fossils', 'value': 577.8554936846394}, {'key': 3, 'year': '2021', 'column': 'Fossils', 'value': 577.1977177218217}, {'key': 4, 'year': '2020', 'column': 'Benzin', 'value': 429.1728914844493}, {'key': 5, 'year': '2021', 'column': 'Benzin', 'value': 426.3555297413646}, {'key': 6, 'year': '2020', 'column': 'Diesel', 'value': 144.2007333967133}, {'key': 7, 'year': '2021', 'column': 'Diesel', 'value': 146.73089844773196}, {'key': 8, 'year': '2020', 'column': 'Gas (einschl. bivalent)', 'value': 4.481868803476844}, {'key': 9, 'year': '2021', 'column': 'Gas (einschl. bivalent)', 'value': 4.1112895327251815}, {'key': 10, 'year': '2020', 'column': 'Elektro', 'value': 0.6337996287745031}, {'key': 11, 'year': '2021', 'column': 'Elektro', 'value': 1.252747503046454}, {'key': 12, 'year': '2020', 'column': 'Hybrid', 'value': 3.644347865453393}, {'key': 13, 'year': '2021', 'column': 'Hybrid', 'value': 8.871730044301707}, {'key': 14, 'year': '2020', 'column': 'sonstige Kraftstoffarten', 'value': 0.2037213092489474}, {'key': 15, 'year': '2021', 'column': 'sonstige Kraftstoffarten', 'value': 0.1480519776327627}]
# [{'key': 0, 'year': '2010', 'column': 'Rinder', 'value': 13797.0}, {'key': 1, 'year': '2016', 'column': 'Rinder', 'value': 12381.0}, {'key': 2, 'year': '2020', 'column': 'Rinder', 'value': 12050.0}, {'key': 3, 'year': '2010', 'column': 'Schafe', 'value': 1502.0}, {'key': 4, 'year': '2016', 'column': 'Schafe', 'value': 825.0}, {'key': 5, 'year': '2020', 'column': 'Schafe', 'value': 1173.0}, {'key': 6, 'year': '2010', 'column': 'Schweine', 'value': 36733.0}, {'key': 7, 'year': '2016', 'column': 'Schweine', 'value': 31199.0}, {'key': 8, 'year': '2020', 'column': 'Schweine', 'value': 29186.0}]
# [{'key': 0, 'year': '2016', 'column': 'Umweltthermie', 'value': 13}, {'key': 1, 'year': '2017', 'column': 'Umweltthermie', 'value': 21}, {'key': 2, 'year': '2018', 'column': 'Umweltthermie', 'value': 24}, {'key': 3, 'year': '2019', 'column': 'Umweltthermie', 'value': 17}, {'key': 4, 'year': '2020', 'column': 'Umweltthermie', 'value': 24}, {'key': 5, 'year': '2016', 'column': 'andere erneuerbare Energien', 'value': 8}, {'key': 6, 'year': '2017', 'column': 'andere erneuerbare Energien', 'value': 13}, {'key': 7, 'year': '2018', 'column': 'andere erneuerbare Energien', 'value': 11}, {'key': 8, 'year': '2019', 'column': 'andere erneuerbare Energien', 'value': 5}, {'key': 9, 'year': '2020', 'column': 'andere erneuerbare Energien', 'value': 10}, {'key': 10, 'year': '2016', 'column': 'Gas', 'value': 77}, {'key': 11, 'year': '2017', 'column': 'Gas', 'value': 31}, {'key': 12, 'year': '2018', 'column': 'Gas', 'value': 26}, {'key': 13, 'year': '2019', 'column': 'Gas', 'value': 24}, {'key': 14, 'year': '2020', 'column': 'Gas', 'value': 101}, {'key': 15, 'year': '2016', 'column': 'andere fossile Energie', 'value': 80}, {'key': 16, 'year': '2017', 'column': 'andere fossile Energie', 'value': 34}, {'key': 17, 'year': '2018', 'column': 'andere fossile Energie', 'value': 31}, {'key': 18, 'year': '2019', 'column': 'andere fossile Energie', 'value': 135}, {'key': 19, 'year': '2020', 'column': 'andere fossile Energie', 'value': 102}, {'key': 20, 'year': '2016', 'column': 'Strom', 'value': 0}, {'key': 21, 'year': '2017', 'column': 'Strom', 'value': 0}, {'key': 22, 'year': '2018', 'column': 'Strom', 'value': 6}, {'key': 23, 'year': '2019', 'column': 'Strom', 'value': 1}, {'key': 24, 'year': '2020', 'column': 'Strom', 'value': 1}, {'key': 25, 'year': '2016', 'column': 'renewables', 'value': 21}, {'key': 26, 'year': '2017', 'column': 'renewables', 'value': 34}, {'key': 27, 'year': '2018', 'column': 'renewables', 'value': 35}, {'key': 28, 'year': '2019', 'column': 'renewables', 'value': 22}, {'key': 29, 'year': '2020', 'column': 'renewables', 'value': 34}, {'key': 30, 'year': '2016', 'column': 'fossils', 'value': 80}, {'key': 31, 'year': '2017', 'column': 'fossils', 'value': 34}, {'key': 32, 'year': '2018', 'column': 'fossils', 'value': 37}, {'key': 33, 'year': '2019', 'column': 'fossils', 'value': 136}, {'key': 34, 'year': '2020', 'column': 'fossils', 'value': 103}]
# [{'key': 0, 'year': '2003', 'column': 'Erdgas', 'value': 240813.0}, {'key': 1, 'year': '2004', 'column': 'Erdgas', 'value': 255737.0}, {'key': 2, 'year': '2005', 'column': 'Erdgas', 'value': 257623.0}, {'key': 3, 'year': '2006', 'column': 'Erdgas', 'value': 624921.0}, {'key': 4, 'year': '2007', 'column': 'Erdgas', 'value': 688703.0}, {'key': 5, 'year': '2008', 'column': 'Erdgas', 'value': 348654.0}, {'key': 6, 'year': '2009', 'column': 'Erdgas', 'value': 366252.0}, {'key': 7, 'year': '2010', 'column': 'Erdgas', 'value': 439740.0}, {'key': 8, 'year': '2011', 'column': 'Erdgas', 'value': 394340.0}, {'key': 9, 'year': '2012', 'column': 'Erdgas', 'value': 368905.0}, {'key': 10, 'year': '2013', 'column': 'Erdgas', 'value': 349410.0}, {'key': 11, 'year': '2014', 'column': 'Erdgas', 'value': 306252.0}, {'key': 12, 'year': '2015', 'column': 'Erdgas', 'value': 342868.0}, {'key': 13, 'year': '2016', 'column': 'Erdgas', 'value': 366987.0}, {'key': 14, 'year': '2017', 'column': 'Erdgas', 'value': 362650.0}, {'key': 15, 'year': '2018', 'column': 'Erdgas', 'value': 347058.0}, {'key': 16, 'year': '2019', 'column': 'Erdgas', 'value': 365585.0}, {'key': 17, 'year': '2020', 'column': 'Erdgas', 'value': 349691.0}, {'key': 18, 'year': '2003', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 19, 'year': '2004', 'column': 'Erneuerbare Energien', 'value': None}, {'key': 20, 'year': '2005', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 21, 'year': '2006', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 22, 'year': '2007', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 23, 'year': '2008', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 24, 'year': '2009', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 25, 'year': '2010', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 26, 'year': '2011', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 27, 'year': '2012', 'column': 'Erneuerbare Energien', 'value': None}, {'key': 28, 'year': '2013', 'column': 'Erneuerbare Energien', 'value': None}, {'key': 29, 'year': '2014', 'column': 'Erneuerbare Energien', 'value': None}, {'key': 30, 'year': '2015', 'column': 'Erneuerbare Energien', 'value': None}, {'key': 31, 'year': '2016', 'column': 'Erneuerbare Energien', 'value': None}, {'key': 32, 'year': '2017', 'column': 'Erneuerbare Energien', 'value': None}, {'key': 33, 'year': '2018', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 34, 'year': '2019', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 35, 'year': '2020', 'column': 'Erneuerbare Energien', 'value': 0.0}, {'key': 36, 'year': '2003', 'column': 'Heizöl', 'value': 88692.0}, {'key': 37, 'year': '2004', 'column': 'Heizöl', 'value': 99830.0}, {'key': 38, 'year': '2005', 'column': 'Heizöl', 'value': 92802.0}, {'key': 39, 'year': '2006', 'column': 'Heizöl', 'value': 112969.0}, {'key': 40, 'year': '2007', 'column': 'Heizöl', 'value': 103685.0}, {'key': 41, 'year': '2008', 'column': 'Heizöl', 'value': 110084.0}, {'key': 42, 'year': '2009', 'column': 'Heizöl', 'value': 87039.0}, {'key': 43, 'year': '2010', 'column': 'Heizöl', 'value': 59859.0}, {'key': 44, 'year': '2011', 'column': 'Heizöl', 'value': 64328.0}, {'key': 45, 'year': '2012', 'column': 'Heizöl', 'value': 53217.0}, {'key': 46, 'year': '2013', 'column': 'Heizöl', 'value': 50047.0}, {'key': 47, 'year': '2014', 'column': 'Heizöl', 'value': 46935.0}, {'key': 48, 'year': '2015', 'column': 'Heizöl', 'value': 50451.0}, {'key': 49, 'year': '2016', 'column': 'Heizöl', 'value': 43101.0}, {'key': 50, 'year': '2017', 'column': 'Heizöl', 'value': 41589.0}, {'key': 51, 'year': '2018', 'column': 'Heizöl', 'value': 40064.0}, {'key': 52, 'year': '2019', 'column': 'Heizöl', 'value': 52241.0}, {'key': 53, 'year': '2020', 'column': 'Heizöl', 'value': 29746.0}, {'key': 54, 'year': '2003', 'column': 'Kohle', 'value': 0.0}, {'key': 55, 'year': '2004', 'column': 'Kohle', 'value': 0.0}, {'key': 56, 'year': '2005', 'column': 'Kohle', 'value': 0.0 ...
# [{'key': 0, 'year': '2004', 'column': 'biotonne', 'value': 50.37398162994819}, {'key': 1, 'year': '2005', 'column': 'biotonne', 'value': 49.06689230479951}, {'key': 2, 'year': '2006', 'column': 'biotonne', 'value': 47.87005471681898}, {'key': 3, 'year': '2007', 'column': 'biotonne', 'value': 49.39359035164984}, {'key': 4, 'year': '2008', 'column': 'biotonne', 'value': 46.80202546580797}, {'key': 5, 'year': '2009', 'column': 'biotonne', 'value': 48.62545527116699}, {'key': 6, 'year': '2010', 'column': 'biotonne', 'value': 45.10677056978039}, {'key': 7, 'year': '2011', 'column': 'biotonne', 'value': 48.39871020254829}, {'key': 8, 'year': '2012', 'column': 'biotonne', 'value': 45.858003778404}, {'key': 9, 'year': '2013', 'column': 'biotonne', 'value': 42.6579776721329}, {'key': 10, 'year': '2014', 'column': 'biotonne', 'value': 48.35769375977563}, {'key': 11, 'year': '2015', 'column': 'biotonne', 'value': 48.01611366195963}, {'key': 12, 'year': '2016', 'column': 'biotonne', 'value': 47.03789011756744}, {'key': 13, 'year': '2017', 'column': 'biotonne', 'value': 55.3226696083839}, {'key': 14, 'year': '2018', 'column': 'biotonne', 'value': 58.312434807696576}, {'key': 15, 'year': '2019', 'column': 'biotonne', 'value': 60.7877574306713}, {'key': 16, 'year': '2020', 'column': 'biotonne', 'value': 63.4478699805333}, {'key': 17, 'year': '2004', 'column': 'gartenPark', 'value': 60.38389886276218}, {'key': 18, 'year': '2005', 'column': 'gartenPark', 'value': 64.10943449442956}, {'key': 19, 'year': '2006', 'column': 'gartenPark', 'value': 61.68772261533026}, {'key': 20, 'year': '2007', 'column': 'gartenPark', 'value': 75.91493810072305}, {'key': 21, 'year': '2008', 'column': 'gartenPark', 'value': 84.8827491273782}, {'key': 22, 'year': '2009', 'column': 'gartenPark', 'value': 110.85166891183955}, {'key': 23, 'year': '2010', 'column': 'gartenPark', 'value': 103.9166076308066}, {'key': 24, 'year': '2011', 'column': 'gartenPark', 'value': 120.80894092602448}, {'key': 25, 'year': '2012', 'column': 'gartenPark', 'value': 118.9036295897582}, {'key': 26, 'year': '2013', 'column': 'gartenPark', 'value': 117.0877624058544}, {'key': 27, 'year': '2014', 'column': 'gartenPark', 'value': 89.75783398953669}, {'key': 28, 'year': '2015', 'column': 'gartenPark', 'value': 91.38655462184872}, {'key': 29, 'year': '2016', 'column': 'gartenPark', 'value': 91.79429519578198}, {'key': 30, 'year': '2017', 'column': 'gartenPark', 'value': 103.34252619966908}, {'key': 31, 'year': '2018', 'column': 'gartenPark', 'value': 85.62107459109168}, {'key': 32, 'year': '2019', 'column': 'gartenPark', 'value': 98.11730224961686}, {'key': 33, 'year': '2020', 'column': 'gartenPark', 'value': 88.99225859024854}, {'key': 34, 'year': '2004', 'column': 'sum', 'value': 110.75788049271036}, {'key': 35, 'year': '2005', 'column': 'sum', 'value': 113.17632679922906}, {'key': 36, 'year': '2006', 'column': 'sum', 'value': 109.55777733214924}, {'key': 37, 'year': '2007', 'column': 'sum', 'value': 125.3085284523729}, {'key': 38, 'year': '2008', 'column': 'sum', 'value': 131.68477459318618}, {'key': 39, 'year': '2009', 'column': 'sum', 'value': 159.47712418300654}, {'key': 40, 'year': '2010', 'column': 'sum', 'value': 149.023378200587}, {'key': 41, 'year': '2011', 'column': 'sum', 'value': 169.2076511285728}, {'key': 42, 'year': '2012', 'column': 'sum', 'value': 164.7616333681622}, {'key': 43, 'year': '2013', 'column': 'sum', 'value': 159.74574007798728}, {'key': 44, 'year': '2014', 'column': 'sum', 'value': 138.11552774931232}, {'key': 45, 'year': '2015', 'column': 'sum', 'value': 139.40266828380837}, {'key': 46, 'year': '2016', 'column': 'sum', 'value': 138.84310150970995}, {'key': 47, 'year': '2017', 'column': 'sum', 'value': 158.66519580805294}, {'key': 48, 'year': '2018', 'column': 'sum', 'value': 143.93350939878826}, {'key': 49, 'year': '2019', 'column': 'sum', 'value': 158.90505968028816}, {'key': 50, 'year': '2020', 'column': 'sum', 'value': 152.45144642129566}]

# %%
paths = [mobi2]
for path in paths:
    #read dataset
    df = pd.read_csv(path)

    #check if ags is in list of current ags
    check = df[~df['AGS'].isin(currentAGS)]

#TODO: agri1 & bui1 & en2 have regierunsgbezirke included
    #is brunaschweig included??

check
